# %%
import os
import re
import numpy as np

from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
from collections import Counter
from num2words import num2words

# %%
## Lemmatizations
import nltk
from nltk.stem import WordNetLemmatizer 
nltk.download('wordnet')

lemmatizer = WordNetLemmatizer()
# Out:
# [nltk_data] Downloading package wordnet to C:\Users\Lakshmi
# [nltk_data]     Praffulla\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
# Loading Dataset

# %%
inside_folder = 'stories'

# %%
#Place the path of the dataset 

directory = [x[0] for x in os.walk(str(os.getcwd())+'\\'+inside_folder+'\\')]
#Above command will give the path for directory[0] with \\ appended . So we remove \\ in next line
directory[0] = directory[0][:len(directory[0])-1]

directory
# Out:
# ['C:\\Users\\Lakshmi Praffulla\\Desktop\\Information Retrival Assignment 2\\GitHub\\Implementation of TF-IDF and Jaccard-Coefficient\\stories',
#  'C:\\Users\\Lakshmi Praffulla\\Desktop\\Information Retrival Assignment 2\\GitHub\\Implementation of TF-IDF and Jaccard-Coefficient\\stories\\FARNON',
#  'C:\\Users\\Lakshmi Praffulla\\Desktop\\Information Retrival Assignment 2\\GitHub\\Implementation of TF-IDF and Jaccard-Coefficient\\stories\\SRE']

# %%
#Extracting the title names from the data_files
#This has been done by finding the regular expression in .html files.

data = []
titles = []
file_name = []
check = False

for item in directory:
    file = open(item+"\\index.html","r")
    text = file.read().strip()
    file.close()
    
    nameofFile = re.findall('><A HREF="(.*)">', text)
    titleofFile = re.findall('<BR><TD> (.*)\n', text)
    #print(nameofFile)
    #print(titleofFile)

    if check == False:
        nameofFile = nameofFile[2:]
        check = True
    file_name.append(nameofFile)
    titles.append(titleofFile)    
    print(len(nameofFile), len(titleofFile))    
        
    for allfiles in range(len(nameofFile)):
        data.append((str(item) +"\\"+ str(nameofFile[allfiles]),titleofFile[allfiles]))
        
print('Total Number of files are:',len(data))
# Out:
# 452 452
# 0 0
# 15 15
# Total Number of files are: 467

# %%
len(titles)
# Out:
# 3

# %%
#Here titles and file_names are in list of lists i.e one list has 452 cells, second has 0 cells and third has 15 cells
#Here we are joining the three list onto one

titles = [j for i in titles for j in i]
file_name = [j for i in file_name for j in i]

# %%
print(len(titles))
len(file_name)
# Out:
# 467
# 467

# %%
# Data is in the form = [(path of the file, tilte)]
data[452]
# Out:
# ('C:\\Users\\Lakshmi Praffulla\\Desktop\\Information Retrival Assignment 2\\Dataset_for_question1\\stories\\SRE\\sre01.txt',
#  'SRE: The Saga Of The Best SRE Game Ever Played! By Josh Renaud')

# %%
# we have 467 files in total
total_files = len(data)
total_files
# Out:
# 467

# %%
def retrive_document_text(doc_id):
    print(data[doc_id])
    file = open(data[doc_id][0], 'r', encoding='cp1250')
    text = file.read().strip()
    file.close()
    print(text)
    

#Documents to read with document_id    
retrive_document_text(1)
# Out:
# ('C:\\Users\\Lakshmi Praffulla\\Desktop\\Information Retrival Assignment 2\\Dataset_for_question1\\stories\\13chil.txt', 'The Story of the Sly Fox')
# FOR CHILDREN:
#
#                                    Sly Fox
#
#     Mr. Rabbit sat on his front porch rocking, eating a great big carrot,
# and looking.
#
#     "Looks like Sly Fox coming down the road," he said to himself, walking
# to the end of the porch. Shading his eyes with his paws, he exclaimed, "It
# is Sly Fox."
#
#     "Good morning Mr. Rabbit," cried Sly Fox, as he walked across the yard.
# "Good morning," replied Mr. Rabbit, a slight frown on his face.
#
#     "Well," said Sly Fox, "as I haven't seen you in so long a time, thought
# I would stop and chat a while."
#
#     Mr. Rabbit could not be rude in his own home, even to an enemy, so he
# offered Sly Fox a seat on the porch.
#
#     "Take a chair," he said politely. 	But Sly Fox did not stay long, and as
# he was leaving, he asked: "Mr. Rabbit, my mother is having a good dinner
# tonight. Won't you, Mrs. Rabbit, and your three little rabs come to dinner
# with me?"
#
#     Oh, thought Mr. Rabbit, he knows about my little rabs and wants to take
# us off to eat us. He pretended to be disappointed as he replied: "Sorry, Sly
# Fox, we have an engagement for today, but if you want us we can come
# tomorrow."
#
#     At this Sly Fox chuckled inwardly, and readily agreed to come for them
# the next day. Wishing Mr. Rabbit "Good day", he trotted on down the road
# toward his home.
#
#     As soon as he was out of sight, Mr. Rabbit ran into his house and called
# Mrs. Rabbit. "Get all our things together," he said, "and put rubber boots
# on our little rabs. We have to move quickly to the Piney Woods across the
# brook. Old Sly Fox has found our home and will destroy us."
#
#     In no time at all the Rabbit family had moved, and the little rabs were
# delighted with their new home. A woodland of towering pines it was, the
# ground covered with pine needles which made a soft carpeting. The wind made
# music in the pine trees, birds sang, and the fragrance of flowers filled the
# air. They found a huge hollow tree where Mr. Rabbit burrowed deep and made
# them a cozy home. Squirrels had left nuts hidden around in the old tree.
# Owls hooted throughout the night, crickets chirped merrily.
#
#     Next morning old Sly Fox knocked on the door where he had left Mr.
# Rabbit. Mrs. Hedgehog answered the door. "Good morning, Mrs. Hedgehog. Is
# Mr. Rabbit in?" inquired Sly Fox with a wicked grin and a cunning look in
# his eyes.
#
#     "No," replied Mrs. Eedgehog, none too cordially. "The Rabbit family
# moved to parts unknown right after you left yesterday."
#
#     "Ah," exclaimed old Sly Fox, "Mr. Rabbit and family were going to have
# dinner with me. My mother has planned a real feast. Why don't you come and
# enjoy it with us?"
#
#     "Oh," replied Mrs. Hedgehog, smacking her lips and thinking of all the
# goodies, "I have just moved in and there is so much to do! Why not let it go
# until tomorrow?"
#
#     "Do you like nice young grasshoppers?" asked Sly Fox softly.
#
#     "Do I? Nothing so good as tender young grasshoppers," answered Mrs.
# Hedgehog, fairly dribbling at the mouth at the thought of such a dainty.
#
#     "Well," said Sly Fox, "we pass a field where there are any number of
# them. Come get in this sack, and when I stop in the field we will open the
# sack and rake in all of them we want. Mother will bake them with apples and
# they will be deilicious!" This was too much for greedy Mrs. Hedgehog to
# resist, so in the sack she went. Sly Fox with a grin grabbed the sack, threw
# it over his shoulder and trotted toward home. 	After going a long way, Mrs.
# Hedgehog became suspicious and cried, "How long before we reach that field
# of grasshoppers?"
#
#     "Why, you silly, greedy hedgehog, there is no field of grasshoppers for
# you. I am going to eat you for my dinner. It's you with apple dumplings that
# my mother will bake."
#
#     Every hair on Mrs. Hedgehog's head stood on end with fright. Oh, how
# foolish she had been! Her greed had trapped her. If only she had stayed home
# and straightened her house and cooked her own dinner, she would not have
# been in this sack to be eaten by Sly Fox. Greediness never pays, she thought
# to herself.
#
#     Sly Fox became tired, and as a slight rain had begun to fall, he looked
# for a dry place to sit down. Throwing the sack to the ground and chuckling
# at the thought of sitting on Mrs. Hedgehog, he dropped heavily upon the
# sack.
#
#     "Wow, Wow!" he cried, jumping quickly up, for Mrs. Hedgehog shot her
# sharp quills into him with all her might.
#
#     Sly Fox ran to and fro trying to pull out the quills, but they had gone
# too deep. Home he ran, screaming to his mother. Old Mother Fox threw him
# over a log and began pulling out the quills, at the same time calling to a
# neighbor fox to bring some honey to put on the places where the quills had
# been.
#
#     Mrs. Hedgehog crawled out of the bag and began walking slowly toward
# home. She thought to herself that never again would she be so greedy and
# allow herself to be fooled by Sly Fox or any one else.
#
#     Meanwhile, Mr. Rabbit and family were living happily in Piney Woods. The
# little rabs played on the crystal clear brook that ran through the woods,
# wading, sailing little leaf boats, and trying to catch the silvery minnows
# darting here and there.
#
#     Late one evening Papa and Mama Rabbit were sitting before the cozy fire
# talking. Papa Rabbit had on his house robe and bedroom slippers, reading the
# newspaper. Every now and then he looked over his spectacles lovingly at
# dainty little Mama Rabbit, dressed in a flowered housecoat and red slippers
# and knitting little socks for the little rabs.
#
#     "Sniff! Sniff! Sniff!" came suddenly to their ears.
#
#     "Sly Fox!" whispered Papa Rabbit, his face now full of concern and
# alarm.
#
#     "Yes," agreed Mama Rabbit, her voice trembling with fright.
#
#     "Go cover the little rabs with straw and tell them to be very, very
# quiet," instructed Papa Rabbit.
#
#     Mrs. Rabbit quickly covered the little rabs and cautioned them to be as
# quiet as mice. Since they were well behaved and obedient little rabs, they
# did just as their mother told them.
#
#     "I left my big stick beside the old oak tree," cried Papa Rabbit under
# his breath. "What shall we do?"
#
#     "Sniff! Sniff! Sniff!" went Sly Fox again, scratching up the earth by
# the old hollow tree as he began to dig furiously. The poor little Rabbit
# family sat still and frightened, their hearts thumping, their paws shaking,
# and their eyes bulging with panic. Suddenly in the distance they heard the
# "Toot! Toot!Toot!" of horns, and the "Woof! Woof! Woof!" of barking dogs.
#
#     Papa Rabbit whispered, "Fox hunters!" as his heart gave a bound of
# relief.
#
#     Nearer and nearer came the baying of the hounds and the music of the
# horns. Old Sly Fox was so busily digging that he failed to hear at first,
# but suddenly he stopped digging, and threw back his ears to listen. Then he
# quickly jumped away from the log where the Rabbit family lived and started
# running.
#
#     But the hounds were right after him, baying loudly with all their might.
# The horses' feet beat out an excited rhythm as the red-coated fox hunters
# urged them on in the chase. Up hill, over the meadows they ran.
#
#     Sly Fox was now running for his life, but the dogs were getting closer
# and closer. He jumped across the brook and spied a hole among some bushes.
# Into this he slid, and as the dogs went down the side of the stream of water
# before they jumped across they lost his scent. Sly Fox quickly ran out of
# the hole and took off in the opposite direction from the way the dogs were
# going. He had been so frightened and so near death that he resolved to
# himself never to bother the Rabbit family again.
#
#     Meanwhile, when Papa Rabbit had heard the hounds start the chase, he
# turned to Mama Rabbit and cried, "Safe at last! Call our little rabs for
# prayers of thanksgiving and praise to our Father which art in heaven."
#
#     After prayers, Mama Rabbit hustled about making mint tea for her and
# Papa Rabbit, and hot chocolate piled high with whipped cream for the little
# rabs. After that time they Lived happily among the great whispering pines,
# never bothered by old Sly Fox.
#                                                           --Beulah Murrelle

# %%
def lematization(data):
    lemmatizer = WordNetLemmatizer()
    
    tokens = word_tokenize(str(data))
    new_text = ""
    for i in tokens:
        new_text = new_text + " " + lemmatizer.lemmatize(i)
    
    return new_text

# %%
def convert_lower_case(data):
    return np.char.lower(data)

# %%
def remove_stop_words(data):
    stop_words = stopwords.words('english')
    words = word_tokenize(str(data))
    new_text = ""
    for w in words:
        if w not in stop_words and len(w) > 1:
            new_text = new_text + " " + w
    return new_text

# %%
def remove_punctuation(data):
    symbols = "!\"#$%&()*+-./:;<=>?@[\]^_`{|}~\n"
    for i in range(len(symbols)):
        data = np.char.replace(data, symbols[i], ' ')
        data = np.char.replace(data, "  ", " ")
    data = np.char.replace(data, ',', '')
    return data

# %%
def remove_apostrophe(data):
    return np.char.replace(data, "'", "")

# %%
#Stemming was not done in this question
def stemming(data):
    stemmer= PorterStemmer()
    
    tokens = word_tokenize(str(data))
    new_text = ""
    for w in tokens:
        new_text = new_text + " " + stemmer.stem(w)
    return new_text

# %%
def convert_numbers(data):
    tokens = word_tokenize(str(data))
    new_text = ""
    for w in tokens:
        try:
            w = num2words(int(w))
        except:
            a = 0
        new_text = new_text + " " + w
    new_text = np.char.replace(new_text, "-", " ")
    return new_text

# %%
def preprocess(data):
    data = convert_lower_case(data)
    data = remove_punctuation(data) #remove comma seperately
    data = remove_apostrophe(data)
    data = remove_stop_words(data)
    data = convert_numbers(data)
    #data = stemming(data)
    data = lematization(data)
    data = remove_punctuation(data)
    data = convert_numbers(data)
    #data = stemming(data) #needed again as we need to stem the words
    data = remove_punctuation(data) #needed again as num2word is giving few hypens and commas fourty-one
    data = remove_stop_words(data) #needed again as num2word is giving stop words 101 - one hundred and one
    return data

# %%
# Extracting of the data into text and titles

# %%
processed_text = []
processed_title = []

for i in data[:total_files]:
    file = open(i[0], 'r', encoding="utf8", errors='ignore')
    text = file.read().strip()
    file.close()

    processed_text.append(word_tokenize(str(preprocess(text))))
    processed_title.append(word_tokenize(str(preprocess(i[1]))))

# %%
processed_title[0]
# Out:
# ['going',
#  'one',
#  'hundred',
#  'west',
#  'fifty',
#  'three',
#  'north',
#  'jim',
#  'prentice',
#  'one',
#  'thousand',
#  'nine',
#  'hundred',
#  'ninety']

# %% [markdown]
# # Jaccard Coefficient based document retrieval

# %%
import operator

# %%
def union(list1,list2):
    final_list = list(set(list1) | set(list2))
    return final_list

# %%
def intersection(list1,list2):
    final_list = list(set(list1) & set(list2))
    return final_list

# %%
def JaccardsCoefficient(query_list):
    JC = {}
    doc_id = 0
    for item in processed_text:
        #item 
        #query_list
    
        after_union = union(item,query_list)
        after_intersection = intersection(item,query_list)
    
        JC[doc_id] = len(after_intersection)/len(after_union)
    
        doc_id = doc_id + 1
        
        
        
        #Sorting the JC decreasing 
        final_ans = dict(sorted(JC.items(),key=operator.itemgetter(1),reverse=True))
            
    return final_ans

# %%
def execute(query,k):
    query_afterPreprocess =  preprocess(query)
    query_list = query_afterPreprocess.split(" ")
    query_list.remove('')
    #print(query_list)
    after_jc = JaccardsCoefficient(query_list)
    #print(after_jc.keys())
    count = -1
    list_append = []
    for item in after_jc.keys():
        count += 1
        if count == k:
            #print('Top ',k,' Documents based on Jaccard score are',list_append)
            print('Top ',k,' Documents based on Jaccard score are :')
            for i in list_append:
                print(file_name[i])
#                 print(titles[i]+ " - " +file_name[i])
            
            return
        list_append.append(item)
    
    #print('Top ',k,' Documents based on Jaccard score are',list_append)
    print('Top ',k,' Documents based on Jaccard score are :')
    
    for i in list_append:
        print(file_name[i])
#         print(titles[i]+" - "+file_name[i])

# %%
getInput = input('Enter the String   : ')
k = int(input('Enter how many closest matches required  : '))
print('-------------------------------------------------------------------------------------------------------------')
execute(getInput,k)
print('-------------------------------------------------------------------------------------------------------------')
# Out:
# Enter the String   : 100 west by 53 north
# Enter how many closest matches required  : 10
# -------------------------------------------------------------------------------------------------------------
# Top  10  Documents based on Jaccard score are :
# kneeslapper
# kneeslapper.txt
# traitor.txt
# poem-4.txt
# write
# poem-1.txt
# poem-2.txt
# mike.txt
# burltrs
# snowmaid.txt
# -------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # TF_IDF Based Document Retrival

# %%
# processed_text has all the text_data of each document stored in a list
# processed_text = [[Doc_0 text],[Doc_1 text],.....]

#Natural Term Frequency = tf

natural_term_frequency = []
for item in processed_text:
    dictionary_tf ={}
    
    for word in item:
        if dictionary_tf.get(word) == None:
            dictionary_tf[word] = 1
        else:
            count = dictionary_tf.get(word)
            count += 1
            dictionary_tf[word] = count
    
    natural_term_frequency.append(dictionary_tf)

# %%
natural_term_frequency[0]
# Out:
# {'shareware': 1,
#  'trial': 1,
#  'project': 1,
#  'freeware': 1,
#  'need': 1,
#  'support': 1,
#  'continue': 1,
#  'one': 12,
#  'hundred': 11,
#  'west': 2,
#  'fifty': 8,
#  'three': 5,
#  'north': 20,
#  'jim': 2,
#  'prentice': 2,
#  'copyright': 1,
#  'thousand': 3,
#  'nine': 2,
#  'ninety': 2,
#  'brandon': 1,
#  'manitoba': 1,
#  'canada': 1,
#  'magic': 1,
#  'phrase': 1,
#  'spoken': 1,
#  'mumbled': 1,
#  'thought': 2,
#  'inwardly': 1,
#  'soul': 1,
#  'venturing': 1,
#  'northward': 1,
#  'imaginary': 1,
#  'line': 3,
#  'shown': 1,
#  'map': 3,
#  'labelled': 1,
#  'degree': 5,
#  'presence': 1,
#  'indicated': 1,
#  'highway': 1,
#  'traveller': 3,
#  'road': 9,
#  'side': 3,
#  'sign': 1,
#  'division': 1,
#  'territory': 1,
#  'distinct': 1,
#  'mind': 1,
#  'international': 1,
#  'border': 1,
#  'writer': 2,
#  'poet': 1,
#  'pilot': 9,
#  'contributed': 1,
#  'lore': 1,
#  'rigor': 2,
#  'life': 17,
#  'bush': 3,
#  'told': 1,
#  'tale': 2,
#  'man': 3,
#  'eating': 1,
#  'mosquito': 3,
#  'murderous': 1,
#  'horde': 1,
#  'black': 2,
#  'fly': 6,
#  'lump': 1,
#  'flesh': 1,
#  'carried': 2,
#  'away': 4,
#  'giant': 1,
#  'bull': 1,
#  'dog': 4,
#  'story': 1,
#  'record': 2,
#  'breaking': 3,
#  'trout': 4,
#  'walleye': 3,
#  'pike': 2,
#  'legion': 1,
#  'sight': 1,
#  'sound': 2,
#  'heard': 2,
#  'deep': 1,
#  'spruce': 1,
#  'forest': 2,
#  'crashing': 1,
#  'moose': 6,
#  'tearing': 1,
#  'brush': 1,
#  'tree': 3,
#  'drumming': 1,
#  'grouse': 1,
#  'incessant': 1,
#  'hum': 1,
#  'insect': 2,
#  'cackling': 1,
#  'quackery': 1,
#  'duck': 3,
#  'feeding': 2,
#  'quiet': 2,
#  'pond': 1,
#  'placid': 1,
#  'bay': 1,
#  'intermittent': 1,
#  'song': 3,
#  'loon': 3,
#  'never': 3,
#  'forgotten': 1,
#  'voice': 2,
#  'signature': 1,
#  'authenticity': 1,
#  'northern': 13,
#  'scene': 1,
#  'wildlife': 2,
#  'land': 2,
#  'seems': 1,
#  'different': 2,
#  'found': 1,
#  'elsewhere': 1,
#  'take': 4,
#  'special': 2,
#  'breed': 1,
#  'person': 2,
#  'live': 4,
#  'farther': 2,
#  'travel': 4,
#  'becomes': 2,
#  'apparent': 1,
#  'southerner': 1,
#  'whether': 3,
#  'first': 3,
#  'fiftieth': 1,
#  'trip': 5,
#  'really': 1,
#  'aware': 1,
#  'implication': 1,
#  'living': 2,
#  'generally': 1,
#  'owner': 2,
#  'cottage': 2,
#  'southern': 5,
#  'lake': 14,
#  'amenity': 2,
#  'hand': 1,
#  'weekend': 1,
#  'roughing': 1,
#  'dweller': 2,
#  'year': 8,
#  'round': 1,
#  'basis': 2,
#  'modern': 1,
#  'cabin': 4,
#  'shore': 4,
#  'near': 1,
#  'large': 6,
#  'metropolitan': 1,
#  'center': 4,
#  'equipped': 3,
#  'electric': 2,
#  'service': 8,
#  'telephone': 3,
#  'paved': 2,
#  'natural': 2,
#  'gas': 3,
#  'pipeline': 1,
#  'cable': 1,
#  'television': 1,
#  'nearby': 3,
#  'provide': 2,
#  'food': 8,
#  'fuel': 3,
#  'repair': 2,
#  'entertainment': 1,
#  'drivein': 1,
#  'theater': 1,
#  'fast': 1,
#  'chain': 1,
#  'abound': 1,
#  'waterfront': 1,
#  'business': 2,
#  'dock': 1,
#  'built': 1,
#  'arriving': 1,
#  'boat': 4,
#  'shopping': 2,
#  'laundry': 1,
#  'transfer': 1,
#  'suitcase': 1,
#  'family': 2,
#  'car': 4,
#  'local': 4,
#  'merchant': 1,
#  'deliver': 1,
#  'good': 2,
#  'water': 5,
#  'entrepreneur': 1,
#  'make': 1,
#  'servicing': 1,
#  'maintaining': 1,
#  'absence': 1,
#  'season': 5,
#  'located': 1,
#  'five': 2,
#  'well': 2,
#  'street': 2,
#  'rival': 1,
#  'home': 8,
#  'many': 12,
#  'city': 4,
#  'community': 6,
#  'although': 2,
#  'seasonal': 2,
#  'differ': 1,
#  'little': 1,
#  'urban': 2,
#  'offer': 2,
#  'escape': 1,
#  'look': 1,
#  'average': 1,
#  'study': 1,
#  'compare': 1,
#  'standard': 1,
#  'area': 4,
#  'retreat': 1,
#  'bus': 5,
#  'doesnt': 1,
#  'start': 3,
#  'either': 1,
#  'walk': 1,
#  'call': 1,
#  'taxi': 3,
#  'yes': 1,
#  'kind': 1,
#  'another': 4,
#  'even': 2,
#  'ride': 1,
#  'back': 2,
#  'pick': 2,
#  'truck': 2,
#  'mail': 3,
#  'delivery': 3,
#  'unknown': 1,
#  'pleasant': 1,
#  'stroll': 1,
#  'midsummer': 1,
#  'contrasted': 1,
#  'ordeal': 1,
#  'threatening': 1,
#  'condition': 4,
#  'winter': 10,
#  'house': 2,
#  'milk': 1,
#  'bread': 1,
#  'nonexistent': 1,
#  'perhaps': 1,
#  'newspaper': 2,
#  'delivered': 1,
#  'requires': 2,
#  'effort': 2,
#  'especially': 2,
#  'rail': 2,
#  'scheduled': 1,
#  'air': 2,
#  'settlement': 3,
#  'severely': 1,
#  'restricted': 1,
#  'available': 4,
#  'small': 4,
#  'company': 1,
#  'exist': 1,
#  'fare': 1,
#  'collected': 1,
#  'transport': 3,
#  'native': 2,
#  'reserve': 2,
#  'diminishing': 1,
#  'recent': 1,
#  'bushpilot': 1,
#  'charter': 1,
#  'aircraft': 12,
#  'still': 1,
#  'play': 1,
#  'role': 1,
#  'transportation': 1,
#  'learn': 1,
#  'would': 1,
#  'keep': 1,
#  'colleague': 1,
#  'ground': 3,
#  'summer': 4,
#  'float': 2,
#  'busy': 1,
#  'hauling': 1,
#  'trapper': 1,
#  'fisherman': 3,
#  'freight': 2,
#  'fish': 7,
#  'fur': 1,
#  'supply': 1,
#  'camp': 2,
#  'traplines': 1,
#  'logging': 2,
#  'fall': 1,
#  'ice': 10,
#  'thin': 1,
#  'ski': 4,
#  'yet': 1,
#  'thick': 4,
#  'change': 3,
#  'wheel': 1,
#  'equipment': 5,
#  'changing': 1,
#  'permit': 1,
#  'flying': 3,
#  'present': 3,
#  'problem': 6,
#  'hear': 4,
#  'temperature': 2,
#  'exceeding': 1,
#  'forty': 5,
#  'zero': 5,
#  'blowing': 1,
#  'snow': 3,
#  'crystal': 1,
#  'whiteout': 1,
#  'challenge': 1,
#  'daily': 2,
#  'work': 2,
#  'preheating': 2,
#  'engine': 6,
#  'coax': 1,
#  'congealed': 1,
#  'oil': 3,
#  'propeller': 2,
#  'pitch': 1,
#  'mechanism': 1,
#  'fueling': 1,
#  'super': 1,
#  'cooled': 1,
#  'gasoline': 4,
#  'regular': 3,
#  'chore': 1,
#  'must': 7,
#  'tied': 2,
#  'rope': 1,
#  'frozen': 1,
#  'hole': 2,
#  'four': 4,
#  'foot': 2,
#  'lifted': 1,
#  'run': 1,
#  'onto': 2,
#  'board': 1,
#  'pole': 1,
#  'prevent': 1,
#  'freezing': 1,
#  'passenger': 2,
#  'wear': 2,
#  'heavy': 2,
#  'arctic': 3,
#  'clothing': 2,
#  'heat': 1,
#  'system': 1,
#  'capable': 1,
#  'coping': 1,
#  'cold': 4,
#  'battery': 1,
#  'removed': 1,
#  'end': 2,
#  'day': 15,
#  'ensure': 2,
#  'maximum': 1,
#  'efficiency': 1,
#  'next': 2,
#  'wing': 2,
#  'covered': 2,
#  'stop': 1,
#  'ingres': 1,
#  'build': 1,
#  'frost': 1,
#  'flight': 8,
#  'surface': 1,
#  'fueled': 1,
#  'blow': 1,
#  'pot': 1,
#  'often': 1,
#  'preheat': 1,
#  'starting': 1,
#  'get': 4,
#  'minus': 1,
#  'turned': 1,
#  'done': 1,
#  'chin': 1,
#  'ups': 1,
#  'coldsoaked': 1,
#  'cessna': 1,
#  'flew': 1,
#  'airport': 4,
#  'lack': 2,
#  'comparison': 1,
#  'south': 4,
#  'usually': 3,
#  'locate': 1,
#  'operator': 1,
#  'larger': 1,
#  'may': 10,
#  'pay': 2,
#  'airstrip': 1,
#  'normal': 1,
#  'procedure': 1,
#  'buzz': 3,
#  'town': 3,
#  'arrival': 2,
#  'let': 1,
#  'people': 3,
#  'know': 1,
#  'landing': 2,
#  'someone': 1,
#  'head': 1,
#  'strip': 1,
#  'meet': 1,
#  'unless': 1,
#  'customer': 2,
#  'transaction': 1,
#  'cash': 1,
#  'cheque': 1,
#  'nearly': 1,
#  'useless': 1,
#  'village': 1,
#  'without': 1,
#  'bank': 1,
#  'credit': 1,
#  'stranger': 1,
#  'foolhardy': 1,
#  'grip': 1,
#  'snowmobile': 3,
#  'major': 2,
#  'mode': 1,
#  'largest': 1,
#  'place': 2,
#  'vehicle': 3,
#  'left': 4,
#  'running': 1,
#  'twenty': 1,
#  'hour': 3,
#  'allowed': 1,
#  'restart': 1,
#  'balky': 1,
#  'resident': 1,
#  'enjoy': 2,
#  'month': 2,
#  'brings': 1,
#  'activity': 2,
#  'motor': 3,
#  'stored': 2,
#  'lawnmowers': 1,
#  'garden': 1,
#  'chair': 1,
#  'tuned': 1,
#  'fishing': 10,
#  'shack': 2,
#  'towed': 1,
#  'river': 3,
#  'blade': 1,
#  'powered': 1,
#  'auger': 1,
#  'sharpened': 1,
#  'flock': 1,
#  'favorite': 3,
#  'spot': 2,
#  'drill': 1,
#  'comfort': 1,
#  'woodburning': 1,
#  'stove': 1,
#  'glowing': 1,
#  'huddled': 1,
#  'lee': 1,
#  'normally': 1,
#  'catch': 1,
#  'tullibee': 1,
#  'whitefish': 1,
#  'perch': 1,
#  'burbot': 1,
#  'catfish': 1,
#  'bass': 1,
#  'plentiful': 1,
#  'popular': 1,
#  'bait': 2,
#  'minnow': 1,
#  'use': 3,
#  'sucker': 1,
#  'belly': 1,
#  'net': 1,
#  'bag': 1,
#  'egg': 2,
#  'others': 3,
#  'metal': 1,
#  'spoon': 1,
#  'bucktail': 1,
#  'lead': 1,
#  'headed': 1,
#  'jigging': 1,
#  'lure': 1,
#  'snelled': 1,
#  'hook': 1,
#  'best': 1,
#  'whatever': 1,
#  'taking': 1,
#  'time': 3,
#  'hunting': 7,
#  'sport': 3,
#  'colder': 1,
#  'weather': 1,
#  'move': 4,
#  'warmth': 1,
#  'hunter': 2,
#  'face': 2,
#  'similar': 1,
#  'extreme': 1,
#  'require': 2,
#  'snowmachine': 1,
#  'kept': 2,
#  'top': 1,
#  'started': 1,
#  'dependable': 1,
#  'death': 1,
#  'situation': 2,
#  'could': 1,
#  'develop': 1,
#  'machine': 1,
#  'break': 2,
#  'mile': 6,
#  'rifle': 1,
#  'care': 1,
#  'bolt': 1,
#  'grease': 1,
#  'freeze': 1,
#  'solid': 1,
#  'firing': 1,
#  'pin': 1,
#  'struck': 1,
#  'hammer': 1,
#  'bear': 2,
#  'lived': 1,
#  'weapon': 1,
#  'failed': 1,
#  'operate': 1,
#  'outdoor': 1,
#  'include': 1,
#  'cross': 1,
#  'country': 1,
#  'skiing': 1,
#  'snowmobiling': 1,
#  'racing': 1,
#  'team': 1,
#  'included': 1,
#  'festival': 1,
#  'held': 1,
#  'spring': 2,
#  'arrives': 1,
#  'brought': 1,
#  'wager': 1,
#  'made': 3,
#  'date': 1,
#  'blower': 1,
#  'shovel': 1,
#  'skidoo': 1,
#  'suit': 2,
#  'replaced': 1,
#  'lawn': 2,
#  'mower': 1,
#  'rake': 1,
#  'bathing': 1,
#  'pussy': 1,
#  'willow': 1,
#  'blossom': 1,
#  'goose': 2,
#  'return': 2,
#  'frog': 1,
#  'begin': 2,
#  'croak': 1,
#  'battalion': 1,
#  'hatched': 1,
#  'low': 1,
#  'mercury': 1,
#  'climb': 1,
#  'upward': 1,
#  'high': 3,
#  'reach': 1,
#  'sometimes': 1,
#  'fantastic': 1,
#  'differential': 1,
#  'continues': 1,
#  'commercial': 1,
#  'trapping': 1,
#  'building': 1,
#  'construction': 2,
#  'landscaping': 1,
#  'patrol': 2,
#  'hydro': 1,
#  'transmission': 1,
#  'fire': 2,
#  'interval': 1,
#  'carry': 3,
#  'conservationist': 1,
#  'animal': 1,
#  'census': 1,
#  'tank': 1,
#  'baby': 1,
#  'restock': 1,
#  'seriously': 1,
#  'ill': 1,
#  'injured': 1,
#  'taken': 1,
#  'medical': 2,
#  'medevac': 2,
#  'tourist': 2,
#  'prospector': 1,
#  'vie': 1,
#  'geologist': 1,
#  'botanist': 1,
#  'biologist': 1,
#  'entomologist': 1,
#  'surveyor': 1,
#  'see': 2,
#  'touch': 1,
#  'smell': 2,
#  'measure': 1,
#  'wonder': 1,
#  'opening': 1,
#  'heralded': 1,
#  'recreational': 1,
#  'type': 2,
#  'trailer': 1,
#  'van': 1,
#  'motorhomes': 1,
#  '4x4s': 1,
#  'arrive': 2,
#  'tow': 1,
#  'bicycle': 1,
#  'motorcycle': 1,
#  'atvs': 1,
#  'timer': 1,
#  'fill': 1,
#  'private': 2,
#  'provincial': 1,
#  'government': 2,
#  'campground': 1,
#  'experienced': 1,
#  'adventuresome': 1,
#  'trail': 1,
#  'stream': 1,
#  'parking': 1,
#  'lot': 1,
#  'crammed': 1,
#  'booze': 1,
#  'sold': 1,
#  'great': 3,
#  'quantity': 1,
#  'hotel': 2,
#  'full': 1,
#  'reservation': 1,
#  'advance': 1,
#  'prior': 1,
#  'leaving': 1,
#  'short': 3,
#  'week': 1,
#  'prime': 1,
#  'period': 2,
#  'every': 1,
#  'camping': 1,
#  'occupied': 1,
#  'sportsman': 1,
#  'recede': 1,
#  'cycle': 1,
#  'repeat': 1,
#  'annually': 1,
#  'number': 1,
#  'privately': 1,
#  'owned': 1,
#  'piper': 1,
#  'cub': 1,
#  'beechcraft': 1,
#  'taildragger': 1,
#  'bizjet': 1,
#  'new': 6,
#  'experience': 2,
#  'unnerving': 1,
#  'accustomed': 2,
#  'network': 1,
#  'railroad': 1,
#  'track': 1,
#  'always': 1,
#  'contact': 2,
#  'navigation': 2,
#  'aid': 1,
#  'seldom': 1,
#  'prepared': 1,
#  'reality': 1,
#  'apart': 1,
#  'case': 3,
#  'railway': 1,
#  'lower': 2,
#  'altitude': 1,
#  'exception': 1,
#  'rather': 2,
#  'rule': 1,
#  'plan': 1,
#  'course': 3,
#  'mandatory': 1,
#  'reading': 1,
#  'difficult': 2,
#  'basic': 1,
#  'shape': 1,
#  'sharp': 1,
#  'eye': 1,
#  'seaplane': 2,
#  'ever': 1,
#  'danger': 2,
#  'log': 1,
#  'rock': 1,
#  'reef': 1,
#  'amplified': 1,
#  'distance': 1,
#  'civilization': 3,
#  'carefully': 1,
#  'planned': 1,
#  'around': 2,
#  'suitable': 1,
#  'refueling': 1,
#  'facility': 2,
#  'element': 1,
#  'pleasure': 1,
#  'remote': 3,
#  'green': 1,
#  'undisturbed': 1,
#  'indescribable': 1,
#  'securing': 1,
#  'setting': 1,
#  'true': 1,
#  'beauty': 1,
#  'enjoyed': 3,
#  'teeming': 1,
#  'surrounded': 2,
#  'wood': 1,
#  'smoke': 1,
#  'coffee': 3,
#  'mingling': 1,
#  'fresh': 6,
#  'sizzling': 1,
#  'frypan': 1,
#  'bird': 2,
#  'cry': 2,
#  'evening': 2,
#  'wail': 2,
#  'coyote': 1,
#  'wolf': 1,
#  'whistle': 1,
#  'raven': 1,
#  'hawk': 1,
#  'eagle': 1,
#  'shoreline': 1,
#  'wake': 1,
#  'passing': 2,
#  'beaver': 2,
#  'muskrat': 1,
#  'occasional': 1,
#  'warning': 1,
#  'smack': 1,
#  'tail': 1,
#  'sens': 1,
#  'varied': 1,
#  'hue': 1,
#  'evergreen': 1,
#  'deciduous': 1,
#  'color': 1,
#  'windflower': 1,
#  'taste': 2,
#  'wild': 2,
#  'strawberry': 1,
#  'raspberry': 1,
#  'blueberry': 2,
#  'excitement': 1,
#  'sky': 1,
#  'dancing': 1,
#  'dazzling': 1,
#  'display': 1,
#  'aurora': 1,
#  'borealis': 1,
#  'appears': 1,
#  'light': 1,
#  'star': 1,
#  'incredibly': 1,
#  'brilliant': 1,
#  'smog': 1,
#  'free': 1,
#  'heaven': 2,
#  'night': 3,
#  'lying': 1,
#  'tent': 2,
#  'rustling': 1,
#  'noise': 1,
#  'twig': 1,
#  'snap': 1,
#  'mouse': 1,
#  'rabbit': 1,
#  'secure': 1,
#  'visualize': 1,
#  'bundle': 1,
#  'securely': 1,
#  'branch': 1,
#  'wind': 1,
#  'rising': 1,
#  'wave': 1,
#  'airplane': 1,
#  'alright': 1,
#  'go': 1,
#  'check': 1,
#  'like': 2,
#  'morning': 2,
#  'chance': 1,
#  'big': 1,
#  'lost': 1,
#  'bigger': 1,
#  'lone': 1,
#  'ear': 1,
#  'somehow': 1,
#  'penetrated': 1,
#  'netting': 1,
#  'last': 1,
#  'thing': 2,
#  'sleep': 1,
#  'peacefully': 1,
#  'early': 1,
#  'announce': 1,
#  'constant': 1,
#  'sting': 1,
#  'slap': 1,
#  'warfare': 1,
#  'might': 1,
#  'far': 1,
#  'friend': 2,
#  'neighbor': 5,
#  'also': 2,
#  'facing': 1,
#  'howling': 1,
#  'screaming': 1,
#  'kid': 1,
#  'squealing': 1,
#  'tire': 1,
#  'police': 1,
#  'siren': 1,
#  'reek': 1,
#  'diesel': 1,
#  'fume': 1,
#  'jangle': 1,
#  'typewriter': 1,
#  'clatter': 1,
#  'pile': 1,
#  'dissatisfied': 1,
#  'grumble': 1,
#  'bos': 1,
#  'loom': 1,
#  'threateningly': 1,
#  'jostle': 1,
#  'lunch': 1,
#  'fight': 1,
#  'traffic': 1,
#  'deposit': 1,
#  'childrens': 1,
#  'toy': 1,
#  'cluttering': 1,
#  'driveway': 1,
#  'sit': 1,
#  'tv': 5,
#  'dinner': 1,
#  'discus': 1,
#  'crazy': 1,
#  'happen': 1,
#  'dealer': 1,
#  'order': 2,
#  'part': 1,
#  'shipped': 1,
#  'plane': 1,
#  'meanwhile': 1,
#  'sits': 1,
#  'applies': 1,
#  'appliance': 2,
#  'tool': 1,
#  'repairman': 1,
#  'send': 1,
#  'set': 2,
#  'buy': 1,
#  'providing': 1,
#  'station': 3,
#  'radio': 2,
#  'cbc': 1,
#  'augmented': 1,
#  'programming': 1,
#  'obtain': 1,
#  'example': 1,
#  'veterinarian': 1,
#  'visit': 1,
#  'weekly': 1,
#  'monthly': 1,
#  'extent': 1,
#  'serious': 1,
#  'illness': 1,
#  'injury': 1,
#  'distant': 1,
#  'meat': 1,
#  'produce': 1,
#  'become': 1,
#  'exists': 1,
#  'acute': 1,
#  'however': 1,
#  'access': 1,
#  'event': 1,
#  'shipment': 1,
#  'perishable': 1,
#  'commodity': 1,
#  'dependant': 1,
#  'space': 1,
#  'subsequent': 1,
#  'price': 5,
#  'reflect': 1,
#  'added': 1,
#  'cost': 3,
#  'product': 1,
#  'subject': 1,
#  'heating': 1,
#  'propane': 1,
#  'seven': 1,
#  'considerably': 1,
#  'expensive': 1,
#  'location': 1,
#  'higher': 2,
#  'ago': 1,
#  'ran': 1,
#  'bed': 1,
#  'per': 3,
#  'breakfast': 1,
#  'toast': 1,
#  'bacon': 1,
#  'twelve': 1,
#  'avgas': 1,
#  'gallon': 1,
#  'two': 2,
#  'circle': 1,
#  'expect': 1,
#  'matter': 1,
#  'ancestry': 2,
#  'white': 1,
#  'born': 1,
#  'parent': 1,
#  'moved': 1,
#  'employment': 2,
#  'reason': 1,
#  'transient': 1,
#  'following': 1,
#  'job': 2,
#  'working': 1,
#  'corporation': 1,
#  'transferred': 1,
#  'requirement': 1,
#  'definitely': 1,
#  'endure': 1,
#  'involved': 1,
#  'give': 1,
#  'extended': 1,
#  'ten': 3,
#  'adapted': 1,
#  'way': 1,
#  'owning': 1,
#  'able': 1,
#  'independently': 1,
#  'outdoors': 1,
#  'learned': 1,
#  'adjust': 1,
#  'passed': 1,
#  'child': 1,
#  'adult': 1,
#  'took': 1,
#  'stock': 1,
#  'stuck': 1,
#  'rut': 2,
#  'townspeople': 1,
#  'centered': 1,
#  'post': 1,
#  'office': 1,
#  'decided': 1,
#  'moving': 1,
#  'possibly': 1,
#  'remaining': 1,
#  'rest': 1,
#  'february': 1,
#  'eighty': 1,
#  'miss': 3,
#  ...}

# %%
# Logarithmic Term Frequency = 1 + log(tf)

logarithmic_term_frequency = []

for item in natural_term_frequency:
    dictionary_ltf = {}
    allkeys = item.keys()
    
    for word in allkeys:
        natural_freq = item.get(word)
        log_freq = 1 + np.log(natural_freq)
        dictionary_ltf[word] = log_freq
        
    logarithmic_term_frequency.append(dictionary_ltf)

# %%
#logarithmic_term_frequency[0]

# %%
#Augmented Term Frequency = 0.5 + ((0.5*tf)/max(tf))


augmented_term_frequency = []

for item in natural_term_frequency:
    dictionary_atf = {}
    allkeys = item.keys()
    max_tf = max(item.values())
    
    for word in allkeys:
        natural_freq = item.get(word)
        aug_freq = 0.5 + ((0.5 * natural_freq)/max_tf)
        dictionary_atf[word] = aug_freq
    
    augmented_term_frequency.append(dictionary_atf)

# %%
#augmented_term_frequency[0]

# %%
# Boolean Term Frequency
#Can't do boolean as we are storing in a dictionary of list  . So 0 will never occur . Calculation will be fine

boolean_term_frequency = []

for item in natural_term_frequency:
    dictionary_btf = {}
    allkeys = item.keys()
    
    for word in allkeys:
        natural_freq = item.get(word)
        if natural_freq > 0:
            bool_freq = 1
        else:
            bool_freq = 0
        dictionary_btf[word] = bool_freq
        
    boolean_term_frequency.append(dictionary_btf)

# %%
#boolean_term_frequency[0]

# %%
## Log average Term Frequency

logave_term_frequency = []

for item in natural_term_frequency:
    
    dictionary_latf = {}
    allkeys = item.keys()
    allvalues = item.values()
    avg = sum(allvalues)/len(allvalues)
    
    for word in allkeys:
        natural_freq = item.get(word)
        logave = (1+np.log(natural_freq))/(1+np.log(avg)) 
        dictionary_latf[word] = logave
    
    logave_term_frequency.append(dictionary_latf)

# %%
#logave_term_frequency[200]

# %%
# Various variants of Term Frequencies :
        #logave_term_frequency
        #boolean_term_frequency
        #augmented_term_frequency
        #logarithmic_term_frequency
        #natural_term_frequency

# %%
#Document Frequency 

document_frequency = {}

for item in processed_text:
    
    unique_terms = list(set(item))
    
    for word in unique_terms:
        
        if document_frequency.get(word) == None:
            document_frequency[word] = 1
        else:
            count = document_frequency.get(word)
            count += 1
            document_frequency[word] = count

# %%
len(document_frequency)
# Out:
# 45095

# %%
#document_frequency = { term : in how many documents the term is present }

# %%
print(len(document_frequency))
N = len(data)
print('Total Number of documents are',N)
# Out:
# 45095
# Total Number of documents are 467

# %%
#Inverse Document Frequency 

inverse_document_frequency = {}

keys_df = document_frequency.keys()

for item in keys_df:
    
    getvalue = document_frequency[item]
    in_doc_freq = np.log(N/getvalue)
    inverse_document_frequency[item] = in_doc_freq

# %%
#inverse_document_frequency

# %%
#TF-IDF weighting 
#Natural_Term_Frequency



list_return = []

for item in natural_term_frequency:
    dict_inside = {}
    allkeys = item.keys()
    
    for word in allkeys:
        current_freq = item[word]
        idf_for_word = inverse_document_frequency[word]
        update_freq = current_freq * idf_for_word
        dict_inside[word] = update_freq
    
    list_return.append(dict_inside)

# %%
list_return[0]
# Out:
# {'shareware': 4.536891345234797,
#  'trial': 2.5909811961794835,
#  'project': 2.4827676115392507,
#  'freeware': 6.1463292576688975,
#  'need': 0.7897429829968848,
#  'support': 1.8025238358152134,
#  'continue': 1.6919819614153895,
#  'one': 0.6060563428400709,
#  'hundred': 3.953750639324086,
#  'west': 3.9438839755465205,
#  'fifty': 8.669873797135445,
#  'three': 2.3478772770030782,
#  'north': 37.11739633041012,
#  'jim': 6.4037805570049136,
#  'prentice': 10.095433938001575,
#  'copyright': 1.445848891876481,
#  'thousand': 1.229270880569116,
#  'nine': 1.0446235029631177,
#  'ninety': 1.5607064852940917,
#  'brandon': 5.0477169690007875,
#  'manitoba': 5.453182077108952,
#  'canada': 3.8437441646748516,
#  'magic': 1.828841144132587,
#  'phrase': 2.4827676115392507,
#  'spoken': 2.408659639385529,
#  'mumbled': 2.5354113450246727,
#  'thought': 0.7560165237502503,
#  'inwardly': 4.066887715989061,
#  'soul': 1.5019383585275246,
#  'venturing': 4.200419108613584,
#  'northward': 4.200419108613584,
#  'imaginary': 3.150596984114906,
#  'line': 2.876830355484427,
#  'shown': 1.9874461743092255,
#  'map': 6.953063583539407,
#  'labelled': 4.200419108613584,
#  'degree': 10.60488783466874,
#  'presence': 1.7274886498722994,
#  'indicated': 2.6498216962024173,
#  'highway': 2.5909811961794835,
#  'traveller': 9.60567083550737,
#  'road': 12.304851881016312,
#  'side': 1.9721745945366327,
#  'sign': 1.2190755725116926,
#  'division': 2.7790334276824233,
#  'territory': 3.150596984114906,
#  'distinct': 2.8141247474936932,
#  'mind': 0.7039115471471038,
#  'international': 3.2559574997727325,
#  'border': 2.7790334276824233,
#  'writer': 4.277992144872853,
#  'poet': 3.3131159136126813,
#  'pilot': 23.318830765615353,
#  'contributed': 3.5813799002073603,
#  'lore': 4.354569788440842,
#  'rigor': 10.906364154217904,
#  'life': 7.751486656862227,
#  'bush': 7.019000303695732,
#  'told': 0.6409977217365346,
#  'tale': 3.7672987612551636,
#  'man': 1.6437218960115678,
#  'eating': 1.8155959173825662,
#  'mosquito': 13.063709365322527,
#  'murderous': 3.5813799002073603,
#  'horde': 3.4382790565666874,
#  'black': 1.8736862096549527,
#  'fly': 10.585815737970094,
#  'lump': 2.9274534328006965,
#  'flesh': 1.8978340156195384,
#  'carried': 2.7683106457422824,
#  'away': 1.5497099351664667,
#  'giant': 1.9122227530716378,
#  'bull': 3.150596984114906,
#  'dog': 5.856792122178711,
#  'story': 0.7992217269514287,
#  'record': 3.454977299744599,
#  'breaking': 6.257658741367434,
#  'trout': 16.267550863956245,
#  'walleye': 18.438987773006694,
#  'pike': 7.496867969741054,
#  'legion': 4.354569788440842,
#  'sight': 1.0649248926844344,
#  'sound': 1.5794859659937697,
#  'heard': 1.2658010230078303,
#  'deep': 0.9758452626307454,
#  'spruce': 4.200419108613584,
#  'forest': 3.6311918347651324,
#  'crashing': 2.712342053183751,
#  'moose': 30.286301814004723,
#  'tearing': 2.680593354869171,
#  'brush': 2.5354113450246727,
#  'tree': 3.427148855170314,
#  'drumming': 4.200419108613584,
#  'grouse': 5.0477169690007875,
#  'incessant': 3.748433984870527,
#  'hum': 2.7790334276824233,
#  'insect': 5.9365508546419035,
#  'cackling': 4.536891345234797,
#  'quackery': 6.1463292576688975,
#  'duck': 8.235395628020227,
#  'feeding': 5.854906865601393,
#  'quiet': 2.751289266406465,
#  'pond': 3.2559574997727325,
#  'placid': 3.949104680332678,
#  'bay': 2.4327571909645895,
#  'intermittent': 4.536891345234797,
#  'song': 5.824909914833794,
#  'loon': 14.28010468964702,
#  'never': 1.1812698565297928,
#  'forgotten': 1.7396100104046441,
#  'voice': 1.5054034226330715,
#  'signature': 4.066887715989061,
#  'authenticity': 4.536891345234797,
#  'northern': 34.44768205063142,
#  'scene': 1.6354697511520473,
#  'wildlife': 8.400838217227168,
#  'land': 2.785478133125065,
#  'seems': 1.3927390665625325,
#  'different': 2.325445271921122,
#  'found': 0.5332011512808271,
#  'elsewhere': 2.619968733052736,
#  'take': 1.810388475464791,
#  'special': 3.0427128887692523,
#  'breed': 3.010835041739748,
#  'person': 2.10515811372427,
#  'live': 4.360333809282357,
#  'farther': 4.592363311917677,
#  'travel': 8.076779490495223,
#  'becomes': 4.679333535797155,
#  'apparent': 2.3851291419753347,
#  'southerner': 6.1463292576688975,
#  'whether': 4.906409253456141,
#  'first': 1.2196090364689898,
#  'fiftieth': 5.0477169690007875,
#  'trip': 8.69805005202322,
#  'really': 0.6824974526432873,
#  'aware': 1.7396100104046441,
#  'implication': 3.949104680332678,
#  'living': 2.325445271921122,
#  'generally': 2.619968733052736,
#  'owner': 4.352074688233551,
#  'cottage': 5.9365508546419035,
#  'southern': 14.841377136604759,
#  'lake': 33.069954732508904,
#  'amenity': 9.520069793098013,
#  'hand': 0.4799025695564652,
#  'weekend': 2.8882327196474153,
#  'roughing': 5.453182077108952,
#  'dweller': 7.687488329349703,
#  'year': 4.2948596998715,
#  'round': 1.2190755725116926,
#  'basis': 5.700984783329137,
#  'modern': 2.4574498035549612,
#  'cabin': 11.401969566658273,
#  'shore': 9.931070446157003,
#  'near': 1.1093766552552682,
#  'large': 4.910718533275897,
#  'metropolitan': 4.200419108613584,
#  'center': 7.007520411985834,
#  'equipped': 8.235395628020227,
#  'electric': 4.817319278771058,
#  'service': 12.739618928546852,
#  'telephone': 7.859906199158208,
#  'paved': 8.133775431978123,
#  'natural': 3.8244455061432756,
#  'gas': 6.825384740283019,
#  'pipeline': 6.1463292576688975,
#  'cable': 2.712342053183751,
#  'television': 2.562810319212787,
#  'nearby': 5.40757150744564,
#  'provide': 4.865514381929179,
#  'food': 10.417137369682449,
#  'fuel': 8.44237424248108,
#  'repair': 5.490263752013484,
#  'entertainment': 3.010835041739748,
#  'drivein': 6.1463292576688975,
#  'theater': 3.5072719280536386,
#  'fast': 1.3260476920638604,
#  'chain': 1.8978340156195384,
#  'abound': 3.8437441646748516,
#  'waterfront': 4.354569788440842,
#  'business': 2.6360310407331924,
#  'dock': 3.0552868043105814,
#  'built': 1.5019383585275246,
#  'arriving': 3.0552868043105814,
#  'boat': 9.27075144471921,
#  'shopping': 5.361186709738342,
#  'laundry': 4.200419108613584,
#  'transfer': 3.010835041739748,
#  'suitcase': 4.066887715989061,
#  'family': 2.6682898045929595,
#  'car': 5.894001692827965,
#  'local': 6.9584400416185765,
#  'merchant': 3.010835041739748,
#  'deliver': 2.9274534328006965,
#  'good': 0.9051942377323955,
#  'water': 4.576103204071554,
#  'entrepreneur': 4.066887715989061,
#  'make': 0.4359022402940277,
#  'servicing': 4.760034896549007,
#  'maintaining': 3.5072719280536386,
#  'absence': 2.562810319212787,
#  'season': 13.895167138412116,
#  'located': 2.6498216962024173,
#  'five': 1.2658010230078303,
#  'well': 0.5940089554440764,
#  'street': 2.2448974736452416,
#  'rival': 3.010835041739748,
#  'home': 4.903518151531016,
#  'many': 7.546516334450276,
#  'city': 5.675765755826227,
#  'community': 16.88474848496216,
#  'although': 2.9657803271136602,
#  'seasonal': 10.095433938001575,
#  'differ': 3.748433984870527,
#  'little': 0.3811381548840527,
#  'urban': 6.876558113133375,
#  'offer': 3.579240861958611,
#  'escape': 1.581981066201061,
#  'look': 0.44254678301269623,
#  'average': 2.7790334276824233,
#  'study': 2.085886247122478,
#  'compare': 3.4382790565666874,
#  'standard': 2.362139623750636,
#  'area': 5.50257853281293,
#  'retreat': 3.010835041739748,
#  'bus': 13.895167138412116,
#  'doesnt': 1.3423082129356407,
#  'start': 3.4473509517143466,
#  'either': 1.0711554424350704,
#  'walk': 1.1224487368226208,
#  'call': 0.7664319041284379,
#  'taxi': 10.121221606287348,
#  'yes': 0.7850370919594721,
#  'kind': 0.9645457073768122,
#  'another': 1.770187132050785,
#  'even': 0.8784379858400433,
#  'ride': 1.8978340156195384,
#  'back': 0.5710860684060631,
#  'pick': 2.9657803271136602,
#  'truck': 4.468612504481502,
#  'mail': 6.953063583539407,
#  'delivery': 9.767872499318198,
#  'unknown': 1.7643026229950158,
#  'pleasant': 2.0519846954467966,
#  'stroll': 3.3131159136126813,
#  'midsummer': 5.0477169690007875,
#  'contrasted': 4.760034896549007,
#  'ordeal': 3.3131159136126813,
#  'threatening': 2.745131876006742,
#  'condition': 7.949784697236902,
#  'winter': 20.35455393495586,
#  'house': 1.6960237822417212,
#  'milk': 2.7790334276824233,
#  'bread': 2.8141247474936932,
#  'nonexistent': 4.354569788440842,
#  'perhaps': 1.204686835059593,
#  'newspaper': 5.125620638425574,
#  'delivered': 2.8882327196474153,
#  'requires': 6.021670083479496,
#  'effort': 3.553762810403752,
#  'especially': 3.0427128887692523,
#  'rail': 6.203613639890949,
#  'scheduled': 3.373740535429116,
#  'air': 1.7161244539487241,
#  'settlement': 11.24530195461158,
#  'severely': 2.8504923916645684,
#  'restricted': 4.200419108613584,
#  'available': 8.343544988489912,
#  'small': 2.9746075031864714,
#  'company': 1.5512094075343075,
#  'exist': 2.2751282467610063,
#  'fare': 3.5813799002073603,
#  'collected': 2.680593354869171,
#  'transport': 8.44237424248108,
#  'native': 5.239937466105472,
#  'reserve': 6.511914999545465,
#  'diminishing': 4.536891345234797,
#  'recent': 2.1760373441167755,
#  'bushpilot': 6.1463292576688975,
#  'charter': 4.354569788440842,
#  'aircraft': 48.802652591868735,
#  'still': 0.5044221867307838,
#  'play': 1.2410544792304679,
#  'role': 2.8504923916645684,
#  'transportation': 3.5072719280536386,
#  'learn': 1.6689924431906908,
#  'would': 0.25192642340404653,
#  'keep': 0.7897429829968848,
#  'colleague': 3.5072719280536386,
#  'ground': 3.049291628237471,
#  'summer': 6.721684556057255,
#  'float': 6.021670083479496,
#  'busy': 1.6576928879367574,
#  'hauling': 3.8437441646748516,
#  'trapper': 5.453182077108952,
#  'fisherman': 10.314837169700063,
#  'freight': 7.898209360665356,
#  'fish': 14.601203729857346,
#  'fur': 2.8141247474936932,
#  'supply': 1.9874461743092255,
#  'camp': 5.239937466105472,
#  'traplines': 6.1463292576688975,
#  'logging': 9.520069793098013,
#  'fall': 1.1093766552552682,
#  'ice': 19.56674515642472,
#  'thin': 1.5512094075343075,
#  'ski': 15.796418721330712,
#  'yet': 0.8282092638246809,
#  'thick': 6.586078349354529,
#  'change': 3.3871482625619187,
#  'wheel': 2.0031945312773645,
#  'equipment': 10.97542769543735,
#  'changing': 2.2545089595582706,
#  'permit': 3.1018068199454745,
#  'flying': 5.446787752147698,
#  'present': 4.178217199687598,
#  'problem': 7.812853027261836,
#  'hear': 3.452502115723635,
#  'temperature': 5.017486195885023,
#  'exceeding': 4.066887715989061,
#  'forty': 5.74558491952391,
#  'zero': 10.97542769543735,
#  'blowing': 2.3396667678985774,
#  'snow': 7.448302834617753,
#  'crystal': 2.4327571909645895,
#  'whiteout': 6.1463292576688975,
#  'challenge': 2.8504923916645684,
#  'daily': 4.592363311917677,
#  'work': 1.2497366796133018,
#  'preheating': 12.292658515337795,
#  'engine': 13.056224064700654,
#  'coax': 5.0477169690007875,
#  'congealed': 4.200419108613584,
#  'oil': 7.372349410664883,
#  'propeller': 10.906364154217904,
#  'pitch': 2.3851291419753347,
#  'mechanism': 2.7790334276824233,
#  'fueling': 5.0477169690007875,
#  'super': 2.362139623750636,
#  'cooled': 3.748433984870527,
#  'gasoline': 15.374976658699406,
#  'regular': 6.3629327008012435,
#  'chore': 4.066887715989061,
#  'must': 4.208062692325344,
#  'tied': 3.9438839755465205,
#  'rope': 2.3396667678985774,
#  'frozen': 2.2961816559588386,
#  'hole': 2.891697783752962,
#  'four': 2.5155054448167586,
#  'foot': 1.4873037515932357,
#  'lifted': 1.9268215524927905,
#  'run': 0.9368431048274763,
#  'onto': 2.5885979874985603,
#  'board': 1.7396100104046441,
#  'pole': 2.5909811961794835,
#  'prevent': 2.4827676115392507,
#  'freezing': 3.748433984870527,
#  'passenger': 4.9655352230785015,
#  'wear': 3.7117396330410126,
#  'heavy': 2.4673487438656907,
#  'arctic': 12.200663147967184,
#  'clothing': 4.724279247501272,
#  'heat': 1.7518801029964586,
#  'system': 1.5512094075343075,
#  'capable': 2.234306252240751,
#  'coping': 4.760034896549007,
#  'cold': 4.21031622744854,
#  'battery': 2.8882327196474153,
#  'removed': 1.7036780011785808,
#  'end': 1.233800340314948,
#  'day': 4.197918011034007,
#  'ensure': 7.014543856107277,
#  'maximum': 3.2018902785024568,
#  'efficiency': 3.949104680332678,
#  'next': 1.2497366796133018,
#  'wing': 4.241955133867496,
#  'covered': 2.6200947014348386,
#  'stop': 1.1029041407496507,
#  'ingres': 5.0477169690007875,
#  'build': 2.103277989834347,
#  'frost': 3.661422607880897,
#  'flight': 16.025556250218916,
#  'surface': 1.8155959173825662,
#  'fueled': 4.536891345234797,
#  'blow': 1.4641980305446778,
#  'pot': 2.2145036249445713,
#  'often': 1.3505387120721561,
#  'preheat': 6.1463292576688975,
#  'starting': 1.828841144132587,
#  'get': 1.269534560234761,
#  'minus': 3.2018902785024568,
#  'turned': 0.6369409210409201,
#  'done': 0.8530244329444049,
#  'chin': 2.362139623750636,
#  'ups': 3.5072719280536386,
#  'coldsoaked': 6.1463292576688975,
#  'cessna': 5.453182077108952,
#  'flew': 1.624540680619857,
#  'airport': 13.02382999909093,
#  'lack': 4.39017107817494,
#  'comparison': 3.150596984114906,
#  'south': 7.107525620807504,
#  'usually': 4.745943198603182,
#  'locate': 3.5813799002073603,
#  'operator': 3.150596984114906,
#  'larger': 1.9416366382779313,
#  'may': 8.184530888793162,
#  'pay': 2.7176750297737025,
#  'airstrip': 6.1463292576688975,
#  'normal': 1.7518801029964586,
#  'procedure': 3.010835041739748,
#  'buzz': 9.305420459836423,
#  'town': 4.026924638806922,
#  'arrival': 4.635375722359605,
#  'let': 0.5115396544996478,
#  'people': 1.6215815741186999,
#  'know': 0.35943187630218965,
#  'landing': 4.817319278771058,
#  'someone': 0.8940558296222674,
#  'head': 0.4492357711634928,
#  'strip': 2.362139623750636,
#  'meet': 1.2787948072133148,
#  'unless': 1.6576928879367574,
#  'customer': 4.724279247501272,
#  'transaction': 3.661422607880897,
#  'cash': 2.362139623750636,
#  'cheque': 4.536891345234797,
#  'nearly': 1.4101308092744018,
#  'useless': 2.3851291419753347,
#  'village': 2.1760373441167755,
#  'without': 0.6532678143283489,
#  'bank': 1.6689924431906908,
#  'credit': 2.085886247122478,
#  'stranger': 1.828841144132587,
#  'foolhardy': 5.0477169690007875,
#  'grip': 2.035455393495586,
#  'snowmobile': 15.143150907002362,
#  'major': 3.9133490312849437,
#  'mode': 2.9274534328006965,
#  'largest': 2.4574498035549612,
#  'place': 1.1790023919387191,
#  'vehicle': 7.448302834617753,
#  'left': 2.0035294401026387,
#  'running': 1.2787948072133148,
#  'twenty': 0.7850370919594721,
#  'hour': 2.426373533902738,
#  'allowed': 1.6465195873386322,
#  'restart': 5.0477169690007875,
#  'balky': 6.1463292576688975,
#  'resident': 3.4382790565666874,
#  'enjoy': 3.853643104985581,
#  'month': 2.2982339678095642,
#  'brings': 2.619968733052736,
#  'activity': 4.509017919116541,
#  'motor': 9.767872499318198,
#  'stored': 6.301193968229812,
#  'lawnmowers': 6.1463292576688975,
#  'garden': 1.9566745156424719,
#  'chair': 1.2635273350825265,
#  'tuned': 3.1018068199454745,
#  'fishing': 27.12342053183751,
#  'shack': 7.687488329349703,
#  'towed': 4.200419108613584,
#  'river': 5.650948141882745,
#  'blade': 2.562810319212787,
#  'powered': 2.9274534328006965,
#  'auger': 6.1463292576688975,
#  'sharpened': 3.661422607880897,
#  'flock': 3.0552868043105814,
#  'favorite': 6.309833969503042,
#  'spot': 2.891697783752962,
#  'drill': 3.4382790565666874,
#  'comfort': 2.4574498035549612,
#  'woodburning': 6.1463292576688975,
#  'stove': 3.5072719280536386,
#  'glowing': 2.3176878611798024,
#  'huddled': 2.8882327196474153,
#  'lee': 3.2559574997727325,
#  'normally': 2.5087430979425114,
#  'catch': 1.5116002694392616,
#  'tullibee': 6.1463292576688975,
#  'whitefish': 5.453182077108952,
#  'perch': 3.2559574997727325,
#  'burbot': 6.1463292576688975,
#  'catfish': 5.453182077108952,
#  'bass': 3.373740535429116,
#  'plentiful': 4.760034896549007,
#  'popular': 2.2545089595582706,
#  'bait': 7.162759800414721,
#  'minnow': 5.453182077108952,
#  'use': 2.49936983588133,
#  'sucker': 3.373740535429116,
#  'belly': 2.5354113450246727,
#  'net': 2.19508553908747,
#  'bag': 1.7036780011785808,
#  'egg': 4.509017919116541,
#  'others': 2.843496679209215,
#  'metal': 1.6804211390143138,
#  'spoon': 3.5072719280536386,
#  'bucktail': 6.1463292576688975,
#  'lead': 1.3260476920638604,
#  'headed': 1.5716182791655144,
#  'jigging': 6.1463292576688975,
#  'lure': 3.3131159136126813,
#  'snelled': 6.1463292576688975,
#  'hook': 2.562810319212787,
#  'best': 0.8331232786271101,
#  'whatever': 1.3927390665625325,
#  'taking': 1.0283354452521423,
#  'time': 0.41254821667890723,
#  'hunting': 18.33978113136915,
#  'sport': 7.606234035074018,
#  'colder': 4.354569788440842,
#  'weather': 2.1389960724364263,
#  'move': 4.385893001677441,
#  'warmth': 2.4827676115392507,
#  'hunter': 5.490263752013484,
#  'face': 1.0518567839034947,
#  'similar': 1.9566745156424719,
#  'extreme': 2.3396667678985774,
#  'require': 5.2996433924048345,
#  'snowmachine': 6.1463292576688975,
#  'kept': 2.1174658448730264,
#  'top': 0.9815432837453832,
#  'started': 0.7302288554644771,
#  'dependable': 5.453182077108952,
#  'death': 1.0403837837683165,
#  'situation': 3.143236558331029,
#  'could': 0.26579627126819705,
#  'develop': 3.010835041739748,
#  'machine': 1.6354697511520473,
#  'break': 2.5575896144266297,
#  'mile': 9.128138666307757,
#  'rifle': 2.7790334276824233,
#  'care': 1.0403837837683165,
#  'bolt': 2.2751282467610063,
#  'grease': 4.200419108613584,
#  'freeze': 3.2018902785024568,
#  'solid': 2.085886247122478,
#  'firing': 2.5909811961794835,
#  'pin': 2.745131876006742,
#  'struck': 1.6465195873386322,
#  'hammer': 3.2559574997727325,
#  'bear': 3.8244455061432756,
#  'lived': 1.1765159580928966,
#  'weapon': 1.4641980305446778,
#  'failed': 1.7643026229950158,
#  'operate': 3.150596984114906,
#  'outdoor': 5.0477169690007875,
#  'include': 2.745131876006742,
#  'cross': 1.7643026229950158,
#  'country': 1.6030344753988934,
#  'skiing': 4.354569788440842,
#  'snowmobiling': 6.1463292576688975,
#  'racing': 2.680593354869171,
#  'team': 2.2145036249445713,
#  'included': 2.680593354869171,
#  'festival': 3.949104680332678,
#  'held': 0.9988347808554442,
#  'spring': 3.739326277305684,
#  'arrives': 3.661422607880897,
#  'brought': 1.046462829844699,
#  'wager': 4.066887715989061,
#  'made': 1.307706720882083,
#  'date': 1.7518801029964586,
#  'blower': 4.536891345234797,
#  'shovel': 4.200419108613584,
#  'skidoo': 5.453182077108952,
#  'suit': 3.206068950797787,
#  'replaced': 2.234306252240751,
#  'lawn': 5.181962392358967,
#  'mower': 5.0477169690007875,
#  'rake': 4.200419108613584,
#  'bathing': 3.5072719280536386,
#  'pussy': 4.354569788440842,
#  'willow': 4.354569788440842,
#  'blossom': 3.661422607880897,
#  'goose': 6.747481070858232,
#  'return': 2.2982339678095642,
#  'frog': 3.0552868043105814,
#  'begin': 3.0232005388785232,
#  'croak': 4.760034896549007,
#  'battalion': 4.354569788440842,
#  'hatched': 3.8437441646748516,
#  'low': 1.3588375148868512,
#  'mercury': 3.5072719280536386,
#  'climb': 2.2751282467610063,
#  'upward': 2.4827676115392507,
#  'high': 2.843496679209215,
#  'reach': 1.3260476920638604,
#  'sometimes': 1.4367990563565631,
#  'fantastic': 2.8504923916645684,
#  'differential': 4.760034896549007,
#  'continues': 3.150596984114906,
#  'commercial': 2.8882327196474153,
#  'trapping': 4.066887715989061,
#  'building': 1.2865168533072253,
#  'construction': 5.6282494949873865,
#  'landscaping': 5.453182077108952,
#  'patrol': 6.511914999545465,
#  'hydro': 6.1463292576688975,
#  'transmission': 3.150596984114906,
#  'fire': 2.2448974736452416,
#  'interval': 2.745131876006742,
#  'carry': 4.420501269620974,
#  'conservationist': 6.1463292576688975,
#  'animal': 1.5512094075343075,
#  'census': 6.1463292576688975,
#  'tank': 2.745131876006742,
#  'baby': 1.8422641644647275,
#  'restock': 5.453182077108952,
#  'seriously': 2.2751282467610063,
#  'ill': 0.6208763185371133,
#  'injured': 2.9274534328006965,
#  'taken': 0.9645457073768122,
#  'medical': 4.635375722359605,
#  'medevac': 12.292658515337795,
#  'tourist': 7.162759800414721,
#  'prospector': 5.453182077108952,
#  'vie': 4.760034896549007,
#  'geologist': 5.0477169690007875,
#  'botanist': 6.1463292576688975,
#  'biologist': 5.0477169690007875,
#  'entomologist': 6.1463292576688975,
#  'surveyor': 6.1463292576688975,
#  'see': 0.5653961641416004,
#  'touch': 1.3927390665625325,
#  'smell': 3.4310249176511673,
#  'measure': 2.4327571909645895,
#  'wonder': 1.3756446332032326,
#  'opening': 1.7896204309793056,
#  'heralded': 4.760034896549007,
#  'recreational': 4.536891345234797,
#  'type': 3.2709395023040946,
#  'trailer': 3.748433984870527,
#  'van': 2.8882327196474153,
#  'motorhomes': 5.453182077108952,
#  '4x4s': 6.1463292576688975,
#  'arrive': 4.724279247501272,
#  'tow': 3.150596984114906,
#  'bicycle': 3.373740535429116,
#  'motorcycle': 3.8437441646748516,
#  'atvs': 6.1463292576688975,
#  'timer': 4.536891345234797,
#  'fill': 1.7274886498722994,
#  'private': 3.579240861958611,
#  'provincial': 4.536891345234797,
#  'government': 4.277992144872853,
#  'campground': 5.453182077108952,
#  'experienced': 2.3851291419753347,
#  'adventuresome': 6.1463292576688975,
#  'trail': 2.3851291419753347,
#  'stream': 2.035455393495586,
#  'parking': 2.5354113450246727,
#  'lot': 1.052579056862135,
#  'crammed': 3.748433984870527,
#  'booze': 3.8437441646748516,
#  'sold': 2.1760373441167755,
#  'great': 2.022175751992268,
#  'quantity': 3.150596984114906,
#  'hotel': 5.017486195885023,
#  'full': 0.7992217269514287,
#  'reservation': 3.373740535429116,
#  'advance': 2.4574498035549612,
#  'prior': 3.748433984870527,
#  'leaving': 1.3841553228711412,
#  'short': 3.067095834796915,
#  'week': 1.129049420853973,
#  'prime': 2.8141247474936932,
#  'period': 4.468612504481502,
#  'every': 0.6288763612041897,
#  'camping': 3.5072719280536386,
#  'occupied': 2.5909811961794835,
#  'sportsman': 4.200419108613584,
#  'recede': 5.0477169690007875,
#  'cycle': 2.8141247474936932,
#  'repeat': 2.6498216962024173,
#  'annually': 5.453182077108952,
#  'number': 1.1695955152483228,
#  'privately': 3.661422607880897,
#  'owned': 2.4574498035549612,
#  'piper': 4.354569788440842,
#  'cub': 4.536891345234797,
#  'beechcraft': 5.453182077108952,
#  'taildragger': 6.1463292576688975,
#  'bizjet': 6.1463292576688975,
#  'new': 3.7492100388399052,
#  'experience': 3.143236558331029,
#  'unnerving': 4.536891345234797,
#  'accustomed': 5.6282494949873865,
#  'network': 2.619968733052736,
#  'railroad': 3.8437441646748516,
#  'track': 1.6465195873386322,
#  'always': 0.529558160002326,
#  'contact': 3.657682288265174,
#  'navigation': 7.322845215761794,
#  'aid': 2.068791813763178,
#  'seldom': 2.745131876006742,
#  'prepared': 1.7396100104046441,
#  'reality': 1.9416366382779313,
#  'apart': 1.7396100104046441,
#  'case': 3.57150660020291,
#  'railway': 3.5072719280536386,
#  'lower': 3.8244455061432756,
#  'altitude': 3.748433984870527,
#  'exception': 2.619968733052736,
#  'rather': 2.325445271921122,
#  'rule': 1.9268215524927905,
#  'plan': 1.2787948072133148,
#  'course': 2.5590732988332148,
#  'mandatory': 4.536891345234797,
#  'reading': 1.5512094075343075,
#  'difficult': 3.579240861958611,
#  'basic': 2.7790334276824233,
#  'shape': 1.5019383585275246,
#  'sharp': 1.624540680619857,
#  'eye': 0.4492357711634928,
#  'seaplane': 12.292658515337795,
#  'ever': 0.5479072986705226,
#  'danger': 3.4792200208092883,
#  'log': 2.619968733052736,
#  'rock': 1.541159071680806,
#  'reef': 4.536891345234797,
#  'amplified': 4.760034896549007,
#  'distance': 1.3756446332032326,
#  'civilization': 8.78236029840209,
#  'carefully': 1.3756446332032326,
#  'planned': 2.1389960724364263,
#  'around': 0.9391509108012313,
#  'suitable': 3.150596984114906,
#  'refueling': 5.453182077108952,
#  'facility': 5.6282494949873865,
#  'element': 2.7790334276824233,
#  'pleasure': 1.8422641644647275,
#  'remote': 7.772943588538451,
#  'green': 1.1695955152483228,
#  'undisturbed': 3.8437441646748516,
#  'indescribable': 4.536891345234797,
#  'securing': 3.5072719280536386,
#  'setting': 1.9874461743092255,
#  'true': 1.2190755725116926,
#  'beauty': 1.9268215524927905,
#  'enjoyed': 6.15595408634039,
#  'teeming': 5.0477169690007875,
#  'surrounded': 4.241955133867496,
#  'wood': 1.4735004232069913,
#  'smoke': 1.6137297645156414,
#  'coffee': 5.736668259214913,
#  'mingling': 4.066887715989061,
#  'fresh': 10.97304686479552,
#  'sizzling': 4.760034896549007,
#  'frypan': 6.1463292576688975,
#  'bird': 3.249081361239714,
#  'cry': 2.6682898045929595,
#  'evening': 2.785478133125065,
#  'wail': 6.4037805570049136,
#  'coyote': 4.354569788440842,
#  'wolf': 2.5087430979425114,
#  'whistle': 2.9274534328006965,
#  'raven': 3.8437441646748516,
#  'hawk': 3.373740535429116,
#  'eagle': 3.4382790565666874,
#  'shoreline': 4.536891345234797,
#  'wake': 1.9122227530716378,
#  'passing': 3.553762810403752,
#  'beaver': 8.709139576881684,
#  'muskrat': 6.1463292576688975,
#  'occasional': 2.2961816559588386,
#  'warning': 1.9122227530716378,
#  'smack': 3.5072719280536386,
#  'tail': 1.9122227530716378,
#  'sens': 2.068791813763178,
#  'varied': 3.4382790565666874,
#  'hue': 3.4382790565666874,
#  'evergreen': 4.354569788440842,
#  'deciduous': 5.453182077108952,
#  'color': 1.7643026229950158,
#  'windflower': 6.1463292576688975,
#  'taste': 3.5286052459900317,
#  'wild': 3.206068950797787,
#  'strawberry': 3.949104680332678,
#  'raspberry': 4.760034896549007,
#  'blueberry': 9.073782690469594,
#  'excitement': 2.1389960724364263,
#  'sky': 1.3756446332032326,
#  'dancing': 2.157345211104623,
#  'dazzling': 3.5813799002073603,
#  'display': 2.362139623750636,
#  'aurora': 4.354569788440842,
#  'borealis': 5.453182077108952,
#  'appears': 2.2145036249445713,
#  'light': 0.6867437435247384,
#  'star': 1.4828901635568301,
#  'incredibly': 2.7790334276824233,
#  'brilliant': 2.019194872623806,
#  'smog': 4.200419108613584,
#  'free': 1.2190755725116926,
#  'heaven': 3.5286052459900317,
#  'night': 1.850700510472422,
#  'lying': 1.6137297645156414,
#  'tent': 6.4037805570049136,
#  'rustling': 3.5072719280536386,
#  'noise': 1.5512094075343075,
#  'twig': 3.661422607880897,
#  'snap': 2.5909811961794835,
#  'mouse': 2.562810319212787,
#  'rabbit': 2.8504923916645684,
#  'secure': 2.4574498035549612,
#  'visualize': 4.536891345234797,
#  'bundle': 2.9682754273209517,
#  'securely': 3.2559574997727325,
#  'branch': 2.0031945312773645,
#  'wind': 1.302142171210306,
#  'rising': 2.0031945312773645,
#  'wave': 1.6465195873386322,
#  'airplane': 4.066887715989061,
#  'alright': 2.745131876006742,
#  'go': 0.37177771212448896,
#  'check': 1.5716182791655144,
#  'like': 0.3965885369765026,
#  'morning': 1.8956644528061433,
#  'chance': 1.162722635960561,
#  'big': 0.7803532426470459,
#  'lost': 0.823319278530489,
#  'bigger': 2.2961816559588386,
#  'lone': 2.4827676115392507,
#  'ear': 1.2559801294471435,
#  'somehow': 1.6804211390143138,
#  'penetrated': 3.3131159136126813,
#  'netting': 5.453182077108952,
#  'last': 0.5115396544996478,
#  'thing': 0.8195139203794106,
#  'sleep': 1.2559801294471435,
#  'peacefully': 3.2018902785024568,
#  'early': 1.3341449022964798,
#  'announce': 3.748433984870527,
#  'constant': 2.5909811961794835,
#  'sting': 3.2018902785024568,
#  'slap': 3.5813799002073603,
#  'warfare': 3.949104680332678,
#  'might': 0.7664319041284379,
#  'far': 0.7527017113165357,
#  'friend': 1.3905816082063933,
#  'neighbor': 12.287249017774807,
#  'also': 1.6564185276493617,
#  'facing': 2.3396667678985774,
#  'howling': 2.9682754273209517,
#  'screaming': 1.581981066201061,
#  'kid': 1.5312087408276378,
#  'squealing': 4.066887715989061,
#  'tire': 2.6498216962024173,
#  'police': 1.7155124588255837,
#  'siren': 3.0552868043105814,
#  'reek': 4.066887715989061,
#  'diesel': 4.200419108613584,
#  'fume': 3.748433984870527,
#  'jangle': 6.1463292576688975,
#  'typewriter': 3.949104680332678,
#  'clatter': 3.5813799002073603,
#  'pile': 1.869663138652842,
#  'dissatisfied': 4.200419108613584,
#  'grumble': 4.536891345234797,
#  'bos': 2.4574498035549612,
#  'loom': 4.200419108613584,
#  'threateningly': 5.0477169690007875,
#  'jostle': 5.0477169690007875,
#  'lunch': 2.019194872623806,
#  'fight': 1.5613617789983254,
#  'traffic': 2.2545089595582706,
#  'deposit': 3.0552868043105814,
#  'childrens': 3.5813799002073603,
#  'toy': 2.4327571909645895,
#  'cluttering': 5.0477169690007875,
#  'driveway': 2.7790334276824233,
#  'sit': 1.4549813754397536,
#  'tv': 11.480908279794193,
#  'dinner': 1.7643026229950158,
#  'discus': 2.4327571909645895,
#  'crazy': 1.9268215524927905,
#  'happen': 1.5924523660683565,
#  'dealer': 3.373740535429116,
#  'order': 2.325445271921122,
#  'part': 0.7992217269514287,
#  'shipped': 3.949104680332678,
#  'plane': 2.5354113450246727,
#  'meanwhile': 2.019194872623806,
#  'sits': 2.745131876006742,
#  'applies': 3.8437441646748516,
#  'appliance': 7.898209360665356,
#  'tool': 2.157345211104623,
#  'repairman': 4.354569788440842,
#  'send': 1.4013971293056473,
#  'set': 1.3991837720051745,
#  'buy': 1.6465195873386322,
#  'providing': 3.150596984114906,
#  'station': 4.9395587620158965,
#  'radio': 4.635375722359605,
#  'cbc': 6.1463292576688975,
#  'augmented': 4.200419108613584,
#  'programming': 3.2559574997727325,
#  'obtain': 3.3131159136126813,
#  'example': 2.085886247122478,
#  'veterinarian': 5.453182077108952,
#  'visit': 1.6689924431906908,
#  'weekly': 3.949104680332678,
#  'monthly': 3.748433984870527,
#  'extent': 3.2559574997727325,
#  'serious': 1.8558698165205063,
#  'illness': 3.150596984114906,
#  'injury': 2.6498216962024173,
#  'distant': 1.9122227530716378,
#  'meat': 2.3176878611798024,
#  'produce': 2.680593354869171,
#  'become': 1.0837342246419306,
#  'exists': 3.0552868043105814,
#  'acute': 3.748433984870527,
#  'however': 0.9988347808554442,
#  'access': 2.408659639385529,
#  'event': 1.7036780011785808,
#  'shipment': 4.066887715989061,
#  'perishable': 5.0477169690007875,
#  'commodity': 4.200419108613584,
#  'dependant': 6.1463292576688975,
#  'space': 1.4367990563565631,
#  'subsequent': 3.8437441646748516,
#  'price': 9.41824690313791,
#  'reflect': 3.5813799002073603,
#  'added': 1.6919819614153895,
#  'cost': 5.736668259214913,
#  'product': 2.6498216962024173,
#  'subject': 1.5019383585275246,
#  'heating': 3.949104680332678,
#  'propane': 5.453182077108952,
#  'seven': 0.9645457073768122,
#  'considerably': 3.150596984114906,
#  'expensive': 2.4327571909645895,
#  'location': 2.3851291419753347,
#  'higher': 3.8832732765558626,
#  'ago': 1.0223652782656383,
#  'ran': 0.8784710986055692,
#  'bed': 1.129049420853973,
#  'per': 6.888544967876516,
#  'breakfast': 2.120977566933748,
#  'toast': 3.3131159136126813,
#  'bacon': 3.748433984870527,
#  'twelve': 1.2410544792304679,
#  'avgas': 5.453182077108952,
#  'gallon': 3.8437441646748516,
#  'two': 0.6055696812750753,
#  'circle': 1.7643026229950158,
#  'expect': 1.5924523660683565,
#  'matter': 0.942322570592102,
#  'ancestry': 10.095433938001575,
#  'white': 0.9368431048274763,
#  'born': 1.7518801029964586,
#  'parent': 1.7155124588255837,
#  'moved': 1.034341469312354,
#  'employment': 6.511914999545465,
#  'reason': 1.197569367290729,
#  'transient': 5.453182077108952,
#  'following': 1.4828901635568301,
#  'job': 2.409373670119186,
#  'working': 1.2865168533072253,
#  'corporation': 3.2018902785024568,
#  'transferred': 3.2559574997727325,
#  'requirement': 3.748433984870527,
#  'definitely': 2.234306252240751,
#  'endure': 3.010835041739748,
#  'involved': 1.7518801029964586,
#  'give': 0.6615323241782424,
#  'extended': 2.120977566933748,
#  'ten': 2.4846277914740424,
#  'adapted': 3.373740535429116,
#  'way': 0.32032915028844705,
#  'owning': 4.066887715989061,
#  'able': 0.9368431048274763,
#  'independently': 4.536891345234797,
#  'outdoors': 3.949104680332678,
#  'learned': 1.541159071680806,
#  'adjust': 3.2559574997727325,
#  'passed': 1.0283354452521423,
#  'child': 1.129049420853973,
#  'adult': 2.7790334276824233,
#  'took': 0.5442104367891965,
#  'stock': 2.562810319212787,
#  'stuck': 1.7274886498722994,
#  'rut': 9.520069793098013,
#  'townspeople': 4.760034896549007,
#  'centered': 3.2559574997727325,
#  'post': 2.035455393495586,
#  'office': 1.5716182791655144,
#  'decided': 0.942322570592102,
#  'moving': 1.445848891876481,
#  'possibly': 1.6919819614153895,
#  'remaining': 1.9719419877732602,
#  'rest': 0.8888338856411157,
#  'february': 3.8437441646748516,
#  'eighty': 1.1905022000676366,
#  'miss': 5.567609449561519,
#  ...}

# %%
#Function block for calculating TF-IDF

def calculate_tfidf(list_tf):
    list_return = []
    
    for item in list_tf:
        dict_inside = {}
        allkeys = item.keys()
        
        for word in allkeys:
            current_freq = item[word]
            idf_for_word = inverse_document_frequency[word]
            update_freq = current_freq * idf_for_word
            dict_inside[word] = update_freq
    
        list_return.append(dict_inside)
    
    return list_return

# %%
#Calculating TF-IDF for various variant

# %%
len(natural_term_frequency)
# Out:
# 467

# %%
tfidf_n = calculate_tfidf(natural_term_frequency)

# %%
tfidf_log = calculate_tfidf(logarithmic_term_frequency)

# %%
tfidf_aug = calculate_tfidf(augmented_term_frequency)

# %%
tfidf_bool = calculate_tfidf(boolean_term_frequency)

# %%
tfidf_logave = calculate_tfidf(logave_term_frequency)

# %%
def getRankdoc(variant_list,query_list):
    
    doc_rank = {}
    for i in range(N):
        doc_rank[i] = 0.0
        
    for query_word in query_list:
        count = -1
        for item in variant_list:
            count += 1
            if query_word in item :
                score = item[query_word]
                doc_rank[count] += score
                
    doc_rank = dict(sorted(doc_rank.items(),key=operator.itemgetter(1),reverse=True))           
    
    return doc_rank

# %%
#query = "once upon a time"

# %%
#execute_two(query,10)

# %%
N
# Out:
# 467

# %%
def topk(list_tfidf,query_list,k,string):
    
    
    list_tf = getRankdoc(list_tfidf,query_list)
    count = -1
    flag = 0
    list_append = []
    for item in list_tf.keys():
        count += 1
        if count == k:
            print('Top ',k,' Documents based on ',string,' tf-idf are',list_append)
            for i in list_append:
                print(file_name[i])
#                 print(titles[i])
            flag = 1
            break
        list_append.append(item)
    
    if flag == 0:
        print('Top ',k,' Documents based on ',string,' tf-idf are:',list_append)    
        for i in list_append:
            print(file_name[i])
#             print(titles[i])
            
    print()

# %%
def execute_two(query,k):
    query_afterPreprocess =  preprocess(query)
    query_list = query_afterPreprocess.split(" ")
    query_list.remove('')
    

    topk(tfidf_n,query_list,k,'Natural')
    topk(tfidf_log,query_list,k,'Logarithmic')   
    topk(tfidf_aug,query_list,k,'Augmented')
    topk(tfidf_bool,query_list,k,'Boolean')
    topk(tfidf_logave,query_list,k,'Logarithmic Average')

# %%
#execute_two(query,10)

# %%
getInputtwo = input('Enter the String   : ')
k = int(input('Enter how many closest matches required  : '))
print()
execute_two(getInputtwo,k)
# Out:
# Enter the String   : 50000 variety of flowers
# Enter how many closest matches required  : 10
#
# Top  10  Documents based on  Natural  tf-idf are [127, 310, 214, 356, 41, 126, 418, 224, 76, 97]
# dakota.txt
# outcast.dos
# gulliver.txt
# quest
# archive
# cybersla.txt
# timem.hac
# history5.txt
# breaks1.asc
# bureau.txt
#
# Top  10  Documents based on  Logarithmic  tf-idf are [76, 418, 356, 310, 214, 226, 359, 127, 126, 378]
# breaks1.asc
# timem.hac
# quest
# outcast.dos
# gulliver.txt
# hitch3.txt
# radar_ra.txt
# dakota.txt
# cybersla.txt
# sick-kid.txt
#
# Top  10  Documents based on  Augmented  tf-idf are [140, 418, 150, 214, 394, 76, 26, 270, 359, 129]
# domain.poe
# timem.hac
# empty.txt
# gulliver.txt
# sqzply.txt
# breaks1.asc
# aesop11.txt
# long1-3.txt
# radar_ra.txt
# darkness.txt
#
# Top  10  Documents based on  Boolean  tf-idf are [26, 76, 78, 129, 140, 145, 150, 214, 226, 270]
# aesop11.txt
# breaks1.asc
# breaks3.asc
# darkness.txt
# domain.poe
# elite.app
# empty.txt
# gulliver.txt
# hitch3.txt
# long1-3.txt
#
# Top  10  Documents based on  Logarithmic Average  tf-idf are [76, 140, 418, 310, 356, 130, 279, 226, 359, 224]
# breaks1.asc
# domain.poe
# timem.hac
# outcast.dos
# quest
# day.in.mcdonald
# mcdonaldl.txt
# hitch3.txt
# radar_ra.txt
# history5.txt

# %% [markdown]
# # Tf-Idf based vector space document retrieval

# %%
## Create Documents as Vectors
## This vector contains log tf-idf values . Using this normalize the vector 

## Then create query as vector of lof tf-idf values. 
## Normalize the query vector

## Then apply cosine rule to each document vector to that of query 
## Take maximum of these.

# %%
## document_frequency = { term : in how many documents the term is present }
## tf-idf_frequency i.e tfidf_log = [  {term : frequency , term : frequency,..} , { term:frequency , term:frequency, .. } ]

# %%
len(tfidf_log)
# Out:
# 467

# %%
#All terms that are present
all_terms = list(document_frequency.keys())

# %%
len(all_terms)
# Out:
# 45095

# %%
doc_vector = []

for item in tfidf_log:
    #item is a dictionary. it is a document actually
    doc_inside = []
    for word in all_terms:
        #for each term
        
        if word in item :
            #check if the word is present in the document. if yes then store its frequency or else store 0.0
            temp = item[word]
            doc_inside.append(temp)
        else:
            doc_inside.append(0.0)
            
    doc_vector += [doc_inside]

# %%
def cosinevalues(query):
    
    
    query_text = word_tokenize(str(preprocess(query)))
    
    #term_freq_query
    term_freq_query = {}

    for item in query_text:
    
        if item in term_freq_query:
            temp = term_freq_query[item]
            temp += 1
            term_freq_query[item] = temp
        else:
             term_freq_query[item] = 1
    
    
    # Coverting into log frequency

    for item in term_freq_query.keys():
    
        temp = term_freq_query[item]
        new = 1 + np.log(temp)
        term_freq_query[item] = new
    
    #inverse_document_frequency
    tf_idf_query = {}

    for item in term_freq_query.keys():
    
        if item in inverse_document_frequency :
        
            temp = inverse_document_frequency[item]
            toadd = temp * term_freq_query[item]
        
            tf_idf_query[item] = toadd
        
        else:
            tf_idf_query[item] = 0.0
    
    
    #  query vector 

    query_vector = []

    for word in all_terms :
    
        if word in tf_idf_query :
            temp = tf_idf_query[word]
            query_vector.append(temp)
        else:
            query_vector.append(0.0)
    
    
    #Normalization of doc vectors
    
    norm_doc_vector = []

    for item in doc_vector:
        #each doc list
    
        norm = 0.0
        for freq in item:
            norm += (freq*freq)
    
        norm = 1 / np.sqrt(norm)
    
        temp_list = []
    
        for freq in item:
            k = freq * norm
            temp_list.append(k)
        
        norm_doc_vector.append(temp_list)
        
    #Normalization of query vector    
    
    norm_query_vector = []

    normal = 0.0
    for item in query_vector:
        normal += (item*item)
    
    normal = 1/np.sqrt(normal)
    for item in query_vector:
        norm_query_vector.append(item * normal)
    
    
    #Compute Cosine Scores!!!
    
    cosine_scores = {}

    doc_id = -1
    for item in norm_doc_vector:
    
        doc_id += 1
        list_doc = np.array(item)
        list_query = np.array(norm_query_vector)
        score = sum(list(list_doc * list_query))
    
        cosine_scores[doc_id] = score
    
    sorted_cosine_scores = dict(sorted(cosine_scores.items(),key=operator.itemgetter(1),reverse=True))
    
#     print(sorted_cosine_scores)
    
    #Compute Cosine Score with giving weightage to titles!!!
    
    weighted_cosine_score = cosine_scores
    
    query_weight = remove_stop_words(query)
    query_weight = query_weight.split(" ")
    
    for i in query_weight :
        doc = 0
        
        for title in titles:
            
            if i.lower() in title.lower():
                s = cosine_scores[doc]
                ns = s * 1.4
                weighted_cosine_score[doc] = ns
            doc += 1
#     print("-------------------")
    weighted_cosine_score = dict(sorted(weighted_cosine_score.items(),key=operator.itemgetter(1),reverse=True))
#     print(weighted_cosine_score)
    
    return sorted_cosine_scores,weighted_cosine_score

# %%
def execute_three(getInputthree,k):
    
    cosine_value,cosine_value_weighted = cosinevalues(getInputthree)
    string = ""
    count = -1
    flag = 0
    list_append = []
    print("Not Giving spl attention to document titles")
    for item in cosine_value.keys():
        count += 1
        if count == k:
            print('Top ',k,' Documents based on ',string,' tf-idf are',list_append)
            for i in list_append:
                print(file_name[i]+ " ||| "+ titles[i])
#                 print(titles[i]+ " - "+ file_name[i])
            flag = 1
            break
        list_append.append(item)
    
    if flag == 0:
        print('Top ',k,' Documents based on ',string,' tf-idf are:',list_append)    
        for i in list_append:
            print(file_name[i]+" ||| "+ titles[i])
#             print(titles[i] + " - "+ file_name[i])

            
    print()
    
    print("Giving spl attention to document titles")
    string = ""
    count = -1
    flag = 0
    list_append = []
    for item in cosine_value_weighted.keys():
        count += 1
        if count == k:
            print('Top ',k,' Documents based on ',string,' tf-idf are',list_append)
            for i in list_append:
                print(file_name[i]+" ||| "+ titles[i])
#                 print(titles[i]+ " - "+ file_name[i])
            flag = 1
            break
        list_append.append(item)
    
    if flag == 0:
        print('Top ',k,' Documents based on ',string,' tf-idf are:',list_append)    
        for i in list_append:
            print(file_name[i]+" ||| "+ titles[i])
#             print(titles[i] + " - "+ file_name[i])

            
    print()

# %%
getInputthree = input('Enter the String   : ')
k = int(input('Enter how many closest matches required  : '))
print()
execute_three(getInputthree,k)
# Out:
# Enter the String   : 100 west by 53 north
# Enter how many closest matches required  : 10
#
# Not Giving spl attention to document titles
# Top  10  Documents based on    tf-idf are [317, 0, 106, 42, 384, 105, 79, 390, 328, 154]
# peace.fun ||| Vision of Peace on Earth
# 100west.txt ||| Going 100 West by 53 North by Jim Prentice (1990)
# candle.hum ||| The Wind, The Cold, The Candle, by Walter Hawn
# arctic.txt ||| The Arctic Circle and Beyond, by Jim Prentice (1990)
# snowmaid.txt ||| The Fable of the Snow Maiden
# campfire.txt ||| The Best Campire Story of the Week: Do you have a B.C.?
# bruce-p.txt ||| The Adventure of the Bruce-Partington Plans
# spam.key ||| The Key and I, or, My Travels in the Sky, and What I Found There, by Padre Martini, Archdukebishop of West Texas
# pphamlin.txt ||| The Pied Piper of Hamelin
# enginer.txt ||| The Adventure of the Engineer's Thumb
#
# Giving spl attention to document titles
# Top  10  Documents based on    tf-idf are [0, 317, 106, 390, 42, 384, 127, 105, 79, 328]
# 100west.txt ||| Going 100 West by 53 North by Jim Prentice (1990)
# peace.fun ||| Vision of Peace on Earth
# candle.hum ||| The Wind, The Cold, The Candle, by Walter Hawn
# spam.key ||| The Key and I, or, My Travels in the Sky, and What I Found There, by Padre Martini, Archdukebishop of West Texas
# arctic.txt ||| The Arctic Circle and Beyond, by Jim Prentice (1990)
# snowmaid.txt ||| The Fable of the Snow Maiden
# dakota.txt ||| Rifts World Book: North Dakota by Sean Satterlee
# campfire.txt ||| The Best Campire Story of the Week: Do you have a B.C.?
# bruce-p.txt ||| The Adventure of the Bruce-Partington Plans
# pphamlin.txt ||| The Pied Piper of Hamelin

# %%
#file_name[169]

# %%
titles[0]
# Out:
# 'Going 100 West by 53 North by Jim Prentice (1990)'

# %%
#retrive_document_text(53)

# %%
q = "danah away from the veiw "

# %%
query_text = word_tokenize(str(preprocess(q)))

# %%
query_text
# Out:
# ['danah', 'away', 'veiw']

# %%
#term_freq_query

term_freq_query = {}

for item in query_text:
    
    if item in term_freq_query:
        temp = term_freq_query[item]
        temp += 1
        term_freq_query[item] = temp
    else:
         term_freq_query[item] = 1

# %%
term_freq_query
# Out:
# {'danah': 1, 'away': 1, 'veiw': 1}

# %%
#Coverting into log frequency

for item in term_freq_query.keys():
    
    temp = term_freq_query[item]
    new = 1 + np.log(temp)
    term_freq_query[item] = new

# %%
 term_freq_query
# Out:
# {'danah': 1.0, 'away': 1.0, 'veiw': 1.0}

# %%
#inverse_document_frequency
tf_idf_query = {}

for item in term_freq_query.keys():
    
    if item in inverse_document_frequency :
        
        temp = inverse_document_frequency[item]
        toadd = temp * term_freq_query[item]
        
        tf_idf_query[item] = toadd
        
    else:
        tf_idf_query[item] = 0.0

# %%
tf_idf_query
# Out:
# {'danah': 6.1463292576688975, 'away': 0.3874274837916167, 'veiw': 0.0}

# %%
len(all_terms)
# Out:
# 45095

# %%
 #query vector 

query_vector = []

for word in all_terms :
    
    if word in tf_idf_query :
        temp = tf_idf_query[word]
        query_vector.append(temp)
    else:
        query_vector.append(0.0)

# %%
# l = query_vector

# for i in l:
#     if i != 0.0:
#         print(i)
# Out:
# 0.3874274837916167
# 6.1463292576688975

# %%
doc_vector[0]
# Out:
# [6.1463292576688975,
#  6.1463292576688975,
#  1.5924523660683565,
#  6.346650432998613,
#  2.2545089595582706,
#  4.863928226768842,
#  4.9775385894459,
#  1.2635273350825265,
#  3.817215488423222,
#  0.8784710986055692,
#  3.010835041739748,
#  1.3260476920638604,
#  1.5716182791655144,
#  4.066887715989061,
#  1.7396100104046441,
#  0.6208763185371133,
#  1.0837342246419306,
#  1.7643026229950158,
#  2.035455393495586,
#  2.068791813763178,
#  3.949104680332678,
#  2.4327571909645895,
#  5.453182077108952,
#  1.7274886498722994,
#  6.1463292576688975,
#  1.9122227530716378,
#  6.1463292576688975,
#  3.373740535429116,
#  0.5115396544996478,
#  4.200419108613584,
#  3.949104680332678,
#  4.354569788440842,
#  2.712342053183751,
#  3.2018902785024568,
#  6.1463292576688975,
#  1.9566745156424719,
#  1.828841144132587,
#  0.8331232786271101,
#  3.010835041739748,
#  0.8530244329444049,
#  3.953049737727117,
#  2.5909811961794835,
#  3.150596984114906,
#  2.680593354869171,
#  1.6137297645156414,
#  5.453182077108952,
#  1.3423082129356407,
#  1.9719419877732602,
#  3.9994500440423195,
#  4.200419108613584,
#  0.9147897981390058,
#  2.1389960724364263,
#  2.0031945312773645,
#  6.508024595212968,
#  1.9004709140742926,
#  0.5044221867307838,
#  14.092011646191084,
#  5.453182077108952,
#  1.6576928879367574,
#  4.539404313999759,
#  2.5909811961794835,
#  3.1018068199454745,
#  4.066887715989061,
#  3.2018902785024568,
#  3.783009331488886,
#  1.5512094075343075,
#  3.591127187484768,
#  5.512815260763211,
#  6.1463292576688975,
#  1.581981066201061,
#  2.6498216962024173,
#  1.6137297645156414,
#  5.498298579110691,
#  2.019194872623806,
#  3.150596984114906,
#  3.010835041739748,
#  3.8437441646748516,
#  2.7790334276824233,
#  2.575880374436533,
#  1.7396100104046441,
#  3.373740535429116,
#  5.0477169690007875,
#  5.72793942673069,
#  3.8437441646748516,
#  2.680593354869171,
#  0.1760041482757966,
#  7.745530434597822,
#  4.764727381962915,
#  2.562810319212787,
#  1.0403837837683165,
#  4.306320298023537,
#  3.0552868043105814,
#  1.302142171210306,
#  1.869663138652842,
#  2.103277989834347,
#  7.86650962391046,
#  5.0477169690007875,
#  6.06380328055015,
#  4.066887715989061,
#  1.2787948072133148,
#  1.2865168533072253,
#  1.0800299526095167,
#  3.516205751006616,
#  7.080173346429272,
#  3.8437441646748516,
#  7.111927770919209,
#  3.4322169175126622,
#  4.200419108613584,
#  2.8504923916645684,
#  2.745131876006742,
#  4.066887715989061,
#  2.9274534328006965,
#  2.8141247474936932,
#  5.512815260763211,
#  2.5909811961794835,
#  3.8437441646748516,
#  3.150596984114906,
#  1.1952527513136546,
#  3.783009331488886,
#  2.8504923916645684,
#  1.7518801029964586,
#  2.358112223806042,
#  4.119015978868627,
#  4.7426315987834045,
#  1.6354697511520473,
#  9.446480153264448,
#  0.9368431048274763,
#  2.9274534328006965,
#  3.9614001915172765,
#  3.5072719280536386,
#  2.619968733052736,
#  2.5354113450246727,
#  4.956609525967033,
#  2.680593354869171,
#  3.00852174140695,
#  5.09778686205274,
#  1.7036780011785808,
#  3.150596984114906,
#  0.7573707905837576,
#  2.498402546748363,
#  3.5813799002073603,
#  1.5019383585275246,
#  5.453182077108952,
#  3.4382790565666874,
#  7.251715186116206,
#  2.7141733023620276,
#  4.536891345234797,
#  4.0747425092183045,
#  0.6288763612041897,
#  6.1463292576688975,
#  2.6165079345945172,
#  3.150596984114906,
#  4.354569788440842,
#  2.7790334276824233,
#  1.7478295346681174,
#  9.23303985893705,
#  4.910053430500353,
#  0.9368431048274763,
#  2.9682754273209517,
#  1.2744347803182385,
#  4.200419108613584,
#  2.4327571909645895,
#  4.760034896549007,
#  3.1018068199454745,
#  7.856359411404528,
#  3.2559574997727325,
#  2.8504923916645684,
#  4.354569788440842,
#  1.0711554424350704,
#  6.1463292576688975,
#  1.624540680619857,
#  2.300711907169755,
#  3.150596984114906,
#  5.0477169690007875,
#  3.5072719280536386,
#  2.0031945312773645,
#  1.5116002694392616,
#  1.9268215524927905,
#  2.3851291419753347,
#  2.2315942622429517,
#  1.0223652782656383,
#  1.541159071680806,
#  8.059439664458901,
#  2.562810319212787,
#  6.1463292576688975,
#  3.0552868043105814,
#  0.37177771212448896,
#  2.9274534328006965,
#  2.619968733052736,
#  0.7436623995109133,
#  1.7925906625893737,
#  6.1463292576688975,
#  2.7790334276824233,
#  1.7709392275974654,
#  1.1905022000676366,
#  0.7992217269514287,
#  2.4574498035549612,
#  4.339215066285064,
#  1.6465195873386322,
#  2.3176878611798024,
#  1.1905022000676366,
#  3.2559574997727325,
#  1.6689924431906908,
#  4.413965035951521,
#  2.448034974796385,
#  6.1463292576688975,
#  4.536891345234797,
#  2.3851291419753347,
#  5.453182077108952,
#  2.2751282467610063,
#  1.129049420853973,
#  2.9682754273209517,
#  0.6400236228222337,
#  3.661422607880897,
#  1.7901675575112743,
#  4.200419108613584,
#  2.4327571909645895,
#  4.066887715989061,
#  6.1463292576688975,
#  4.863928226768842,
#  1.197569367290729,
#  4.200419108613584,
#  5.760967489002291,
#  1.4358089425325926,
#  2.165187822347923,
#  2.6498216962024173,
#  1.6919819614153895,
#  1.4828901635568301,
#  2.2961816559588386,
#  4.009979488336521,
#  2.284924160997782,
#  1.4367990563565631,
#  2.7505864730964458,
#  2.2545089595582706,
#  6.1463292576688975,
#  4.066887715989061,
#  2.8882327196474153,
#  0.7302288554644771,
#  0.5028722940687481,
#  1.7274886498722994,
#  4.536891345234797,
#  0.7950603583717047,
#  6.1463292576688975,
#  3.0923060954998527,
#  3.0552868043105814,
#  4.4865381339116945,
#  3.661422607880897,
#  1.6804211390143138,
#  3.2376745629658203,
#  1.2787948072133148,
#  1.9268215524927905,
#  0.9758452626307454,
#  5.9057567769353065,
#  7.251715186116206,
#  3.1422607473279984,
#  2.562810319212787,
#  2.2145036249445713,
#  1.3756446332032326,
#  0.5126592992417393,
#  2.035455393495586,
#  8.546527754328277,
#  1.197569367290729,
#  2.7790334276824233,
#  6.1463292576688975,
#  2.234306252240751,
#  1.9122227530716378,
#  3.010835041739748,
#  3.8437441646748516,
#  1.1029041407496507,
#  2.562810319212787,
#  4.354569788440842,
#  2.562810319212787,
#  6.1463292576688975,
#  3.887773496840174,
#  5.453182077108952,
#  6.1463292576688975,
#  2.562810319212787,
#  1.057994067764805,
#  1.5312087408276378,
#  0.6369409210409201,
#  3.5072719280536386,
#  3.68435149398447,
#  0.7992217269514287,
#  3.748433984870527,
#  3.8437441646748516,
#  2.9985494236230643,
#  2.4827676115392507,
#  3.2018902785024568,
#  1.057994067764805,
#  5.421271497508733,
#  5.453182077108952,
#  2.085886247122478,
#  9.172305025751083,
#  4.647912296126049,
#  6.1463292576688975,
#  3.9994500440423195,
#  3.748433984870527,
#  1.7821712624425703,
#  6.686415455241358,
#  6.1463292576688975,
#  5.453182077108952,
#  2.4827676115392507,
#  2.4827676115392507,
#  6.1463292576688975,
#  9.423726230150038,
#  1.9268215524927905,
#  2.8141247474936932,
#  3.150596984114906,
#  7.415558921385711,
#  4.760034896549007,
#  1.3756446332032326,
#  1.204686835059593,
#  14.172724045391412,
#  2.2145036249445713,
#  3.748433984870527,
#  2.408659639385529,
#  2.7790334276824233,
#  9.23303985893705,
#  3.28747659977217,
#  1.6804211390143138,
#  4.536891345234797,
#  0.3811381548840527,
#  1.7518801029964586,
#  4.377466510975038,
#  6.1463292576688975,
#  3.3131159136126813,
#  2.8882327196474153,
#  3.5072719280536386,
#  1.7896204309793056,
#  0.7527017113165357,
#  3.5813799002073603,
#  1.5512094075343075,
#  3.661422607880897,
#  5.0477169690007875,
#  1.3588375148868512,
#  4.536891345234797,
#  1.5006841145831535,
#  6.8329924204041514,
#  3.150596984114906,
#  3.150596984114906,
#  4.354569788440842,
#  5.938327576441062,
#  0.4492357711634928,
#  3.5813799002073603,
#  5.453182077108952,
#  1.5924523660683565,
#  3.949104680332678,
#  2.191575413054961,
#  3.150596984114906,
#  6.8329924204041514,
#  1.7643026229950158,
#  0.2885929190634896,
#  3.0552868043105814,
#  0.9368431048274763,
#  10.406640053415195,
#  0.9245160199148028,
#  6.1463292576688975,
#  3.748433984870527,
#  3.33878801682607,
#  6.8858394699807555,
#  4.760034896549007,
#  5.453182077108952,
#  1.3341449022964798,
#  3.373740535429116,
#  1.1093766552552682,
#  3.8437441646748516,
#  1.7745722778496986,
#  3.3131159136126813,
#  1.8422641644647275,
#  3.2826930311177143,
#  1.452825640346629,
#  1.0377393816683493,
#  1.828841144132587,
#  3.748433984870527,
#  3.5072719280536386,
#  2.362139623750636,
#  1.8558698165205063,
#  3.748433984870527,
#  1.8978340156195384,
#  1.492368907511374,
#  4.536891345234797,
#  2.745131876006742,
#  1.2253279960708745,
#  2.5909811961794835,
#  1.5019383585275246,
#  1.2190755725116926,
#  6.412562685300048,
#  0.7663135357378572,
#  1.4013971293056473,
#  0.9988347808554442,
#  3.2559574997727325,
#  1.2559801294471435,
#  4.200419108613584,
#  0.35943187630218965,
#  1.5512094075343075,
#  5.421271497508733,
#  1.9004709140742926,
#  5.025727170893837,
#  2.4327571909645895,
#  4.536891345234797,
#  3.010835041739748,
#  0.8940558296222674,
#  3.2559574997727325,
#  1.9566745156424719,
#  2.9248925369805905,
#  1.9874461743092255,
#  4.066887715989061,
#  2.5593617343347397,
#  1.3927390665625325,
#  1.7444821046760317,
#  1.5716182791655144,
#  5.530685473969383,
#  0.7897429829968848,
#  2.4827676115392507,
#  2.085886247122478,
#  1.8422641644647275,
#  0.6409977217365346,
#  1.0715937166278011,
#  3.010835041739748,
#  2.4827676115392507,
#  2.7790334276824233,
#  2.3396667678985774,
#  3.33878801682607,
#  2.5909811961794835,
#  2.9228193199962837,
#  3.2376745629658203,
#  4.078215277354143,
#  2.745131876006742,
#  4.013014168266904,
#  0.4799025695564652,
#  2.5087430979425114,
#  0.6824974526432873,
#  3.748433984870527,
#  1.2190755725116926,
#  4.371263872718574,
#  4.354569788440842,
#  4.066887715989061,
#  1.3212528926286566,
#  0.44254678301269623,
#  3.9994500440423195,
#  1.3756446332032326,
#  0.6532678143283489,
#  1.7274886498722994,
#  4.200419108613584,
#  1.7396100104046441,
#  3.4382790565666874,
#  4.354569788440842,
#  1.828841144132587,
#  6.1463292576688975,
#  3.5072719280536386,
#  1.0649248926844344,
#  4.77461209694858,
#  3.0300907869850855,
#  2.7790334276824233,
#  5.760967489002291,
#  3.2559574997727325,
#  2.9274534328006965,
#  3.2018902785024568,
#  2.6498216962024173,
#  2.3851291419753347,
#  1.94562418143193,
#  2.5354113450246727,
#  2.5354113450246727,
#  1.6689924431906908,
#  5.0477169690007875,
#  4.066887715989061,
#  5.1056845818460195,
#  3.748433984870527,
#  2.362139623750636,
#  2.660981058285564,
#  4.203690981463232,
#  4.354569788440842,
#  0.8888338856411157,
#  7.76967302175369,
#  4.200419108613584,
#  1.7396100104046441,
#  6.1463292576688975,
#  1.9686605528498515,
#  3.0740711085524395,
#  3.5813799002073603,
#  2.5593617343347397,
#  7.6816247896911145,
#  1.586213261565667,
#  3.150596984114906,
#  2.3851291419753347,
#  3.5072719280536386,
#  12.89876211034429,
#  1.0403837837683165,
#  10.406640053415195,
#  0.998112287892237,
#  3.2559574997727325,
#  4.354569788440842,
#  10.593200860863599,
#  1.9122227530716378,
#  3.5813799002073603,
#  0.9815432837453832,
#  5.0477169690007875,
#  5.453182077108952,
#  3.373740535429116,
#  0.8282092638246809,
#  4.247671303030586,
#  1.0283354452521423,
#  1.3505387120721561,
#  1.6048194617782165,
#  9.138553669884843,
#  1.2410544792304679,
#  1.4641980305446778,
#  1.8875121870257163,
#  5.453182077108952,
#  1.7643026229950158,
#  1.624540680619857,
#  1.2190755725116926,
#  3.0300907869850855,
#  1.7643026229950158,
#  1.7396100104046441,
#  4.0098706951981935,
#  0.7850370919594721,
#  6.1463292576688975,
#  5.09778686205274,
#  8.546527754328277,
#  2.2961816559588386,
#  4.536891345234797,
#  3.3131159136126813,
#  5.025727170893837,
#  1.5019383585275246,
#  2.745131876006742,
#  3.150596984114906,
#  4.764727381962915,
#  2.8504923916645684,
#  4.200419108613584,
#  2.8882327196474153,
#  6.1463292576688975,
#  2.5354113450246727,
#  3.949104680332678,
#  4.247671303030586,
#  6.144833465173007,
#  5.3208454054973195,
#  5.453182077108952,
#  4.760034896549007,
#  0.823319278530489,
#  2.1389960724364263,
#  4.818795040209509,
#  1.6919819614153895,
#  1.394000715144546,
#  3.4382790565666874,
#  6.1463292576688975,
#  2.8141247474936932,
#  4.536891345234797,
#  5.5345592745791565,
#  1.8025238358152134,
#  1.6465195873386322,
#  2.5107512995063233,
#  4.200419108613584,
#  1.5924523660683565,
#  1.94562418143193,
#  6.509489909412125,
#  2.4574498035549612,
#  1.046462829844699,
#  3.7827986724589855,
#  2.2961816559588386,
#  2.1760373441167755,
#  4.435992673523452,
#  4.536891345234797,
#  2.3851291419753347,
#  0.5079745883351516,
#  5.0477169690007875,
#  6.1463292576688975,
#  5.453182077108952,
#  2.059671582626451,
#  2.358112223806042,
#  3.748433984870527,
#  4.647912296126049,
#  2.388211438383095,
#  1.4735004232069913,
#  8.595961511384381,
#  3.9241866675745927,
#  1.7036780011785808,
#  1.5512094075343075,
#  2.712342053183751,
#  4.200419108613584,
#  3.5813799002073603,
#  1.1093766552552682,
#  1.581981066201061,
#  0.47864946060787944,
#  3.661422607880897,
#  1.4735004232069913,
#  0.32032915028844705,
#  2.157345211104623,
#  3.748433984870527,
#  8.546527754328277,
#  2.8504923916645684,
#  3.8437441646748516,
#  0.5479072986705226,
#  2.6498216962024173,
#  4.536891345234797,
#  3.949104680332678,
#  5.453182077108952,
#  6.1463292576688975,
#  0.8843506693943283,
#  1.0715937166278011,
#  5.72793942673069,
#  1.9416366382779313,
#  2.619968733052736,
#  0.9645457073768122,
#  7.215614679981046,
#  6.7222646400128525,
#  0.6937788418600134,
#  5.437464978010263,
#  1.0283354452521423,
#  4.200419108613584,
#  3.150596984114906,
#  1.1224487368226208,
#  3.8437441646748516,
#  5.0477169690007875,
#  4.354569788440842,
#  1.5512094075343075,
#  2.7790334276824233,
#  1.9122227530716378,
#  6.1463292576688975,
#  4.536891345234797,
#  2.9872240117785274,
#  2.745131876006742,
#  0.7664319041284379,
#  0.4492357711634928,
#  3.2559574997727325,
#  4.066887715989061,
#  2.5354113450246727,
#  2.0031945312773645,
#  2.408659639385529,
#  3.0552868043105814,
#  1.7518801029964586,
#  6.508024595212968,
#  5.0477169690007875,
#  2.745131876006742,
#  4.435992673523452,
#  7.37292755985013,
#  2.4574498035549612,
#  0.529558160002326,
#  2.103277989834347,
#  3.373740535429116,
#  3.373740535429116,
#  1.2591120768231583,
#  1.7155124588255837,
#  1.6465195873386322,
#  5.712239275502609,
#  3.8437441646748516,
#  1.1772296646365847,
#  2.085886247122478,
#  0.5442104367891965,
#  3.8437441646748516,
#  2.1389960724364263,
#  3.661422607880897,
#  5.210366619483444,
#  2.035455393495586,
#  2.3291688321604735,
#  0.9645457073768122,
#  0.7850370919594721,
#  3.887773496840174,
#  3.8947512031181653,
#  4.538639081024462,
#  1.7643026229950158,
#  4.386912507195127,
#  1.738090138651244,
#  1.2213118733802588,
#  3.748433984870527,
#  7.718192480907646,
#  0.3357413816120795,
#  4.536891345234797,
#  2.8882327196474153,
#  1.052579056862135,
#  1.046462829844699,
#  2.3396667678985774,
#  4.200419108613584,
#  3.3131159136126813,
#  1.6465195873386322,
#  2.9274534328006965,
#  1.9686605528498515,
#  1.5613617789983254,
#  3.748433984870527,
#  0.9988347808554442,
#  2.6498216962024173,
#  2.1760373441167755,
#  3.3372961915025483,
#  2.5909811961794835,
#  5.821512490604196,
#  2.5117634680230054,
#  5.924614351387214,
#  2.19508553908747,
#  6.4620840872021725,
#  4.066887715989061,
#  3.4382790565666874,
#  3.949104680332678,
#  2.362139623750636,
#  1.162722635960561,
#  4.354569788440842,
#  1.9891323579251403,
#  2.019194872623806,
#  6.168720455681383,
#  6.1463292576688975,
#  3.5813799002073603,
#  1.034341469312354,
#  1.7274886498722994,
#  2.3176878611798024,
#  4.903863969217242,
#  3.5072719280536386,
#  1.9686605528498515,
#  5.0477169690007875,
#  2.9872240117785274,
#  1.7155124588255837,
#  2.2589036797817084,
#  2.680593354869171,
#  0.5332011512808271,
#  2.7690909980541645,
#  0.7897429829968848,
#  3.1892956379730775,
#  3.5072719280536386,
#  4.760034896549007,
#  2.619968733052736,
#  3.010835041739748,
#  4.760034896549007,
#  2.5909811961794835,
#  2.5107512995063233,
#  3.949104680332678,
#  2.7141733023620276,
#  2.2545089595582706,
#  3.621635169274532,
#  0.6867437435247384,
#  6.1463292576688975,
#  2.6498216962024173,
#  2.019194872623806,
#  2.9274534328006965,
#  5.421271497508733,
#  0.48346638328939495,
#  5.25181547183229,
#  5.210366619483444,
#  2.619968733052736,
#  1.3927390665625325,
#  2.3396667678985774,
#  1.6465195873386322,
#  0.4359022402940277,
#  1.294634277973923,
#  4.760034896549007,
#  3.5072719280536386,
#  3.373740535429116,
#  3.0552868043105814,
#  3.5072719280536386,
#  4.354569788440842,
#  4.354569788440842,
#  3.0300907869850855,
#  5.453182077108952,
#  2.2751282467610063,
#  8.283948759841042,
#  0.7992217269514287,
#  4.200419108613584,
#  1.6532211719338612,
#  4.536891345234797,
#  5.0477169690007875,
#  6.80211392064431,
#  4.536891345234797,
#  5.453182077108952,
#  3.9241866675745927,
#  2.619968733052736,
#  3.810231903474704,
#  4.200419108613584,
#  2.7790334276824233,
#  1.056046892834945,
#  0.26579627126819705,
#  2.601259995422726,
#  4.760034896549007,
#  1.6576928879367574,
#  3.5072719280536386,
#  3.2559574997727325,
#  6.074972860831876,
#  2.0397121182388336,
#  2.8141247474936932,
#  3.5813799002073603,
#  5.0477169690007875,
#  1.3796099464978748,
#  4.536891345234797,
#  2.012450512144355,
#  3.5813799002073603,
#  2.7790334276824233,
#  5.334424400734821,
#  1.4145876276592164,
#  2.5354113450246727,
#  3.010835041739748,
#  3.2018902785024568,
#  1.129049420853973,
#  0.5115396544996478,
#  1.6689924431906908,
#  1.134357006174427,
#  2.3396667678985774,
#  3.0552868043105814,
#  2.234306252240751,
#  1.541159071680806,
#  4.066887715989061,
#  4.013014168266904,
#  3.748433984870527,
#  6.686415455241358,
#  4.354569788440842,
#  1.2865168533072253,
#  1.9122227530716378,
#  2.660981058285564,
#  1.6804211390143138,
#  6.1463292576688975,
#  5.453182077108952,
#  6.1463292576688975,
#  6.719526285432213,
#  4.764727381962915,
#  5.0477169690007875,
#  2.085886247122478,
#  3.8437441646748516,
#  1.3927390665625325,
#  1.6973391050491182,
#  2.2589036797817084,
#  4.915266107542624,
#  3.4382790565666874,
#  6.1463292576688975,
#  4.200419108613584,
#  1.2190755725116926,
#  1.8155959173825662,
#  2.191438692068168,
#  3.2559574997727325,
#  2.7030109706477607,
#  6.1463292576688975,
#  5.157234356525475,
#  3.3131159136126813,
#  8.95774043194552,
#  4.536891345234797,
#  1.4828901635568301,
#  1.5019383585275246,
#  10.406640053415195,
#  1.6354697511520473,
#  5.453182077108952,
#  1.4022801799583864,
#  5.453182077108952,
#  2.362139623750636,
#  2.157345211104623,
#  1.0587329224365132,
#  2.9046150828759965,
#  5.453182077108952,
#  2.5087430979425114,
#  1.6919819614153895,
#  4.200419108613584,
#  3.949104680332678,
#  1.5613617789983254,
#  2.1455483364758603,
#  4.451109585956552,
#  9.989467728386781,
#  3.2376745629658203,
#  2.8504923916645684,
#  3.3199649059698255,
#  4.200419108613584,
#  2.157345211104623,
#  3.5813799002073603,
#  4.200419108613584,
#  4.818393338544384,
#  3.5072719280536386,
#  3.748433984870527,
#  5.453182077108952,
#  2.2181029782672246,
#  5.0477169690007875,
#  8.059439664458901,
#  1.8978340156195384,
#  3.8437441646748516,
#  2.448034974796385,
#  6.143589748579185,
#  3.9241866675745927,
#  2.4574498035549612,
#  1.9874461743092255,
#  5.453182077108952,
#  2.2751282467610063,
#  3.455406239521599,
#  6.1463292576688975,
#  6.199327365371984,
#  1.9268215524927905,
#  2.816984510846866,
#  4.536891345234797,
#  2.3974189008517555,
#  0.8531621704348316,
#  4.354569788440842,
#  3.373740535429116,
#  2.0887922845671585,
#  4.066887715989061,
#  1.2559801294471435,
#  3.949104680332678,
#  1.4367990563565631,
#  3.2559574997727325,
#  2.2751282467610063,
#  0.7803532426470459,
#  1.129049420853973,
#  2.4574498035549612,
#  1.4101308092744018,
#  0.8599209920214052,
#  1.1695955152483228,
#  3.494007503851614,
#  1.1498449900409071,
#  2.0519846954467966,
#  4.4865381339116945,
#  5.9057567769353065,
#  1.4641980305446778,
#  1.5716182791655144,
#  1.5512094075343075,
#  0.942322570592102,
#  2.4574498035549612,
#  3.096497226880114,
#  2.3851291419753347,
#  2.2145036249445713,
#  4.180501611138583,
#  2.1760373441167755,
#  1.1695955152483228,
#  4.760034896549007,
#  3.817215488423222,
#  1.3260476920638604,
#  1.4549813754397536,
#  4.82630315615444,
#  3.661422607880897,
#  3.150596984114906,
#  2.680593354869171,
#  1.828841144132587,
#  4.066887715989061,
#  5.512815260763211,
#  1.445848891876481,
#  3.7166028915938574,
#  3.949104680332678,
#  2.3176878611798024,
#  1.7274886498722994,
#  8.059439664458901,
#  2.575880374436533,
#  2.3694369891177605,
#  3.0552868043105814,
#  1.3841553228711412,
#  5.453182077108952,
#  2.8882327196474153,
#  2.120977566933748,
#  1.2410544792304679,
#  4.536891345234797,
#  2.7790334276824233,
#  2.3435786823763136,
#  1.6030344753988934,
#  1.7643026229950158,
#  4.760034896549007,
#  9.70479122397245,
#  2.4115510235398103,
#  4.92550855433023,
#  3.635267736757551,
#  1.9686605528498515,
#  4.247261259681904,
#  0.942322570592102,
#  6.1463292576688975,
#  3.1656148718069175,
#  6.1463292576688975,
#  3.5813799002073603,
#  6.1463292576688975,
#  3.2018902785024568,
#  3.010835041739748,
#  3.2018902785024568,
#  3.2559574997727325,
#  1.7036780011785808,
#  3.949104680332678,
#  3.4382790565666874,
#  4.760034896549007,
#  1.9416366382779313,
#  3.661422607880897,
#  2.120977566933748,
#  3.4382790565666874,
#  2.035455393495586,
#  1.8155959173825662,
#  3.262392479045305,
#  3.3860119545413747,
#  1.7518801029964586,
#  2.1330936275839827,
#  5.0477169690007875,
#  3.5072719280536386,
#  2.068791813763178,
#  4.354569788440842,
#  1.3371511050281764,
#  3.9290804067396277,
#  0.8904741740095269,
#  1.3260476920638604,
#  1.7518801029964586,
#  2.4327571909645895,
#  5.453182077108952,
#  3.312937939433548,
#  0.9645457073768122,
#  1.748402750502319,
#  1.1765159580928966,
#  1.445848891876481,
#  2.745131876006742,
#  1.3423082129356407,
#  3.591127187484768,
#  5.453182077108952,
#  3.3131159136126813,
#  1.2787948072133148,
#  0.7664319041284379,
#  2.8141247474936932,
#  1.9891323579251403,
#  5.0477169690007875,
#  3.010835041739748,
#  2.7790334276824233,
#  ...]

# %%
#Normalization of doc_vector

norm_doc_vector = []

for item in doc_vector:
    #each doc list
    
    norm = 0.0
    for freq in item:
        norm += (freq*freq)
    
    norm = 1 / np.sqrt(norm)
    
    temp_list = []
    
    for freq in item:
        k = freq * norm
        temp_list.append(k)
        
    norm_doc_vector.append(temp_list)

# %%
norm_doc_vector[0]
# Out:
# [0.05054892988376198,
#  0.05054892988376198,
#  0.013096721574943744,
#  0.052196420706571406,
#  0.018541638519744164,
#  0.04000214706815724,
#  0.0409365067511934,
#  0.010391560879627696,
#  0.03139372298266651,
#  0.007224763286626453,
#  0.02476185102296301,
#  0.010905743737211189,
#  0.01292537689848829,
#  0.03344708904817646,
#  0.014306982388116618,
#  0.005106240192560719,
#  0.00891289793264915,
#  0.014510060532835307,
#  0.016740087888873757,
#  0.01701425484284544,
#  0.03247841227195877,
#  0.020007595999978457,
#  0.04484831627190014,
#  0.014207293325269751,
#  0.05054892988376198,
#  0.015726592217061408,
#  0.05054892988376198,
#  0.027746475436314626,
#  0.004207028462688238,
#  0.03454528420175307,
#  0.03247841227195877,
#  0.035813057465998534,
#  0.022306970960934865,
#  0.026333136478423065,
#  0.05054892988376198,
#  0.016092174491489534,
#  0.015040841270901734,
#  0.006851811614762721,
#  0.02476185102296301,
#  0.007015483623211614,
#  0.03251085739835192,
#  0.021308869298273747,
#  0.02591128775655898,
#  0.02204586182445279,
#  0.013271712155033264,
#  0.04484831627190014,
#  0.011039474277011917,
#  0.016217737953173366,
#  0.03289246497780037,
#  0.03454528420175307,
#  0.00752345724186721,
#  0.01759163200577365,
#  0.01647476658994987,
#  0.05352360167408079,
#  0.01562994219058571,
#  0.004148492649828988,
#  0.11589618433403553,
#  0.04484831627190014,
#  0.01363327574040617,
#  0.03733318225607847,
#  0.021308869298273747,
#  0.025510025395851472,
#  0.03344708904817646,
#  0.026333136478423065,
#  0.03111240309953313,
#  0.012757529297449772,
#  0.02953431695468368,
#  0.04533875430294501,
#  0.05054892988376198,
#  0.01301060301855119,
#  0.021792788103351373,
#  0.013271712155033264,
#  0.045219365527590594,
#  0.016606357349073026,
#  0.02591128775655898,
#  0.02476185102296301,
#  0.03161190136842082,
#  0.022855457296771624,
#  0.02118467641054012,
#  0.014306982388116618,
#  0.027746475436314626,
#  0.04151367107786037,
#  0.04710798857691834,
#  0.03161190136842082,
#  0.02204586182445279,
#  0.0014475015863075914,
#  0.06370115534609737,
#  0.039186294819069205,
#  0.0210771850482351,
#  0.008556373199872049,
#  0.03541624173976837,
#  0.025127433297391134,
#  0.010709138829338187,
#  0.015376571436373264,
#  0.017297877672521465,
#  0.06469611807939524,
#  0.04151367107786037,
#  0.049870215865023146,
#  0.03344708904817646,
#  0.010517124341311527,
#  0.010580632355639464,
#  0.008882433084544367,
#  0.028918144556402306,
#  0.05822909431787773,
#  0.03161190136842082,
#  0.05849025054784024,
#  0.02822739964552602,
#  0.03454528420175307,
#  0.023443153466057177,
#  0.02257664256251922,
#  0.03344708904817646,
#  0.02407610007680333,
#  0.023144056978029397,
#  0.04533875430294501,
#  0.021308869298273747,
#  0.03161190136842082,
#  0.02591128775655898,
#  0.009830053839719348,
#  0.03111240309953313,
#  0.023443153466057177,
#  0.014407894660155577,
#  0.01939369735366607,
#  0.03387580475714596,
#  0.039004573640810766,
#  0.01345050717464378,
#  0.0776901859463379,
#  0.007704829082972154,
#  0.02407610007680333,
#  0.03257953359278287,
#  0.028844670589891232,
#  0.021547269961088994,
#  0.02085184911729812,
#  0.04076438096391865,
#  0.02204586182445279,
#  0.02474282586966899,
#  0.041925458244975226,
#  0.014011468669471509,
#  0.02591128775655898,
#  0.00622880444314949,
#  0.020547479619549967,
#  0.029454152856652684,
#  0.012352312021067173,
#  0.04484831627190014,
#  0.028277256174381055,
#  0.05963989677621448,
#  0.02232203160647332,
#  0.03731251498028265,
#  0.03351168880773231,
#  0.00517203451936815,
#  0.05054892988376198,
#  0.02151880749979341,
#  0.02591128775655898,
#  0.035813057465998534,
#  0.022855457296771624,
#  0.014374581785782107,
#  0.07593480024862845,
#  0.040381492136010416,
#  0.007704829082972154,
#  0.024411830242274866,
#  0.010481266403252719,
#  0.03454528420175307,
#  0.020007595999978457,
#  0.0391477026600383,
#  0.025510025395851472,
#  0.0646126402247672,
#  0.026777798660096937,
#  0.023443153466057177,
#  0.035813057465998534,
#  0.008809446920973468,
#  0.05054892988376198,
#  0.013360623799239336,
#  0.01892162297246804,
#  0.02591128775655898,
#  0.04151367107786037,
#  0.028844670589891232,
#  0.01647476658994987,
#  0.01243177396277997,
#  0.015846656349227155,
#  0.01961589116154106,
#  0.018353182389370993,
#  0.008408184560265958,
#  0.012674872853079657,
#  0.06628282238424292,
#  0.0210771850482351,
#  0.05054892988376198,
#  0.025127433297391134,
#  0.0030575917290922676,
#  0.02407610007680333,
#  0.021547269961088994,
#  0.006116063249160282,
#  0.01474270835726159,
#  0.05054892988376198,
#  0.022855457296771624,
#  0.014564641608246602,
#  0.009790984132943624,
#  0.0065729968805103125,
#  0.020210674144697145,
#  0.0356867764385595,
#  0.013541383756617618,
#  0.019061237411101172,
#  0.009790984132943624,
#  0.026777798660096937,
#  0.013726206073667459,
#  0.03630153865143127,
#  0.020133244267638236,
#  0.05054892988376198,
#  0.03731251498028265,
#  0.01961589116154106,
#  0.04484831627190014,
#  0.018711216630413027,
#  0.009285581298600198,
#  0.024411830242274866,
#  0.005263712352153204,
#  0.0301124438541367,
#  0.01472278014262177,
#  0.03454528420175307,
#  0.020007595999978457,
#  0.03344708904817646,
#  0.05054892988376198,
#  0.04000214706815724,
#  0.009849106261690825,
#  0.03454528420175307,
#  0.047379619518570316,
#  0.0118084473707621,
#  0.017807039426089986,
#  0.021792788103351373,
#  0.013915277549679224,
#  0.012195654960955322,
#  0.018884365067592425,
#  0.03297906172832077,
#  0.018791780648568134,
#  0.011816590311396523,
#  0.02262150251620419,
#  0.018541638519744164,
#  0.05054892988376198,
#  0.03344708904817646,
#  0.023753539244790848,
#  0.006005582465000133,
#  0.004135745949771739,
#  0.014207293325269751,
#  0.03731251498028265,
#  0.006538772757503155,
#  0.05054892988376198,
#  0.025431889091447106,
#  0.025127433297391134,
#  0.036898397733729695,
#  0.0301124438541367,
#  0.013820198490870026,
#  0.026627435272133508,
#  0.010517124341311527,
#  0.015846656349227155,
#  0.008025592461805621,
#  0.04857040238372741,
#  0.05963989677621448,
#  0.02584272848627419,
#  0.0210771850482351,
#  0.01821262476704923,
#  0.011313641230983601,
#  0.0042162366975858545,
#  0.016740087888873757,
#  0.07028875514017224,
#  0.009849106261690825,
#  0.022855457296771624,
#  0.05054892988376198,
#  0.018375486464941495,
#  0.015726592217061408,
#  0.02476185102296301,
#  0.03161190136842082,
#  0.009070556057455543,
#  0.0210771850482351,
#  0.035813057465998534,
#  0.0210771850482351,
#  0.05054892988376198,
#  0.031974009470858836,
#  0.04484831627190014,
#  0.05054892988376198,
#  0.0210771850482351,
#  0.008701204524985478,
#  0.012593038874532309,
#  0.005238359451313775,
#  0.028844670589891232,
#  0.030301016676608932,
#  0.0065729968805103125,
#  0.030828046909252973,
#  0.03161190136842082,
#  0.024660811065172913,
#  0.020418894050751084,
#  0.026333136478423065,
#  0.008701204524985478,
#  0.044585875783742256,
#  0.04484831627190014,
#  0.017154843684909788,
#  0.07543530197974076,
#  0.03822557870123908,
#  0.05054892988376198,
#  0.03289246497780037,
#  0.030828046909252973,
#  0.014657016636988963,
#  0.05499073216733053,
#  0.05054892988376198,
#  0.04484831627190014,
#  0.020418894050751084,
#  0.020418894050751084,
#  0.05054892988376198,
#  0.07750305206270229,
#  0.015846656349227155,
#  0.023144056978029397,
#  0.02591128775655898,
#  0.06098738812248398,
#  0.0391477026600383,
#  0.011313641230983601,
#  0.009907642074550074,
#  0.11655998304004156,
#  0.01821262476704923,
#  0.030828046909252973,
#  0.019809411783989633,
#  0.022855457296771624,
#  0.07593480024862845,
#  0.02703701952332728,
#  0.013820198490870026,
#  0.03731251498028265,
#  0.0031345743222626196,
#  0.014407894660155577,
#  0.036001365767332205,
#  0.05054892988376198,
#  0.027247883572950833,
#  0.023753539244790848,
#  0.028844670589891232,
#  0.014718280438889248,
#  0.006190404782049974,
#  0.029454152856652684,
#  0.012757529297449772,
#  0.0301124438541367,
#  0.04151367107786037,
#  0.011175415338795541,
#  0.03731251498028265,
#  0.012341996809085641,
#  0.05619621733155988,
#  0.02591128775655898,
#  0.02591128775655898,
#  0.035813057465998534,
#  0.04883827268345472,
#  0.0036946259378290596,
#  0.029454152856652684,
#  0.04484831627190014,
#  0.013096721574943744,
#  0.03247841227195877,
#  0.01802405748947915,
#  0.02591128775655898,
#  0.05619621733155988,
#  0.014510060532835307,
#  0.0023734594453248196,
#  0.025127433297391134,
#  0.007704829082972154,
#  0.08558677811301396,
#  0.007603448092010039,
#  0.05054892988376198,
#  0.030828046909252973,
#  0.027459017290475504,
#  0.05663084451985741,
#  0.0391477026600383,
#  0.04484831627190014,
#  0.010972337194076856,
#  0.027746475436314626,
#  0.009123787615382229,
#  0.03161190136842082,
#  0.014594520710840265,
#  0.027247883572950833,
#  0.015151235505436287,
#  0.026997678273229665,
#  0.011948396896502464,
#  0.00853462498386671,
#  0.015040841270901734,
#  0.030828046909252973,
#  0.028844670589891232,
#  0.019426819685529294,
#  0.015263131748373859,
#  0.030828046909252973,
#  0.015608255686411913,
#  0.012273610492372149,
#  0.03731251498028265,
#  0.02257664256251922,
#  0.010077400080822982,
#  0.021308869298273747,
#  0.012352312021067173,
#  0.010025978605199572,
#  0.052738499349024366,
#  0.006302351788046269,
#  0.011525436119483689,
#  0.008214663937817389,
#  0.026777798660096937,
#  0.01032949079641416,
#  0.03454528420175307,
#  0.002956056526018143,
#  0.012757529297449772,
#  0.044585875783742256,
#  0.01562994219058571,
#  0.041332821547015695,
#  0.020007595999978457,
#  0.03731251498028265,
#  0.02476185102296301,
#  0.007352935963747097,
#  0.026777798660096937,
#  0.016092174491489534,
#  0.02405503863706861,
#  0.01634524821259095,
#  0.03344708904817646,
#  0.02104882303443945,
#  0.011454230073047949,
#  0.014347051694752633,
#  0.01292537689848829,
#  0.045485723350078236,
#  0.006495041349093486,
#  0.020418894050751084,
#  0.017154843684909788,
#  0.015151235505436287,
#  0.005271723582215019,
#  0.00881305139618289,
#  0.02476185102296301,
#  0.020418894050751084,
#  0.022855457296771624,
#  0.019241997368479452,
#  0.027459017290475504,
#  0.021308869298273747,
#  0.02403798798853025,
#  0.026627435272133508,
#  0.03354024971061301,
#  0.02257664256251922,
#  0.033004019685597324,
#  0.003946837262139687,
#  0.020632522866561226,
#  0.005613027619121764,
#  0.030828046909252973,
#  0.010025978605199572,
#  0.0359503537383347,
#  0.035813057465998534,
#  0.03344708904817646,
#  0.010866310122398835,
#  0.0036396140471780586,
#  0.03289246497780037,
#  0.011313641230983601,
#  0.005372635854253976,
#  0.014207293325269751,
#  0.03454528420175307,
#  0.014306982388116618,
#  0.028277256174381055,
#  0.035813057465998534,
#  0.015040841270901734,
#  0.05054892988376198,
#  0.028844670589891232,
#  0.008758205340954105,
#  0.03926758915651588,
#  0.024920215027795924,
#  0.022855457296771624,
#  0.047379619518570316,
#  0.026777798660096937,
#  0.02407610007680333,
#  0.026333136478423065,
#  0.021792788103351373,
#  0.01961589116154106,
#  0.01600129381364367,
#  0.02085184911729812,
#  0.02085184911729812,
#  0.013726206073667459,
#  0.04151367107786037,
#  0.03344708904817646,
#  0.04199041104319605,
#  0.030828046909252973,
#  0.019426819685529294,
#  0.0218845654533501,
#  0.03457219289218144,
#  0.035813057465998534,
#  0.007309989406689352,
#  0.0638997099457931,
#  0.03454528420175307,
#  0.014306982388116618,
#  0.05054892988376198,
#  0.01619075062188867,
#  0.02528192005497123,
#  0.029454152856652684,
#  0.02104882303443945,
#  0.06317557953846631,
#  0.013045409638530573,
#  0.02591128775655898,
#  0.01961589116154106,
#  0.028844670589891232,
#  0.10608260543308554,
#  0.008556373199872049,
#  0.08558677811301396,
#  0.008208721977240983,
#  0.026777798660096937,
#  0.035813057465998534,
#  0.08712110027172369,
#  0.015726592217061408,
#  0.029454152856652684,
#  0.008072454394794428,
#  0.04151367107786037,
#  0.04484831627190014,
#  0.027746475436314626,
#  0.006811397543325556,
#  0.03493389791935674,
#  0.008457284688121718,
#  0.011107163934743966,
#  0.013198431624584102,
#  0.07515772249292173,
#  0.010206738562577854,
#  0.012041926242333504,
#  0.015523366418689993,
#  0.04484831627190014,
#  0.014510060532835307,
#  0.013360623799239336,
#  0.010025978605199572,
#  0.024920215027795924,
#  0.014510060532835307,
#  0.014306982388116618,
#  0.03297816698668058,
#  0.00645633893890386,
#  0.05054892988376198,
#  0.041925458244975226,
#  0.07028875514017224,
#  0.018884365067592425,
#  0.03731251498028265,
#  0.027247883572950833,
#  0.041332821547015695,
#  0.012352312021067173,
#  0.02257664256251922,
#  0.02591128775655898,
#  0.039186294819069205,
#  0.023443153466057177,
#  0.03454528420175307,
#  0.023753539244790848,
#  0.05054892988376198,
#  0.02085184911729812,
#  0.03247841227195877,
#  0.03493389791935674,
#  0.05053662811683319,
#  0.043759946799015126,
#  0.04484831627190014,
#  0.0391477026600383,
#  0.006771181096499133,
#  0.01759163200577365,
#  0.03963096059454425,
#  0.013915277549679224,
#  0.011464606182598307,
#  0.028277256174381055,
#  0.05054892988376198,
#  0.023144056978029397,
#  0.03731251498028265,
#  0.04551758244307473,
#  0.014824401227244065,
#  0.013541383756617618,
#  0.020649038812223415,
#  0.03454528420175307,
#  0.013096721574943744,
#  0.01600129381364367,
#  0.05353565277996947,
#  0.020210674144697145,
#  0.00860636877625478,
#  0.031110670587641005,
#  0.018884365067592425,
#  0.01789626857281716,
#  0.036482699383381834,
#  0.03731251498028265,
#  0.01961589116154106,
#  0.00417770847802337,
#  0.04151367107786037,
#  0.05054892988376198,
#  0.04484831627190014,
#  0.01693924780939065,
#  0.01939369735366607,
#  0.030828046909252973,
#  0.03822557870123908,
#  0.019641240728488267,
#  0.0121184314171664,
#  0.07069531056773938,
#  0.032273480380589706,
#  0.014011468669471509,
#  0.012757529297449772,
#  0.022306970960934865,
#  0.03454528420175307,
#  0.029454152856652684,
#  0.009123787615382229,
#  0.01301060301855119,
#  0.003936531384643824,
#  0.0301124438541367,
#  0.0121184314171664,
#  0.0026344660493826154,
#  0.017742539854195338,
#  0.030828046909252973,
#  0.07028875514017224,
#  0.023443153466057177,
#  0.03161190136842082,
#  0.0045061249507160174,
#  0.021792788103351373,
#  0.03731251498028265,
#  0.03247841227195877,
#  0.04484831627190014,
#  0.05054892988376198,
#  0.007273118328975798,
#  0.00881305139618289,
#  0.04710798857691834,
#  0.015968499273870448,
#  0.021547269961088994,
#  0.007932662128544335,
#  0.059342997297372274,
#  0.05528556471720463,
#  0.005705808550406268,
#  0.04471905496697989,
#  0.008457284688121718,
#  0.03454528420175307,
#  0.02591128775655898,
#  0.009231295642837553,
#  0.03161190136842082,
#  0.04151367107786037,
#  0.035813057465998534,
#  0.012757529297449772,
#  0.022855457296771624,
#  0.015726592217061408,
#  0.05054892988376198,
#  0.03731251498028265,
#  0.024567668080924237,
#  0.02257664256251922,
#  0.006303325278925959,
#  0.0036946259378290596,
#  0.026777798660096937,
#  0.03344708904817646,
#  0.02085184911729812,
#  0.01647476658994987,
#  0.019809411783989633,
#  0.025127433297391134,
#  0.014407894660155577,
#  0.05352360167408079,
#  0.04151367107786037,
#  0.02257664256251922,
#  0.036482699383381834,
#  0.06063677727578672,
#  0.020210674144697145,
#  0.004355217102294328,
#  0.017297877672521465,
#  0.027746475436314626,
#  0.027746475436314626,
#  0.010355248705187477,
#  0.014108798172127797,
#  0.013541383756617618,
#  0.04697886665547189,
#  0.03161190136842082,
#  0.009681827523403568,
#  0.017154843684909788,
#  0.004475721045523997,
#  0.03161190136842082,
#  0.01759163200577365,
#  0.0301124438541367,
#  0.04285134197591839,
#  0.016740087888873757,
#  0.019155659752106636,
#  0.007932662128544335,
#  0.00645633893890386,
#  0.031974009470858836,
#  0.03203139585069775,
#  0.03732688879108637,
#  0.014510060532835307,
#  0.03607905197329258,
#  0.014294482587426787,
#  0.01004437049588182,
#  0.030828046909252973,
#  0.06347632126280676,
#  0.0027612200464221578,
#  0.03731251498028265,
#  0.023753539244790848,
#  0.00865667013787998,
#  0.00860636877625478,
#  0.019241997368479452,
#  0.03454528420175307,
#  0.027247883572950833,
#  0.013541383756617618,
#  0.02407610007680333,
#  0.01619075062188867,
#  0.012841024907882328,
#  0.030828046909252973,
#  0.008214663937817389,
#  0.021792788103351373,
#  0.01789626857281716,
#  0.02744674815055212,
#  0.021308869298273747,
#  0.04787755656562459,
#  0.020657363136097943,
#  0.0487254917336118,
#  0.018052925632929012,
#  0.053145775589452375,
#  0.03344708904817646,
#  0.028277256174381055,
#  0.03247841227195877,
#  0.019426819685529294,
#  0.009562518136512021,
#  0.035813057465998534,
#  0.016359115803115113,
#  0.016606357349073026,
#  0.05073308062657068,
#  0.05054892988376198,
#  0.029454152856652684,
#  0.008506679713407912,
#  0.014207293325269751,
#  0.019061237411101172,
#  0.04033058847769633,
#  0.028844670589891232,
#  0.01619075062188867,
#  0.04151367107786037,
#  0.024567668080924237,
#  0.014108798172127797,
#  0.018577781784304248,
#  0.02204586182445279,
#  0.0043851779623433305,
#  0.022773688299849434,
#  0.006495041349093486,
#  0.026229555043986174,
#  0.028844670589891232,
#  0.0391477026600383,
#  0.021547269961088994,
#  0.02476185102296301,
#  0.0391477026600383,
#  0.021308869298273747,
#  0.020649038812223415,
#  0.03247841227195877,
#  0.02232203160647332,
#  0.018541638519744164,
#  0.029785222132023753,
#  0.005647950164113104,
#  0.05054892988376198,
#  0.021792788103351373,
#  0.016606357349073026,
#  0.02407610007680333,
#  0.044585875783742256,
#  0.003976146946498019,
#  0.04319222757499853,
#  0.04285134197591839,
#  0.021547269961088994,
#  0.011454230073047949,
#  0.019241997368479452,
#  0.013541383756617618,
#  0.0035849676867383603,
#  0.010647392061003711,
#  0.0391477026600383,
#  0.028844670589891232,
#  0.027746475436314626,
#  0.025127433297391134,
#  0.028844670589891232,
#  0.035813057465998534,
#  0.035813057465998534,
#  0.024920215027795924,
#  0.04484831627190014,
#  0.018711216630413027,
#  0.06812924063568604,
#  0.0065729968805103125,
#  0.03454528420175307,
#  0.0135964992435388,
#  0.03731251498028265,
#  0.04151367107786037,
#  0.05594226492292046,
#  0.03731251498028265,
#  0.04484831627190014,
#  0.032273480380589706,
#  0.021547269961088994,
#  0.03133628825518922,
#  0.03454528420175307,
#  0.022855457296771624,
#  0.008685190477433746,
#  0.0021859741833611434,
#  0.021393404681988772,
#  0.0391477026600383,
#  0.01363327574040617,
#  0.028844670589891232,
#  0.026777798660096937,
#  0.04996207725201076,
#  0.016775096244521545,
#  0.023144056978029397,
#  0.029454152856652684,
#  0.04151367107786037,
#  0.011346252946902972,
#  0.03731251498028265,
#  0.01655089006271488,
#  0.029454152856652684,
#  0.022855457296771624,
#  0.04387162380969527,
#  0.011633918035836365,
#  0.02085184911729812,
#  0.02476185102296301,
#  0.026333136478423065,
#  0.009285581298600198,
#  0.004207028462688238,
#  0.013726206073667459,
#  0.009329232191184736,
#  0.019241997368479452,
#  0.025127433297391134,
#  0.018375486464941495,
#  0.012674872853079657,
#  0.03344708904817646,
#  0.033004019685597324,
#  0.030828046909252973,
#  0.05499073216733053,
#  0.035813057465998534,
#  0.010580632355639464,
#  0.015726592217061408,
#  0.0218845654533501,
#  0.013820198490870026,
#  0.05054892988376198,
#  0.04484831627190014,
#  0.05054892988376198,
#  0.05526304381279312,
#  0.039186294819069205,
#  0.04151367107786037,
#  0.017154843684909788,
#  0.03161190136842082,
#  0.011454230073047949,
#  0.013959336022072437,
#  0.018577781784304248,
#  0.04042436247947398,
#  0.028277256174381055,
#  0.05054892988376198,
#  0.03454528420175307,
#  0.010025978605199572,
#  0.01493190925469939,
#  0.01802293306231534,
#  0.026777798660096937,
#  0.022230229833494798,
#  0.05054892988376198,
#  0.04241436912232827,
#  0.027247883572950833,
#  0.07367066976543456,
#  0.03731251498028265,
#  0.012195654960955322,
#  0.012352312021067173,
#  0.08558677811301396,
#  0.01345050717464378,
#  0.04484831627190014,
#  0.011532698546154603,
#  0.04484831627190014,
#  0.019426819685529294,
#  0.017742539854195338,
#  0.008707281048293738,
#  0.02388827184622749,
#  0.04484831627190014,
#  0.020632522866561226,
#  0.013915277549679224,
#  0.03454528420175307,
#  0.03247841227195877,
#  0.012841024907882328,
#  0.017645519443563608,
#  0.03660702460492546,
#  0.08215584987548163,
#  0.026627435272133508,
#  0.023443153466057177,
#  0.02730421137771393,
#  0.03454528420175307,
#  0.017742539854195338,
#  0.029454152856652684,
#  0.03454528420175307,
#  0.03962765690083482,
#  0.028844670589891232,
#  0.030828046909252973,
#  0.04484831627190014,
#  0.018242226737771296,
#  0.04151367107786037,
#  0.06628282238424292,
#  0.015608255686411913,
#  0.03161190136842082,
#  0.020133244267638236,
#  0.0505263994843827,
#  0.032273480380589706,
#  0.020210674144697145,
#  0.01634524821259095,
#  0.04484831627190014,
#  0.018711216630413027,
#  0.028418114357208465,
#  0.05054892988376198,
#  0.050984799411401216,
#  0.015846656349227155,
#  0.02316757637817271,
#  0.03731251498028265,
#  0.019716965173961955,
#  0.00701661641035237,
#  0.035813057465998534,
#  0.027746475436314626,
#  0.017178743654610803,
#  0.03344708904817646,
#  0.01032949079641416,
#  0.03247841227195877,
#  0.011816590311396523,
#  0.026777798660096937,
#  0.018711216630413027,
#  0.006417817805304562,
#  0.009285581298600198,
#  0.020210674144697145,
#  0.011597264060659628,
#  0.007072202628427212,
#  0.009619042393292303,
#  0.028735580689102074,
#  0.009456609195846616,
#  0.01687602895065738,
#  0.036898397733729695,
#  0.04857040238372741,
#  0.012041926242333504,
#  0.01292537689848829,
#  0.012757529297449772,
#  0.007749893562781943,
#  0.020210674144697145,
#  0.025466357991076934,
#  0.01961589116154106,
#  0.01821262476704923,
#  0.03438147778313864,
#  0.01789626857281716,
#  0.009619042393292303,
#  0.0391477026600383,
#  0.03139372298266651,
#  0.010905743737211189,
#  0.011966126194348711,
#  0.03969270919448882,
#  0.0301124438541367,
#  0.02591128775655898,
#  0.02204586182445279,
#  0.015040841270901734,
#  0.03344708904817646,
#  0.04533875430294501,
#  0.011891018393911811,
#  0.030566260136252122,
#  0.03247841227195877,
#  0.019061237411101172,
#  0.014207293325269751,
#  0.06628282238424292,
#  0.02118467641054012,
#  0.019486835020669162,
#  0.025127433297391134,
#  0.011383635244849486,
#  0.04484831627190014,
#  0.023753539244790848,
#  0.017443443366167558,
#  0.010206738562577854,
#  0.03731251498028265,
#  0.022855457296771624,
#  0.01927416991933973,
#  0.013183751455730587,
#  0.014510060532835307,
#  0.0391477026600383,
#  0.07981459999153835,
#  0.01983319124141122,
#  0.04050859889161524,
#  0.02989733973408273,
#  0.01619075062188867,
#  0.03493052562158146,
#  0.007749893562781943,
#  0.05054892988376198,
#  0.02603479857417398,
#  0.05054892988376198,
#  0.029454152856652684,
#  0.05054892988376198,
#  0.026333136478423065,
#  0.02476185102296301,
#  0.026333136478423065,
#  0.026777798660096937,
#  0.014011468669471509,
#  0.03247841227195877,
#  0.028277256174381055,
#  0.0391477026600383,
#  0.015968499273870448,
#  0.0301124438541367,
#  0.017443443366167558,
#  0.028277256174381055,
#  0.016740087888873757,
#  0.01493190925469939,
#  0.026830721518996316,
#  0.027847398617985353,
#  0.014407894660155577,
#  0.017543088841474947,
#  0.04151367107786037,
#  0.028844670589891232,
#  0.01701425484284544,
#  0.035813057465998534,
#  0.010997060947837898,
#  0.032313727700177104,
#  0.007323479543362475,
#  0.010905743737211189,
#  0.014407894660155577,
#  0.020007595999978457,
#  0.04484831627190014,
#  0.027246419869344177,
#  0.007932662128544335,
#  0.01437929605437993,
#  0.009675957824511425,
#  0.011891018393911811,
#  0.02257664256251922,
#  0.011039474277011917,
#  0.02953431695468368,
#  0.04484831627190014,
#  0.027247883572950833,
#  0.010517124341311527,
#  0.006303325278925959,
#  0.023144056978029397,
#  0.016359115803115113,
#  0.04151367107786037,
#  0.02476185102296301,
#  0.022855457296771624,
#  ...]

# %%
#Normalization of query_vector

norm_query_vector = []

normal = 0.0
for item in query_vector:
    normal += (item*item)
    
normal = 1/np.sqrt(normal)
for item in query_vector:
    norm_query_vector.append(item * normal)

# %%
cosine_scores = {}

doc_id = -1
for item in norm_doc_vector:
    
    doc_id += 1
    list_doc = np.array(item)
    list_query = np.array(norm_query_vector)
    score = sum(list(list_doc * list_query))
    
    cosine_scores[doc_id] = score

# %%
cosine_scores
# Out:
# {0: 0.00047832613689488405,
#  1: 0.0003383339724637496,
#  2: 0.00032344600776347093,
#  3: 0.00023212307742751038,
#  4: 0.00045830081444057615,
#  5: 0.00018086641464395804,
#  6: 0.0004356827433236808,
#  7: 0.0,
#  8: 0.0005185780265533383,
#  9: 0.00047880486741403084,
#  10: 0.0,
#  11: 0.0003979648294628428,
#  12: 0.0005612472161976634,
#  13: 0.00019461131385149492,
#  14: 0.0004855055409953166,
#  15: 0.0012232848162419122,
#  16: 0.00042172553883332986,
#  17: 0.0,
#  18: 0.0005653236445496593,
#  19: 0.00046174736515582364,
#  20: 0.00042924989269658114,
#  21: 0.0003439237783090158,
#  22: 0.00042599260945929026,
#  23: 0.0008434323901176068,
#  24: 0.0006080563602399,
#  25: 0.0007926736347653065,
#  26: 0.0002827200461165116,
#  27: 0.0005286785424562958,
#  28: 0.0,
#  29: 0.0010211473481437127,
#  30: 0.0010211473481437127,
#  31: 0.0004889993858450842,
#  32: 0.0,
#  33: 0.0006529179088901885,
#  34: 0.0003146912866920106,
#  35: 0.0006610909616036403,
#  36: 0.00028271095716248125,
#  37: 0.0008318373368268383,
#  38: 0.001304364915128494,
#  39: 0.000458954868468034,
#  40: 0.0901869298178115,
#  41: 0.0003954696960614185,
#  42: 0.00040364064261800707,
#  43: 0.0,
#  44: 0.0004010908229553068,
#  45: 0.0,
#  46: 0.0,
#  47: 0.00024290374119977112,
#  48: 0.0004985566646093802,
#  49: 0.0007950963662892371,
#  50: 0.00032083697608541124,
#  51: 0.0006041219398619397,
#  52: 0.0,
#  53: 0.0,
#  54: 0.0007659464798278427,
#  55: 0.0,
#  56: 0.0005105876908133947,
#  57: 0.0,
#  58: 0.00038225431746304896,
#  59: 0.0004617041963607962,
#  60: 0.0004620102854121539,
#  61: 0.0002665698833653131,
#  62: 0.0,
#  63: 0.0006983042786681497,
#  64: 0.0,
#  65: 0.0005343428234930615,
#  66: 0.0007036933002676209,
#  67: 0.0,
#  68: 0.0005878452838099865,
#  69: 0.0007405244738713048,
#  70: 0.0,
#  71: 0.0007296253739473412,
#  72: 0.0005433248134253608,
#  73: 0.0003166169361789809,
#  74: 0.0,
#  75: 0.001062385614863217,
#  76: 0.00033827198217361096,
#  77: 0.00030180363131254175,
#  78: 0.000374893039823003,
#  79: 0.00042848109809686557,
#  80: 0.0,
#  81: 0.0006818034067103992,
#  82: 0.00081210398620103,
#  83: 0.0,
#  84: 0.0007211496489328414,
#  85: 0.0,
#  86: 0.001141488167412403,
#  87: 0.0004359301344594162,
#  88: 0.00036224111731320745,
#  89: 0.0008751069309605805,
#  90: 0.0004447104742975154,
#  91: 0.0,
#  92: 0.0003423129955969329,
#  93: 0.00021821620274090807,
#  94: 0.000490918092132517,
#  95: 0.0004558773566007975,
#  96: 0.0009233331429721328,
#  97: 0.0002974083858653074,
#  98: 0.0002520690811367605,
#  99: 0.000260116121801741,
#  100: 0.00036040934091780956,
#  101: 0.0,
#  102: 0.0,
#  103: 0.0,
#  104: 0.0,
#  105: 0.0006518587490393731,
#  106: 0.0005571609692763289,
#  107: 0.00043744680336584084,
#  108: 0.0007484101587486356,
#  109: 0.0001940612128928689,
#  110: 0.000633763638112079,
#  111: 0.0,
#  112: 0.00023498650979478412,
#  113: 0.001062422026378102,
#  114: 0.0005857137301252914,
#  115: 0.0006599091017619496,
#  116: 0.0006456568021622582,
#  117: 0.0,
#  118: 0.00039067049353869746,
#  119: 0.00039067049353869746,
#  120: 0.0004392508721181295,
#  121: 0.0,
#  122: 0.0011070753240241022,
#  123: 0.00036639457839859635,
#  124: 0.0,
#  125: 0.0,
#  126: 0.00022904014962363595,
#  127: 0.0002897916004873743,
#  128: 0.0004359675811387698,
#  129: 0.000300328864781436,
#  130: 0.0,
#  131: 0.0,
#  132: 0.00040045536456426964,
#  133: 0.0,
#  134: 0.00040722546092669286,
#  135: 0.00042810579159233744,
#  136: 0.0,
#  137: 0.000957272519322686,
#  138: 0.0007947748236563351,
#  139: 0.0007947748236563351,
#  140: 0.0,
#  141: 0.0005856119632614901,
#  142: 0.00036160985538781016,
#  143: 0.0007008986246373579,
#  144: 0.0,
#  145: 0.00032608357712290525,
#  146: 0.0,
#  147: 0.0,
#  148: 0.0004452579602057456,
#  149: 0.0007463980899944474,
#  150: 0.00025413242033849346,
#  151: 0.0005795611642894806,
#  152: 0.0,
#  153: 0.0003713312697175929,
#  154: 0.0005438729142838792,
#  155: 0.00043100823568071646,
#  156: 0.0,
#  157: 0.0,
#  158: 0.00024752323603266995,
#  159: 0.0002512505672423901,
#  160: 0.00047998045139366726,
#  161: 0.0,
#  162: 0.0002676348515147222,
#  163: 0.0002682256018822089,
#  164: 0.0,
#  165: 0.000614308639998305,
#  166: 0.0005309151426030166,
#  167: 0.0009300610850361044,
#  168: 0.0,
#  169: 0.0002995897100744324,
#  170: 0.0004932475494376852,
#  171: 0.0005480121490104904,
#  172: 0.0006853811772832855,
#  173: 0.0007902776194686096,
#  174: 0.00039015645049628823,
#  175: 0.0010179935593713331,
#  176: 0.0,
#  177: 0.0006928522880187981,
#  178: 0.0,
#  179: 0.0006084887092253049,
#  180: 0.00036476369508869915,
#  181: 0.0,
#  182: 0.0011188111627321573,
#  183: 0.00042171946238115765,
#  184: 0.0,
#  185: 0.0,
#  186: 0.0,
#  187: 0.0006494306428989482,
#  188: 0.0,
#  189: 0.000523422067566365,
#  190: 0.0002489951099942413,
#  191: 0.0003006889595601692,
#  192: 0.0008154666243577406,
#  193: 0.00046775944017057685,
#  194: 0.0005939334310658361,
#  195: 0.0003400201423368406,
#  196: 0.0,
#  197: 0.0004636808961947,
#  198: 0.0006595545527936206,
#  199: 0.0,
#  200: 0.00047604574283015104,
#  201: 0.0,
#  202: 0.0005319136197003907,
#  203: 0.0005637004682192113,
#  204: 0.0009927487106754123,
#  205: 0.0011074099113986392,
#  206: 0.0002522830515763316,
#  207: 0.0004753991030888897,
#  208: 0.0005986041539494514,
#  209: 0.0,
#  210: 0.0004755303976399966,
#  211: 0.0006401970473929204,
#  212: 0.00022139464220826704,
#  213: 0.0013303902216908877,
#  214: 0.00017444469828701854,
#  215: 0.00039348132069791847,
#  216: 0.0,
#  217: 0.0004666477456526914,
#  218: 0.0011046230000017734,
#  219: 0.00023723048998716323,
#  220: 0.0,
#  221: 0.0004282398512084004,
#  222: 0.0,
#  223: 0.0007880552868984228,
#  224: 0.00032139631672901633,
#  225: 0.00029769639839405697,
#  226: 0.0002804167416567773,
#  227: 0.0005414404216747148,
#  228: 0.0,
#  229: 0.0,
#  230: 0.0,
#  231: 0.0,
#  232: 0.0008658162235089269,
#  233: 0.0,
#  234: 0.0,
#  235: 0.0005359631548599508,
#  236: 0.0003145786595459818,
#  237: 0.0,
#  238: 0.0003358001175845688,
#  239: 0.0008929402958958428,
#  240: 0.00030077470272789087,
#  241: 0.00023930675245696263,
#  242: 0.0004923896210557994,
#  243: 0.0006696695406041,
#  244: 0.0005978110747608518,
#  245: 0.00024629113050089963,
#  246: 0.0007541244929527978,
#  247: 0.0006734033032140482,
#  248: 0.0003677468544151359,
#  249: 0.000421021903676731,
#  250: 0.0,
#  251: 0.0,
#  252: 0.00027677395966984144,
#  253: 0.0,
#  254: 0.0,
#  255: 0.0,
#  256: 0.0006105336680305575,
#  257: 0.00041175960112248993,
#  258: 0.0,
#  259: 0.0,
#  260: 0.0005568338499779167,
#  261: 0.0008856351247068505,
#  262: 0.0,
#  263: 0.0005636839064986745,
#  264: 0.0007324688421265437,
#  265: 0.000462648206073056,
#  266: 0.001621722241306633,
#  267: 0.0,
#  268: 0.0006251393405533776,
#  269: 0.0009801682070008498,
#  270: 0.0004306618702698112,
#  271: 0.0004601074827028115,
#  272: 0.001142798910372172,
#  273: 0.0005561696565646992,
#  274: 0.0,
#  275: 0.00034048554669055737,
#  276: 0.0,
#  277: 0.000570024704375562,
#  278: 0.0004464875559437578,
#  279: 0.0,
#  280: 0.0009484216810695787,
#  281: 0.0,
#  282: 0.0,
#  283: 0.0,
#  284: 0.00040937442538784973,
#  285: 0.0,
#  286: 0.0,
#  287: 0.00025279716148570786,
#  288: 0.0008334890020373341,
#  289: 0.0008665192028613876,
#  290: 0.0005176589505148598,
#  291: 0.0009386831671321931,
#  292: 0.0,
#  293: 0.0,
#  294: 0.0,
#  295: 0.0003966294967577032,
#  296: 0.0005475536706806146,
#  297: 0.00042869110648592206,
#  298: 0.0002679423563009398,
#  299: 0.0002909659825152261,
#  300: 0.0003598774943403326,
#  301: 0.00031097364779641946,
#  302: 0.0,
#  303: 0.0004964425810251638,
#  304: 0.00029028420409005245,
#  305: 0.0010587790635128449,
#  306: 0.0,
#  307: 0.0,
#  308: 0.0,
#  309: 0.0006615372448454608,
#  310: 0.0003089211438343414,
#  311: 0.0013145901979465108,
#  312: 0.0004015889387116465,
#  313: 0.0,
#  314: 0.0003556349246772859,
#  315: 0.0009021878602060924,
#  316: 0.0,
#  317: 0.0,
#  318: 0.0008865602441114102,
#  319: 0.0008865602441114102,
#  320: 0.0005824982101063196,
#  321: 0.0005830355246534219,
#  322: 0.00047453828409387043,
#  323: 0.0,
#  324: 0.0,
#  325: 0.0016479150711191579,
#  326: 0.0,
#  327: 0.0004643100512644265,
#  328: 0.000762743250613265,
#  329: 0.00030050866006820767,
#  330: 0.0,
#  331: 0.00049296954566591,
#  332: 0.0005574919613295842,
#  333: 0.0004930918205766156,
#  334: 0.00030761110771193367,
#  335: 0.0007174464841852332,
#  336: 0.0,
#  337: 0.0008691970772320764,
#  338: 0.0,
#  339: 0.0,
#  340: 0.0008197598578694705,
#  341: 0.00044761451083851926,
#  342: 0.0,
#  343: 0.0010842436578295974,
#  344: 0.0,
#  345: 0.0007452392977551742,
#  346: 0.00037593437734099555,
#  347: 0.0004697399009895914,
#  348: 0.0004039942643466006,
#  349: 0.00023397250947900468,
#  350: 0.0,
#  351: 0.0030447805009004526,
#  352: 0.0,
#  353: 0.0,
#  354: 0.0005666897364057512,
#  355: 0.0,
#  356: 0.0003686971732724513,
#  357: 0.0,
#  358: 0.0,
#  359: 0.0002777646673507023,
#  360: 0.00038785335993177255,
#  361: 0.0,
#  362: 0.0006810815251487497,
#  363: 0.0008005738071361844,
#  364: 0.0007494072768591267,
#  365: 0.0,
#  366: 0.0002955973277936586,
#  367: 0.0004674490950339746,
#  368: 0.00024178434472583416,
#  369: 0.00048096622671010256,
#  370: 0.000525401924401145,
#  371: 0.0,
#  372: 0.0006746005936780242,
#  373: 0.00026507964467433316,
#  374: 0.0,
#  375: 0.00058580465872486,
#  376: 0.0,
#  377: 0.0006014536811443311,
#  378: 0.0002937328656436136,
#  379: 0.00044638737596069733,
#  380: 0.00044502214335753444,
#  381: 0.0,
#  382: 0.00048462517675098405,
#  383: 0.0,
#  384: 0.0,
#  385: 0.0009383160513302838,
#  386: 0.0,
#  387: 0.0,
#  388: 0.00041186374671735906,
#  389: 0.0006892371605567657,
#  390: 0.0,
#  391: 0.0,
#  392: 0.0,
#  393: 0.0007699337401407649,
#  394: 0.0003891774118481219,
#  395: 0.0002590643102747191,
#  396: 0.000900506698682257,
#  397: 0.0,
#  398: 0.00029583615269652925,
#  399: 0.0005134339341378156,
#  400: 0.0,
#  401: 0.0006296922193777277,
#  402: 0.00025537141166222477,
#  403: 0.0010606246875186703,
#  404: 0.0005484795227374241,
#  405: 0.0007041531094665332,
#  406: 0.00031567937050616066,
#  407: 0.0004514216589456248,
#  408: 0.0,
#  409: 0.0,
#  410: 0.0005656318154624532,
#  411: 0.0,
#  412: 0.000436180190426354,
#  413: 0.0006706551179428759,
#  414: 0.0,
#  415: 0.0,
#  416: 0.0,
#  417: 0.0,
#  418: 0.0003489656124985618,
#  419: 0.00026593441142964866,
#  420: 0.0002979720691852907,
#  421: 0.0,
#  422: 0.00043109702125027684,
#  423: 0.0,
#  424: 0.0,
#  425: 0.0,
#  426: 0.00040481705107595393,
#  427: 0.0009269459463359152,
#  428: 0.0,
#  429: 0.0014206029323928118,
#  430: 0.0007920624536136694,
#  431: 0.0006456534092948184,
#  432: 0.0,
#  433: 0.0005058396862253822,
#  434: 0.0005220332700520858,
#  435: 0.00025769336966398614,
#  436: 0.0,
#  437: 0.0,
#  438: 0.0,
#  439: 0.0008687721608795509,
#  440: 0.0,
#  441: 0.00035177780053948567,
#  442: 0.0005058107267131771,
#  443: 0.0,
#  444: 0.0010303433955841537,
#  445: 0.0,
#  446: 0.0,
#  447: 0.0006042447985549902,
#  448: 0.0,
#  449: 0.0,
#  450: 0.000390849584297811,
#  451: 0.0005840913491125974,
#  452: 0.0,
#  453: 0.0004307359907507889,
#  454: 0.0,
#  455: 0.0003525940871809818,
#  456: 0.0005209898719257983,
#  457: 0.0,
#  458: 0.0,
#  459: 0.0002573035233227897,
#  460: 0.0002919680914721975,
#  461: 0.0005220328922964889,
#  462: 0.0004469200706362419,
#  463: 0.0003397901553679817,
#  464: 0.0,
#  465: 0.0,
#  466: 0.0003057482629907979}

# %%
sorted_cosine_scores = dict(sorted(cosine_scores.items(),key=operator.itemgetter(1),reverse=True))

# %%
sorted_cosine_scores
# Out:
# {40: 0.0901869298178115,
#  351: 0.0030447805009004526,
#  325: 0.0016479150711191579,
#  266: 0.001621722241306633,
#  429: 0.0014206029323928118,
#  213: 0.0013303902216908877,
#  311: 0.0013145901979465108,
#  38: 0.001304364915128494,
#  15: 0.0012232848162419122,
#  272: 0.001142798910372172,
#  86: 0.001141488167412403,
#  182: 0.0011188111627321573,
#  205: 0.0011074099113986392,
#  122: 0.0011070753240241022,
#  218: 0.0011046230000017734,
#  343: 0.0010842436578295974,
#  113: 0.001062422026378102,
#  75: 0.001062385614863217,
#  403: 0.0010606246875186703,
#  305: 0.0010587790635128449,
#  444: 0.0010303433955841537,
#  29: 0.0010211473481437127,
#  30: 0.0010211473481437127,
#  175: 0.0010179935593713331,
#  204: 0.0009927487106754123,
#  269: 0.0009801682070008498,
#  137: 0.000957272519322686,
#  280: 0.0009484216810695787,
#  291: 0.0009386831671321931,
#  385: 0.0009383160513302838,
#  167: 0.0009300610850361044,
#  427: 0.0009269459463359152,
#  96: 0.0009233331429721328,
#  315: 0.0009021878602060924,
#  396: 0.000900506698682257,
#  239: 0.0008929402958958428,
#  318: 0.0008865602441114102,
#  319: 0.0008865602441114102,
#  261: 0.0008856351247068505,
#  89: 0.0008751069309605805,
#  337: 0.0008691970772320764,
#  439: 0.0008687721608795509,
#  289: 0.0008665192028613876,
#  232: 0.0008658162235089269,
#  23: 0.0008434323901176068,
#  288: 0.0008334890020373341,
#  37: 0.0008318373368268383,
#  340: 0.0008197598578694705,
#  192: 0.0008154666243577406,
#  82: 0.00081210398620103,
#  363: 0.0008005738071361844,
#  49: 0.0007950963662892371,
#  138: 0.0007947748236563351,
#  139: 0.0007947748236563351,
#  25: 0.0007926736347653065,
#  430: 0.0007920624536136694,
#  173: 0.0007902776194686096,
#  223: 0.0007880552868984228,
#  393: 0.0007699337401407649,
#  54: 0.0007659464798278427,
#  328: 0.000762743250613265,
#  246: 0.0007541244929527978,
#  364: 0.0007494072768591267,
#  108: 0.0007484101587486356,
#  149: 0.0007463980899944474,
#  345: 0.0007452392977551742,
#  69: 0.0007405244738713048,
#  264: 0.0007324688421265437,
#  71: 0.0007296253739473412,
#  84: 0.0007211496489328414,
#  335: 0.0007174464841852332,
#  405: 0.0007041531094665332,
#  66: 0.0007036933002676209,
#  143: 0.0007008986246373579,
#  63: 0.0006983042786681497,
#  177: 0.0006928522880187981,
#  389: 0.0006892371605567657,
#  172: 0.0006853811772832855,
#  81: 0.0006818034067103992,
#  362: 0.0006810815251487497,
#  372: 0.0006746005936780242,
#  247: 0.0006734033032140482,
#  413: 0.0006706551179428759,
#  243: 0.0006696695406041,
#  309: 0.0006615372448454608,
#  35: 0.0006610909616036403,
#  115: 0.0006599091017619496,
#  198: 0.0006595545527936206,
#  33: 0.0006529179088901885,
#  105: 0.0006518587490393731,
#  187: 0.0006494306428989482,
#  116: 0.0006456568021622582,
#  431: 0.0006456534092948184,
#  211: 0.0006401970473929204,
#  110: 0.000633763638112079,
#  401: 0.0006296922193777277,
#  268: 0.0006251393405533776,
#  165: 0.000614308639998305,
#  256: 0.0006105336680305575,
#  179: 0.0006084887092253049,
#  24: 0.0006080563602399,
#  447: 0.0006042447985549902,
#  51: 0.0006041219398619397,
#  377: 0.0006014536811443311,
#  208: 0.0005986041539494514,
#  244: 0.0005978110747608518,
#  194: 0.0005939334310658361,
#  68: 0.0005878452838099865,
#  375: 0.00058580465872486,
#  114: 0.0005857137301252914,
#  141: 0.0005856119632614901,
#  451: 0.0005840913491125974,
#  321: 0.0005830355246534219,
#  320: 0.0005824982101063196,
#  151: 0.0005795611642894806,
#  277: 0.000570024704375562,
#  354: 0.0005666897364057512,
#  410: 0.0005656318154624532,
#  18: 0.0005653236445496593,
#  203: 0.0005637004682192113,
#  263: 0.0005636839064986745,
#  12: 0.0005612472161976634,
#  332: 0.0005574919613295842,
#  106: 0.0005571609692763289,
#  260: 0.0005568338499779167,
#  273: 0.0005561696565646992,
#  404: 0.0005484795227374241,
#  171: 0.0005480121490104904,
#  296: 0.0005475536706806146,
#  154: 0.0005438729142838792,
#  72: 0.0005433248134253608,
#  227: 0.0005414404216747148,
#  235: 0.0005359631548599508,
#  65: 0.0005343428234930615,
#  202: 0.0005319136197003907,
#  166: 0.0005309151426030166,
#  27: 0.0005286785424562958,
#  370: 0.000525401924401145,
#  189: 0.000523422067566365,
#  434: 0.0005220332700520858,
#  461: 0.0005220328922964889,
#  456: 0.0005209898719257983,
#  8: 0.0005185780265533383,
#  290: 0.0005176589505148598,
#  399: 0.0005134339341378156,
#  56: 0.0005105876908133947,
#  433: 0.0005058396862253822,
#  442: 0.0005058107267131771,
#  48: 0.0004985566646093802,
#  303: 0.0004964425810251638,
#  170: 0.0004932475494376852,
#  333: 0.0004930918205766156,
#  331: 0.00049296954566591,
#  242: 0.0004923896210557994,
#  94: 0.000490918092132517,
#  31: 0.0004889993858450842,
#  14: 0.0004855055409953166,
#  382: 0.00048462517675098405,
#  369: 0.00048096622671010256,
#  160: 0.00047998045139366726,
#  9: 0.00047880486741403084,
#  0: 0.00047832613689488405,
#  200: 0.00047604574283015104,
#  210: 0.0004755303976399966,
#  207: 0.0004753991030888897,
#  322: 0.00047453828409387043,
#  347: 0.0004697399009895914,
#  193: 0.00046775944017057685,
#  367: 0.0004674490950339746,
#  217: 0.0004666477456526914,
#  327: 0.0004643100512644265,
#  197: 0.0004636808961947,
#  265: 0.000462648206073056,
#  60: 0.0004620102854121539,
#  19: 0.00046174736515582364,
#  59: 0.0004617041963607962,
#  271: 0.0004601074827028115,
#  39: 0.000458954868468034,
#  4: 0.00045830081444057615,
#  95: 0.0004558773566007975,
#  407: 0.0004514216589456248,
#  341: 0.00044761451083851926,
#  462: 0.0004469200706362419,
#  278: 0.0004464875559437578,
#  379: 0.00044638737596069733,
#  148: 0.0004452579602057456,
#  380: 0.00044502214335753444,
#  90: 0.0004447104742975154,
#  120: 0.0004392508721181295,
#  107: 0.00043744680336584084,
#  412: 0.000436180190426354,
#  128: 0.0004359675811387698,
#  87: 0.0004359301344594162,
#  6: 0.0004356827433236808,
#  422: 0.00043109702125027684,
#  155: 0.00043100823568071646,
#  453: 0.0004307359907507889,
#  270: 0.0004306618702698112,
#  20: 0.00042924989269658114,
#  297: 0.00042869110648592206,
#  79: 0.00042848109809686557,
#  221: 0.0004282398512084004,
#  135: 0.00042810579159233744,
#  22: 0.00042599260945929026,
#  16: 0.00042172553883332986,
#  183: 0.00042171946238115765,
#  249: 0.000421021903676731,
#  388: 0.00041186374671735906,
#  257: 0.00041175960112248993,
#  284: 0.00040937442538784973,
#  134: 0.00040722546092669286,
#  426: 0.00040481705107595393,
#  348: 0.0004039942643466006,
#  42: 0.00040364064261800707,
#  312: 0.0004015889387116465,
#  44: 0.0004010908229553068,
#  132: 0.00040045536456426964,
#  11: 0.0003979648294628428,
#  295: 0.0003966294967577032,
#  41: 0.0003954696960614185,
#  215: 0.00039348132069791847,
#  450: 0.000390849584297811,
#  118: 0.00039067049353869746,
#  119: 0.00039067049353869746,
#  174: 0.00039015645049628823,
#  394: 0.0003891774118481219,
#  360: 0.00038785335993177255,
#  58: 0.00038225431746304896,
#  346: 0.00037593437734099555,
#  78: 0.000374893039823003,
#  153: 0.0003713312697175929,
#  356: 0.0003686971732724513,
#  248: 0.0003677468544151359,
#  123: 0.00036639457839859635,
#  180: 0.00036476369508869915,
#  88: 0.00036224111731320745,
#  142: 0.00036160985538781016,
#  100: 0.00036040934091780956,
#  300: 0.0003598774943403326,
#  314: 0.0003556349246772859,
#  455: 0.0003525940871809818,
#  441: 0.00035177780053948567,
#  418: 0.0003489656124985618,
#  21: 0.0003439237783090158,
#  92: 0.0003423129955969329,
#  275: 0.00034048554669055737,
#  195: 0.0003400201423368406,
#  463: 0.0003397901553679817,
#  1: 0.0003383339724637496,
#  76: 0.00033827198217361096,
#  238: 0.0003358001175845688,
#  145: 0.00032608357712290525,
#  2: 0.00032344600776347093,
#  224: 0.00032139631672901633,
#  50: 0.00032083697608541124,
#  73: 0.0003166169361789809,
#  406: 0.00031567937050616066,
#  34: 0.0003146912866920106,
#  236: 0.0003145786595459818,
#  301: 0.00031097364779641946,
#  310: 0.0003089211438343414,
#  334: 0.00030761110771193367,
#  466: 0.0003057482629907979,
#  77: 0.00030180363131254175,
#  240: 0.00030077470272789087,
#  191: 0.0003006889595601692,
#  329: 0.00030050866006820767,
#  129: 0.000300328864781436,
#  169: 0.0002995897100744324,
#  420: 0.0002979720691852907,
#  225: 0.00029769639839405697,
#  97: 0.0002974083858653074,
#  398: 0.00029583615269652925,
#  366: 0.0002955973277936586,
#  378: 0.0002937328656436136,
#  460: 0.0002919680914721975,
#  299: 0.0002909659825152261,
#  304: 0.00029028420409005245,
#  127: 0.0002897916004873743,
#  26: 0.0002827200461165116,
#  36: 0.00028271095716248125,
#  226: 0.0002804167416567773,
#  359: 0.0002777646673507023,
#  252: 0.00027677395966984144,
#  163: 0.0002682256018822089,
#  298: 0.0002679423563009398,
#  162: 0.0002676348515147222,
#  61: 0.0002665698833653131,
#  419: 0.00026593441142964866,
#  373: 0.00026507964467433316,
#  99: 0.000260116121801741,
#  395: 0.0002590643102747191,
#  435: 0.00025769336966398614,
#  459: 0.0002573035233227897,
#  402: 0.00025537141166222477,
#  150: 0.00025413242033849346,
#  287: 0.00025279716148570786,
#  206: 0.0002522830515763316,
#  98: 0.0002520690811367605,
#  159: 0.0002512505672423901,
#  190: 0.0002489951099942413,
#  158: 0.00024752323603266995,
#  245: 0.00024629113050089963,
#  47: 0.00024290374119977112,
#  368: 0.00024178434472583416,
#  241: 0.00023930675245696263,
#  219: 0.00023723048998716323,
#  112: 0.00023498650979478412,
#  349: 0.00023397250947900468,
#  3: 0.00023212307742751038,
#  126: 0.00022904014962363595,
#  212: 0.00022139464220826704,
#  93: 0.00021821620274090807,
#  13: 0.00019461131385149492,
#  109: 0.0001940612128928689,
#  5: 0.00018086641464395804,
#  214: 0.00017444469828701854,
#  7: 0.0,
#  10: 0.0,
#  17: 0.0,
#  28: 0.0,
#  32: 0.0,
#  43: 0.0,
#  45: 0.0,
#  46: 0.0,
#  52: 0.0,
#  53: 0.0,
#  55: 0.0,
#  57: 0.0,
#  62: 0.0,
#  64: 0.0,
#  67: 0.0,
#  70: 0.0,
#  74: 0.0,
#  80: 0.0,
#  83: 0.0,
#  85: 0.0,
#  91: 0.0,
#  101: 0.0,
#  102: 0.0,
#  103: 0.0,
#  104: 0.0,
#  111: 0.0,
#  117: 0.0,
#  121: 0.0,
#  124: 0.0,
#  125: 0.0,
#  130: 0.0,
#  131: 0.0,
#  133: 0.0,
#  136: 0.0,
#  140: 0.0,
#  144: 0.0,
#  146: 0.0,
#  147: 0.0,
#  152: 0.0,
#  156: 0.0,
#  157: 0.0,
#  161: 0.0,
#  164: 0.0,
#  168: 0.0,
#  176: 0.0,
#  178: 0.0,
#  181: 0.0,
#  184: 0.0,
#  185: 0.0,
#  186: 0.0,
#  188: 0.0,
#  196: 0.0,
#  199: 0.0,
#  201: 0.0,
#  209: 0.0,
#  216: 0.0,
#  220: 0.0,
#  222: 0.0,
#  228: 0.0,
#  229: 0.0,
#  230: 0.0,
#  231: 0.0,
#  233: 0.0,
#  234: 0.0,
#  237: 0.0,
#  250: 0.0,
#  251: 0.0,
#  253: 0.0,
#  254: 0.0,
#  255: 0.0,
#  258: 0.0,
#  259: 0.0,
#  262: 0.0,
#  267: 0.0,
#  274: 0.0,
#  276: 0.0,
#  279: 0.0,
#  281: 0.0,
#  282: 0.0,
#  283: 0.0,
#  285: 0.0,
#  286: 0.0,
#  292: 0.0,
#  293: 0.0,
#  294: 0.0,
#  302: 0.0,
#  306: 0.0,
#  307: 0.0,
#  308: 0.0,
#  313: 0.0,
#  316: 0.0,
#  317: 0.0,
#  323: 0.0,
#  324: 0.0,
#  326: 0.0,
#  330: 0.0,
#  336: 0.0,
#  338: 0.0,
#  339: 0.0,
#  342: 0.0,
#  344: 0.0,
#  350: 0.0,
#  352: 0.0,
#  353: 0.0,
#  355: 0.0,
#  357: 0.0,
#  358: 0.0,
#  361: 0.0,
#  365: 0.0,
#  371: 0.0,
#  374: 0.0,
#  376: 0.0,
#  381: 0.0,
#  383: 0.0,
#  384: 0.0,
#  386: 0.0,
#  387: 0.0,
#  390: 0.0,
#  391: 0.0,
#  392: 0.0,
#  397: 0.0,
#  400: 0.0,
#  408: 0.0,
#  409: 0.0,
#  411: 0.0,
#  414: 0.0,
#  415: 0.0,
#  416: 0.0,
#  417: 0.0,
#  421: 0.0,
#  423: 0.0,
#  424: 0.0,
#  425: 0.0,
#  428: 0.0,
#  432: 0.0,
#  436: 0.0,
#  437: 0.0,
#  438: 0.0,
#  440: 0.0,
#  443: 0.0,
#  445: 0.0,
#  446: 0.0,
#  448: 0.0,
#  449: 0.0,
#  452: 0.0,
#  454: 0.0,
#  457: 0.0,
#  458: 0.0,
#  464: 0.0,
#  465: 0.0}

# %%
temp_cosine = sorted_cosine_scores

# %%
#Applying weights to the title
# Out:
# 'danah away from the veiw '

# %%
titles
# Out:
# ['Going 100 West by 53 North by Jim Prentice (1990)',
#  'The Story of the Sly Fox',
#  'A Smart Bomb with a Language Parser',
#  'Two Guys in a Garage, by M. Pshota',
#  'The Early Days of a High-Tech Start-up are Magic (November 18, 1991) by M. Peshota',
#  'The Couch, the File Cabinet, and the Calendar, by M. Peshota (December 9, 1991)',
#  'Engineering the Future of American Technology by M. Peshota (January 5, 1992)',
#  'What Research and Development Was Always Meant to Be, by M. Peshota',
#  'The Adventure of the Three Gables',
#  'The Story of the 3 Little Pigs',
#  'A Collection of Sonnets by Staeorra Rokraven (March 9, 1989)',
#  'The Adventure of the Three Students',
#  'The Story of the Three Wishes',
#  'Fiction: The 4 Moons of Death',
#  'The Story of the Five Orange Pips',
#  'The Story of the Six Able Men',
#  'The Adventure of the Six Napoleons',
#  'The Seven Old Samurai',
#  'The Seven Voyages of Sinbad the Sailor',
#  'The Story of Ali Baba and the 40 Thieves',
#  'The Adventure of the Abbey Grange (RP Story)',
#  'How life goes on at the edge of Abyss',
#  'The Chronicles of Astrus II: Father Adler by Ben Blumenberg',
#  'The Adventures of Aladdin',
#  "Sayed's Adventures",
#  'The Adventures of Tom Thumb',
#  "Aesop's Fables Translated by George Fyler Townsend",
#  "Aesop's Fables (84 of Them) from The PaperLess Readers Club",
#  'The Air Conditioning Story',
#  'Aisle Six, by Morpheous of LOM',
#  'Aisle Six, by Morpheous, an LOM Release',
#  'Aladdin and the Wonderful Lamp',
#  "The Fable of Ali and the Sultan's Saddle",
#  'Alternate Side of the Street; Screenplay by Jeff Massie',
#  'An Aluminum Can A Day, by Carl Mitchell',
#  'The Fable of Amin and the Eggs',
#  "Angel's Fur, by Piper Sickles",
#  'Cliff-Hanger, a Poem',
#  'The Fable of the Ant and the Cricket',
#  'My Lord Aquith: Novella by Yves Barbero',
#  'Arcadia, a Story',
#  ' A Collection of Various Good Stories',
#  'The Arctic Circle and Beyond, by Jim Prentice (1990)',
#  'Updating Aesop, or The Old Lady and the Crypt or Blood',
#  'FICTION: Yahoo! The Ohio VOW has The Bomb by Gregory S. Swann (1986)',
#  'Bagel Man, by Aldebaran of 11th Hour Productions',
#  'Bagel-Man, by Aldebaran of 11th Hour Productions',
#  'Collection of Additional Rules for Battletech, by Matt Murphy',
#  'A Collection of Fiction about The Beast',
#  'The Story of Beauty and the Beast',
#  "The Beggar's Opera, by John Gay, 1728",
#  'The Adventures of Bert and Bernece, by  Francis U. Kaltenbaugh',
#  'How Ernie and Bert Came to Be, by 11th Hour Productions',
#  'FICTION: My Best Wish',
#  'Before the Beyond, by Dallas Vordahl',
#  'Beaver Gone Bad! A mini-manuscript by Pete Stocton and Baron Von Crash',
#  'Mega-Yonkers 2038 : The Story of Knight Foils: Bubble Gum Cards, by Ryan Mathews, January 1992',
#  'Big Red Riding Cape',
#  'Pyramid Scheme, by Douglas M. Warren, 1993',
#  'The Super Blab Novel, from Datanet',
#  'Super Blabnovel-A continuing saga on DATANET',
#  'The Adventure of Black Peter',
#  'A Few Words About The Black Rider (German Literature)',
#  'Lunch in the Park, by Francis U. Kaltenbaugh',
#  'Blasters to the Ready! By William E. Collins',
#  "The Birdlover's Holiday, by Andrew P. Varga",
#  'Blind Sight, by Lyn Nichols, August 1993',
#  'Little Quaint list of Funny Names to Tell a story.',
#  'Soldier Blue, by Rick Arnold',
#  'Bluebeard',
#  "Boom 'Em Issue #1 (1995)",
#  "Book 'Em Issue #2 (1995)",
#  "Book 'Em Issue #3 (1995)",
#  'Brain Damage, by Howard I Cannon, 1979',
#  'Brambles, by Gordon Chapman',
#  'Branded, by John R. Hillman, Jr.',
#  'Breaks: The Adventures of Richard Nixon in the 21st Century, by Philip H. Farber (1992-1993)',
#  'Breaks: The Adventures of Richard Nixon in the 21st Century, by Philip H. Farber (1992-1993)',
#  'Breaks: The Adventures of Richard Nixon in the 21st Century, by Philip H. Farber (1992-1993)',
#  'The Adventure of the Bruce-Partington Plans',
#  'Buggy, by Andrew P. Varga (1991)',
#  'Details, a story by The Martyr',
#  'Dreamworld, by Zaphod Beeblebrox',
#  'A Story for Cat Lovers',
#  'The Hunter, the Hunted, a story by G. Daniel Flower',
#  'Story: Iron Man',
#  'Three Paragraphs: Excertps from Something',
#  "They Don't Come Any Larger: The Continuing Adventures of Mr. X.",
#  'A New Land, by Vengeance',
#  'No Options Left, by G. Daniel Flower',
#  "The Ill-Fated Voyages of Cap'n Roger, by Julius M. Brown (1989)",
#  "The Adventures of Cap'n Roger (Part 2)",
#  'A Phreak Encounter (Story)',
#  'Prints of the City, by G. Daniel Flower',
#  'It was a dark and stormy night (The Best of the Bulwer-Lytton Contest)',
#  "The Zorker's Story (Story)",
#  'Bummers by Thomas Nevin Huber',
#  'The Bureau of Procuration (Story)',
#  'Interview with William S. Burroughs (1966)',
#  'William S. Burroughs: A Sketch (July 1978)',
#  'Which is the Fly and Which is the Human? (Interview with William S. Burroughs and David Cronenberg 1992, Equire Magazine',
#  'The Letters of William S. Burroughs (1945-1959) by Oliver Harris',
#  'The Burn: A Synopsis by Michael C. McPherson',
#  'The Cabin, by Adam Poszar (1991)',
#  'Some aborted attempt at a screenplay, maybe',
#  'The Best Campire Story of the Week: Do you have a B.C.?',
#  'The Wind, The Cold, The Candle, by Walter Hawn',
#  'Accounting for the Cards by H. R. Valimaa',
#  'The Fable of the Cock, the Cat, and the Mouse',
#  'Cosmic Charlie by Colin Campbell',
#  'City Chicken, by D. M. Hanna',
#  'The Donkey that Thought He Was Clever',
#  'Clones to us! By Thomas Nevin Huber',
#  'The Story of The Country Mouse and the Town Mouse',
#  "Computers N' Me, by Rich Griebel",
#  'Conflict, by Jason Scott',
#  'Consumated Dreams, by Melanie Martin Vessels',
#  'Contradiction 1, by Rick Brunet',
#  'Cool Darkness: A Cyberpunk Novel by Matthew Carpenter',
#  'STORY: Cool Darkness, by Matthew Carpenter',
#  'Corcoran, by Bruce Drake',
#  'The Story of the Cow Exploder by CKE Enterprises (1984)',
#  'The Story of the Crab and the Heron',
#  'Crazy Glue, a Novel by Jerry Slaff',
#  'Come Into my World by Thomas NEvin Huber',
#  'Curious Georgie by The Penguin of SubZero AE',
#  'Book: Revolt of the Cyberslaves, by Lawrence Dworin (1991)',
#  'Rifts World Book: North Dakota by Sean Satterlee',
#  'Made for Dancing, by Charles Bell',
#  'The Heart of Darkness by Joseph Conrad',
#  'A Day in McDonaldland by G.I. Joe of DETAC (June 10, 1986)',
#  'Dealer, by Robbie D. Whiting',
#  'The Death of Ms. D, by William S. Burroughs',
#  'The Deer, by Andrew P. Varga (1992)',
#  'A Descent into the Maelstrom',
#  'The Diary of the Swarves',
#  'Guide to Dice Games of Dungeons and Dragons by Reid Bluebaugh',
#  'A Manly Wager by Lucillus and a Heaping of Testosterone',
#  'Disco Can By Fun, by Aldebaran of 11th Hour Productions',
#  'Disco Can Be Fun by Aldebaran of 11th Hour Productions',
#  'The Domain of Arnheim',
#  'The Story of Dopey Dennis',
#  'Dream School: A Novella',
#  "Dad's Pickup, by Andrew P. Varga",
#  'Dwarf, by Jeroen Van Drie',
#  'Fiction: Alex',
#  'The Elves and the Shoemaker',
#  "The Emperor's Three Questions by Leo Tolstoy",
#  "The Emperor's New Clothes",
#  'The Empress Jowka',
#  'The Adventure of the Empty House',
#  'Encoded in Strands, by Gay Bost',
#  'Saturday Night at the Shindar Encampment by Lucillus',
#  'The Enchanted Duplicator, by Walt Willis and Bob Shaw',
#  "The Adventure of the Engineer's Thumb",
#  'English Translations of _The Celts_, _Watermark_, and _Shepherd Moons_, by Enya',
#  'The Snarkout Boys and the Avocado of Death',
#  'A Relevant Excerpt from "The Snarkout Boys and the Avocado of Death", by Daniel Manus Pinkwater.',
#  'The Eye of Argon, by Jim Theis',
#  'EZ Work, by Gay Bost',
#  'The Fable, by Ben Blumenberg',
#  'Pricilla, the Trout Princess, by Gerald E. Gregg',
#  'The Blab Fantasy Novel',
#  'The Blab Fantasy novel-Ripped off and edited by The Slipped Disk',
#  'Hula Hoops and Tinker Toys by Nancy VanWormer (1995)',
#  'Waterlogged Klingons by L. Shawn Aiken (1994)',
#  'Survey Results, by Joe DeRouen (1994)',
#  'Fear of Growing Old',
#  'Fear and the Monkey (A Ouija Board Poem) by William S. Burroughs (1984)',
#  'A List of Father Good Stories',
#  'Beacons of Light, by L. Shawn Aiken (1995)',
#  'Experiment, by Ed Davis (1993)',
#  'Ouija Warning, by Ed Davis (1993)',
#  'A Close Encounter of a Different Kind, by Sylvia L. Ramsey (1993)',
#  'The Imp, by Ed Davis (1993)',
#  'A Chance Meeting in the Park, by Joe DeRouen',
#  'Once There Was a Fish by Doug Rosentrater',
#  'Fleas: A Story, by Adam Poszar (1991)',
#  'Flak Trap (Story) by Brendan Meara (Juanry 18, 1995)',
#  'Matriarchal Shepherd by Marc Edwards',
#  'The Cube of Shalube...By Dr. Muess (June 24, 1989)',
#  'The Spirit and the Flute (How Flutes Relate to History)',
#  'The Story of the Flying Trunk',
#  'Forgotten Souls by CAC/The Stinker',
#  'Another Fourth of July, by Jeff Epstein',
#  'Fowl Death by Nuclear Deth (April 7, 1987)',
#  'The Story of the Fox and the Crow',
#  'The Story of the Fox and the Grapes',
#  'The Story of the Fox and the Stork',
#  'Cheese or These? By Francis U. Kaltenbaugh',
#  'The Story of Fred.',
#  'The Last Free Man, by Francis W. Porretto',
#  "Man's Best Friend, by Marty Weiss",
#  'Friends: A Story',
#  'The Story of the Frog Prince, by Andrew Varga',
#  'The Story of Ronald Frump, by Dave Bealer',
#  'The Game, by Suki',
#  'Collection of Poetry by David Fox (1990)',
#  'A Collection of Poetry by Gay Bost (1994)',
#  'The Story of the Dragons of Gems',
#  'Time for Flowers, by Gay Bost',
#  'Dream Girl by Melina Huddy',
#  'The Girl of the Month Club by Colin Campbell',
#  'A Glimpse Into My Mind at 12:45pm, by Sean M. Gomez (1993)',
#  'Oops! There was a little messup with the christmas gift!',
#  'The Story of Goldilocks and the Three Bears',
#  'The Gold Bug, by Poe',
#  'The Adventure of the Golden Pince-Nez',
#  'The Little Gold Fish',
#  'The Tale of the Golden Goose',
#  'Memory Cemetery, by Gay Bost',
#  'Nightmare in Grey by Fredric Brown',
#  'The Great Learning: The Text of Confucious',
#  'The Parable of the Greedy Dog',
#  "Gulliver's Travels, by Johnathan Swift (1726)",
#  'The Fable of Hansel and Gretel',
#  'The Fable of the Hare and the Elephant',
#  'The Fable of the Hare and the Porcupine',
#  'The Fable of the Hare and the Tortoise',
#  'The Soul Healer: A Story by Ben Blumenberg',
#  'Donatien Alphonse Francois de Sade (A Story)',
#  'The Hell Machine, by James C. Lynn (1990)',
#  'Ashtray and Gherkin (Helmet Fusion Specialists)',
#  'The Hills of Commerce, by Marilyn Hutchings',
#  'The Slopes of Te Aroha',
#  'Complete Transcription of Douglas Adams\' "Restaurant at the End of the Universe"',
#  'Complete Transcription of Douglas Adams\' "Life, the Universe and Everything"',
#  'The Hole THat Was Too Narrow',
#  'The Holmes List: A List of Books That Reference or Discuss Sherlock Holmes',
#  'The Homecoming, by Francis W. Porretto of Horse Feathers BBS',
#  'The Story of Hop Frog',
#  'The Horse and the Donkey',
#  'The Horse and the Wolf',
#  'Hotline! by James Zachary',
#  'Hotline! Part III, by James Zachary',
#  'Hotline! Part IV, by James Zachary',
#  'The Hound of the Baskervilles, by Sir Arthur Conan Doyle',
#  'how Ernie and Bert Came to Be by 11th Hour Productions',
#  'The First Adventures of IDI',
#  'I Give Up, by Thomas Nevin Huber',
#  'Just Imagine: A Story',
#  'Immortality by William S. Burroughs',
#  'Immorti, by Todd Rich',
#  "Please, God, I'm Only 17... by the Elite Executives",
#  'Submerged Interface, by Gay Bost',
#  'The Island of the Fay',
#  'The Story of Jack and the Beanstalk',
#  "Jackmac's Discovery by Jeff Epstein",
#  'Be a Clerk All My Life? Not Me!',
#  'Bricks In The Wall, by M.D. Roccatani',
#  'The Book of Jim',
#  'Keeping Insanity in the Closet, by The Weatherman (April 13th, 1988)',
#  'Odnaar Keep by David M. Millstein',
#  'The Legends of the Kharianians',
#  'Kneeslapper by Slafathor (July 23, 1991)',
#  'Kneeslapper by Slagathor (July 23, 1991)',
#  'The Story of Knucklebones',
#  'The Furry Orphan of War',
#  "KZAP's Psychedelic Sunday",
#  "I have no idea where this came from or where it's going.",
#  "Offender E477439's Lament",
#  'The Fable of the Little Golden Bird',
#  'Notes towards a story',
#  'A Letter to Lillian by Gay Bost',
#  'Lionbirds, by MArtin R. Crim (1994)',
#  "The Adventure of the Lion's Mane",
#  'The Fable of the Lion and the Mosquito',
#  'The Lion Goes to War (Fable)',
#  'The Fable of the Little Mermaid',
#  'The Little Matchgirl',
#  'The Longest Distance by D.W. Boynton (1992)',
#  'The Little Pear Girl: A Story',
#  'The Story of Little Red Riding Hood',
#  'Liberty Tree Pub: Her Honour, by D. M. Hanna',
#  'Luffing, by Ron Fleshman',
#  'The Lure of the Temptress (Soft Documentation)',
#  'MARIO, by Archer Blue: A Short History of Mario',
#  'Once Upon a Mattress, by Nikolai Kingsley, 1995',
#  'The Adventure of the Mazarin Stone',
#  'A Day in McDonaldland by G.I. Joe (June 10, 1986)',
#  'Melissa and the Green Dragon',
#  'An Ode to Mike, by Alien',
#  'Mind Probe, by Michael Abbot',
#  'Mind War by William S. Burroughs',
#  'The Adventure of the Missing Three-Quarter (A story)',
#  'Modem Hippy: A Poem by Morpheous of LOM',
#  'The Story of the Monkey King',
#  'The Secret of Monkey Island Unvield by SYNDICATE',
#  'The Story of the Mouse and the Lion',
#  'The Story of the Magic Tinderbox',
#  'The Musgrave Ritual (Story)',
#  'The Musicians of Bremen',
#  'Someone Talks About Some Weird Dreams He Has',
#  'Poem: Through My Eyes',
#  'The Story of Narcissus',
#  'The Saga of Nigel the Hedgehog',
#  'The Saga of Nigel the Hedgehog 10 (July 6, 1989)',
#  'The Saga of Nigel the Hedgehog 2 (May 25, 1989)',
#  'The Saga of Nigel the Hedgehog 3 (June 2, 1989)',
#  'The Saga of Nigel the Hedgehog 4 (June 2, 1989)',
#  'The Saga of Nigel the Hedgehog 5 (June 12, 1989)',
#  'The Saga of Nigel the Hedgehog 6 (June 12, 1989)',
#  'The Saga of Nigel the Hedgehog 7 (june 17, 1989)',
#  'The Saga of Nigel the Hedgehog 8 and 9',
#  '"Peek in the Night" by Night Words',
#  'Musings by Joe DeRouen (1993)',
#  'If I Had One Wish... by L.J. Herbert (1993)',
#  'A Panacea for Cheezy Movies by L. Shawn Aiken',
#  'The Tale of the Obstinate Goats',
#  'The Fable of Prince Omar and Princess Sheherazade',
#  'The Outcast, by Winwood Reade, 1933',
#  'The Fable of the Ox and the Frog',
#  'Painkiller, by William Slattery',
#  'An Author Argues with his Main Character',
#  'The Story of the Parrot Shah',
#  'What happened on the Friday last October',
#  "Paul Harvey's List of True Real Stories",
#  'Vision of Peace on Earth',
#  'Pepsi Degeneration by Morpheous of LOM',
#  'Pepsi Degeneration by Morpheous of LOM',
#  'Picture Perfect, by Roberta Belinda',
#  'The Story of Pinocchio',
#  'Arrr! The Pirates have arrived!',
#  'Asleep by Craig Plesco',
#  'Poetry: A Song of Love (October 25, 1993)',
#  'Poetry: Broken Heats, by Kylis Noren (October 19, 1993)',
#  'Poetry: "An Ode to Death" - By Us! (October 19, 1993)',
#  'The Fable of the Poplar and the Stream',
#  'The Pied Piper of Hamelin',
#  'Pregnant Pause by Dorothy Lindman',
#  'The Princess vs. the Principal, by Marc Perkel',
#  'Programmer X, by Greg Borek',
#  'The Peasant, the Snake, and the Fox',
#  'Psicop, by Jack Hillman',
#  'Psyche and Cupid: A Theory, by Dr. Harold Levdahed',
#  'The Story of Puss in Boots',
#  'How Sailor Ted Got Out of It',
#  'The Plan, by Shannon Carraher (Part 1)',
#  'Tea Time with the Devil, by Brant Swancer',
#  'I Spoke with the Sun, by Caroline Kennedy (And Other Poems)',
#  'Welcome to the Planet of Kampf, by Jim Zachary',
#  'The Mission, by Jon Lang',
#  'Leftover Stew, by Patrick Barnes',
#  'My Father and Me, by Mike Russello',
#  'Under the Weeping Willow Tree, by Patrick Miner',
#  'Blind Fate, by Toby Bradley',
#  'Bearing Down, by John Dudley',
#  'Hometown Ways, by Amy Slavin',
#  'Remembering, by Kristin Feyen',
#  'The Quarantine, by Moses Domingo',
#  'A Savage Projectile, by Steve Gaines',
#  'Peel Me Away, by Bill DeClercq',
#  'Little White Lines, by Joe Raymundo',
#  'At Midnight, by Karin Johnson',
#  'The Singer in the Depths by Steven Myers',
#  'The Rose, by Suzy Edmonson',
#  'The Quest for Axe of the Dwarven Lords by Bruce RW. Reisman',
#  'Quick Fix, by William S. Burroughs',
#  'A Collection of Quotes by Poets about Poetry',
#  'Interview with the Radar Ranger: A Work of Fiction by D. Railleur',
#  'Rain Dance (Mechwarrior Fan Fiction) by Douglas M. Warren',
#  'The Reality of Our Situation by Kortron',
#  'The Reaper, by Gay Bost',
#  'The Fable of the Red Dragon',
#  'Retribution by Andrew Varga (1991)',
#  'Getting Rid of the Riddler, by Alien',
#  'Book Excerpt: Protoculture and the Children of the Shadow (Robotech)',
#  'Rock, by D.M. Hanna',
#  'The Space Saga of "Rocket" Roger Robinson (Story)',
#  'In Residence by KaRylin',
#  'Story: Running',
#  "The Plot Thickens: A Writer's Dream, by Cecilio Morales",
#  "John's Diner: Who Was The Guy? By Lucia Chambers",
#  'Safe Place: A Synopsis, by Michael C. McPherson',
#  'The Fruit of the Gods: Trichoserus Pachanoi',
#  'The Adventure of Shoscombe Old Place',
#  "A Shrewd Farmer's Story (Fable)",
#  'The Fable of the Hunter and the Hunted',
#  'The Sick Kids: Story by Roger M. Wilcox',
#  'Story about Jamie, badly formatted',
#  'Silver Blaze (Story)',
#  'Sister Mary Agnes by Gay Bost',
#  'The Sleeping Princess (Fable)',
#  'Story about Ed, again badly formatted',
#  'The Fable of the Snow Maiden',
#  'The Fable of the Snow Queen',
#  'Social Vikings by Flat Tire (August 5, 1988)',
#  'Social Vikings by The Flat Tire (August, 1988)',
#  'The Adventure of the Solitary Cyclist',
#  'Space Travel by Adam Poszar (1990)',
#  'The Key and I, or, My Travels in the Sky, and What I Found There, by Padre Martini, Archdukebishop of West Texas',
#  'The Spectacles, by Edgar Allen Poe',
#  "The World's Fastest Spider, by Andrew Varga (1991)",
#  'Story about Harvey and Spiders',
#  'Squeeze Play, by Michael A. Stackpole (1989)',
#  "SRE's Darker Half, by Chris Trendle, Paul Gerth and Robert Chapman",
#  'A Cool 3.7 Million, by The Stainless Steal Rat',
#  'The Stiarway Dram, by Satinka Istari',
#  'Startrek, The Ultimate Story!',
#  "It's All Greek to uncle Thaddeus, by Joe DeRouen (1993)",
#  'The Dark Sucker, by Quantum Mechanic',
#  'Sunday, by Nanci (February 20, 1993)',
#  'The Story of SUPERGUY!!',
#  'The Szechuan Taxi, by Dave Bealer',
#  'Story: Mission Impossible Meets the Twilight Zone',
#  'The Tail of the Bear: A Fable',
#  'The Tao Te Ching, translated by James Legge',
#  'Back Taxes, a Novel by Paul Mahler (1991-1992)',
#  'The Cask of Amontilado, by Edgar Allan Poe',
#  'The Cockroach that Ate Cincinatti (Poem)',
#  'Tears of Glass by Kimberly Ann Carter (1992)',
#  'The Telephone Rape Story',
#  'The Terror Bears on the Rampage by Darkside 414',
#  'Test Pilot, Story by John Vornholt',
#  "The Ramsacker's Textfile Primer by The Ramsacker of Pieces of Eight (July 27, 1989)",
#  'A Thanksgiving Prayer, by William S. Burroughs',
#  'The Tree: A Poem',
#  'The Navajo and the Bhuddist (October 19, 1992)',
#  'The Time Machine, by H.G. Wells (1898)',
#  'Times Doubles Defect; Publisher Possibly Plinked by Jean Blevins',
#  'The Problem with Time Travel (Story)',
#  'Tinned Warmth by Gordon Chapman',
#  'The Tin Soldier (Story)',
#  'My Toilet, my Kingdom, by Bill Luby (1994)',
#  'Treason, by Marcus Tullius Cicero',
#  'Kevin and the Tree',
#  'The Ed Meese Commission presents Pornography Masquerading as Literature, by Tess Truehard and Gurn Blanston',
#  'The Fable of the Ugly Duckling',
#  'The Fable of the Unlucky Warrior',
#  'The Parable of the Vain Crow',
#  'A Manly Wager, a Song by Lucillus',
#  'Valentine, Story by George Willard',
#  "A Vampyre's Words: Poem",
#  "The Valentine's Day Blues, by B.A. Nilsson",
#  'The Adventure of the Veiled Lodger',
#  'The Vigilante',
#  'The Wall, from Karl L. Sandwell-Weiss',
#  'Poem by David Redish, The Wanderer',
#  'Infromation about Spellweavers',
#  'The Weeping Princess',
#  'Introduction to the Neolithic Great Goddess, by Ben Blumenberg (February 12, 1992)',
#  'The Adventure of Wisteria Lodge',
#  'My Living Semi-Hell Type Experience Thing, by Urethris, 1992',
#  'The Story of the Wise Little Girl',
#  'The Wolf and the Seven Kids',
#  'The Wolf and the Crane',
#  'The Wolf and the Lamb',
#  'The Story of the Wombat, from Floyd Gecko',
#  'The Three Golden Rules of Poetry by Michael Howard',
#  'The Writer by Thomas Nevin Huber',
#  'The Spell of the Yukon and Other Verses by Robert W. Service',
#  'Zombies by Suzanne L. McAllister (Spoof/Tribute of George Romero Living Dead Movies)',
#  'SRE: The Saga Of The Best SRE Game Ever Played! By Josh Renaud',
#  'Solar Realms Elite: The True Story of the Unsung Heroes, by Josh Renaud',
#  "Solar Realms Elite: Ultra's Untold Story by Josh Renaud",
#  'Solar Realms Elite IV: The Confrontation, by Josh Renaud',
#  'Solar Realms Elite V: The Underground, by Josh Renaud',
#  'Solar Realms Elite VI: The Alliance Restored, by Josh Renaud',
#  'Solar Realms Elite 7: Petros, by Josh Renaud',
#  'Solar Realms Elite VIII: Kazik, by Josh Renaud',
#  'Solar Realms Elite IX: Survival of the Fittest, by Josh Renaud',
#  'Solar Realms Elite X: Legacies, by Josh Renaud',
#  'Solar Realms Elite: The Feqh Galaxy, by Josh Renaud',
#  'Solar Realms Elite: The Finale by Josh Renaud',
#  'Solar Realms Elite: Galaxy Sei, by Josh Renaud',
#  'The SRE Commerce and Trade Theories, by Josh Renaud',
#  'Solar Realms Elite: X1 and X2, by Josh Renaud']

# %%
q = "Adventure of the Three Gables"

# %%
q = remove_stop_words(q)

# %%
q
# Out:
# ' Adventure Three Gables'

# %%
qu = q.split()

# %%
qu
# Out:
# ['Adventure', 'Three', 'Gables']

# %%
for item in qu:
    doc = 0
    
    for title in titles:
        
        if item.lower() in title.lower():
            score = temp_cosine[doc]
            new_score = score * 1.4
            print(title + " :: " + item+" :: ",doc," :: ",score," :: ",new_score)
        
        doc += 1
# Out:
# The Adventure of the Three Gables :: Adventure ::  8  ::  0.0005185780265533383  ::  0.0007260092371746736
# The Adventure of the Three Students :: Adventure ::  11  ::  0.0003979648294628428  ::  0.0005571507612479799
# The Adventure of the Six Napoleons :: Adventure ::  16  ::  0.00042172553883332986  ::  0.0005904157543666618
# The Adventure of the Abbey Grange (RP Story) :: Adventure ::  20  ::  0.00042924989269658114  ::  0.0006009498497752136
# The Adventures of Aladdin :: Adventure ::  23  ::  0.0008434323901176068  ::  0.0011808053461646495
# Sayed's Adventures :: Adventure ::  24  ::  0.0006080563602399  ::  0.00085127890433586
# The Adventures of Tom Thumb :: Adventure ::  25  ::  0.0007926736347653065  ::  0.001109743088671429
# The Adventures of Bert and Bernece, by  Francis U. Kaltenbaugh :: Adventure ::  51  ::  0.0006041219398619397  ::  0.0008457707158067155
# The Adventure of Black Peter :: Adventure ::  61  ::  0.0002665698833653131  ::  0.00037319783671143833
# Breaks: The Adventures of Richard Nixon in the 21st Century, by Philip H. Farber (1992-1993) :: Adventure ::  76  ::  0.00033827198217361096  ::  0.0004735807750430553
# Breaks: The Adventures of Richard Nixon in the 21st Century, by Philip H. Farber (1992-1993) :: Adventure ::  77  ::  0.00030180363131254175  ::  0.0004225250838375584
# Breaks: The Adventures of Richard Nixon in the 21st Century, by Philip H. Farber (1992-1993) :: Adventure ::  78  ::  0.000374893039823003  ::  0.0005248502557522042
# The Adventure of the Bruce-Partington Plans :: Adventure ::  79  ::  0.00042848109809686557  ::  0.0005998735373356118
# They Don't Come Any Larger: The Continuing Adventures of Mr. X. :: Adventure ::  87  ::  0.0004359301344594162  ::  0.0006103021882431826
# The Adventures of Cap'n Roger (Part 2) :: Adventure ::  91  ::  0.0  ::  0.0
# The Adventure of the Empty House :: Adventure ::  150  ::  0.00025413242033849346  ::  0.0003557853884738908
# The Adventure of the Engineer's Thumb :: Adventure ::  154  ::  0.0005438729142838792  ::  0.0007614220799974309
# The Adventure of the Golden Pince-Nez :: Adventure ::  207  ::  0.0004753991030888897  ::  0.0006655587443244455
# The First Adventures of IDI :: Adventure ::  238  ::  0.0003358001175845688  ::  0.00047012016461839626
# The Adventure of the Lion's Mane :: Adventure ::  265  ::  0.000462648206073056  ::  0.0006477074885022783
# The Adventure of the Mazarin Stone :: Adventure ::  278  ::  0.0004464875559437578  ::  0.0006250825783212609
# The Adventure of the Missing Three-Quarter (A story) :: Adventure ::  284  ::  0.00040937442538784973  ::  0.0005731241955429896
# The Adventure of Shoscombe Old Place :: Adventure ::  375  ::  0.00058580465872486  ::  0.000820126522214804
# The Adventure of the Solitary Cyclist :: Adventure ::  388  ::  0.00041186374671735906  ::  0.0005766092454043026
# The Adventure of the Veiled Lodger :: Adventure ::  434  ::  0.0005220332700520858  ::  0.0007308465780729201
# The Adventure of Wisteria Lodge :: Adventure ::  441  ::  0.00035177780053948567  ::  0.0004924889207552799
# The Adventure of the Three Gables :: Three ::  8  ::  0.0005185780265533383  ::  0.0007260092371746736
# The Adventure of the Three Students :: Three ::  11  ::  0.0003979648294628428  ::  0.0005571507612479799
# The Story of the Three Wishes :: Three ::  12  ::  0.0005612472161976634  ::  0.0007857461026767287
# Three Paragraphs: Excertps from Something :: Three ::  86  ::  0.001141488167412403  ::  0.001598083434377364
# The Emperor's Three Questions by Leo Tolstoy :: Three ::  147  ::  0.0  ::  0.0
# The Story of Goldilocks and the Three Bears :: Three ::  205  ::  0.0011074099113986392  ::  0.0015503738759580948
# The Adventure of the Missing Three-Quarter (A story) :: Three ::  284  ::  0.00040937442538784973  ::  0.0005731241955429896
# The Three Golden Rules of Poetry by Michael Howard :: Three ::  448  ::  0.0  ::  0.0
# The Adventure of the Three Gables :: Gables ::  8  ::  0.0005185780265533383  ::  0.0007260092371746736

# %%
titles[147]
# Out:
# "The Emperor's Three Questions by Leo Tolstoy"
